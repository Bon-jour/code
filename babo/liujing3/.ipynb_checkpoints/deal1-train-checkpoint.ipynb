# %%
setwd('/import/liujing/data/')

# %%
data1 = read.table('./train.txt',header =T,sep = '\t',check.names =  F)

# %%
head(data1,2)
# Out:
#   Gene_name CI10      CI11      CI12      CI13      CI14      CI15
# 1 PCDHGA7   0.4695917 0.0650995 0.5719537 0.2243807 0.2778357 0.3244079
# 2 PCDHGA6   0.9626630 0.3719971 0.9496590 0.4605710 0.7203147 0.3244079
#   CI16      CI17      CI18      ... H42       H43       H44       H45
# 1 0.3385146 0.3741117 0.2707183 ... 0.1563046 0.1786892 0.1263336 0.07888511
# 2 0.6073351 0.5391610 0.3970535 ... 0.2709279 0.5360676 0.2411824 0.27046323
#   H46       H4        H5        H7        H8       H9
# 1 0.2894804 0.4040563 0.1882475 0.1843685 0.927869 0.4618961
# 2 0.5010238 0.4914198 0.4823842 0.6913819 1.293789 0.7743553

# %%
colnames(data1) = paste0(colnames(data1),'_M1')

# %%
data2 = read.table('../test.txt',header =T,sep = '\t',check.names =  F)

# %%
colnames(data2) = paste0(colnames(data2),'_M2')

# %%
head(data2,2)
# Out:
#   Gene_name_M2 CI10_M2 CI11_M2 CI12_M2   CI13_M2 CI14_M2 CI15_M2 CI16_M2 CI1_M2
# 1 RNA5SP111    0       0       0.6257938 0       0       0       0       0
# 2 RNA5SP110    0       0       0.0000000 0       0       0       0       0
#   CI2_M2 ... H18_M2 H1_M2 H2_M2 H3_M2    H4_M2 H5_M2 H6_M2    H7_M2     H8_M2
# 1 0      ... 0      0     0     1.409555 0     0     1.985912 0.7690921 0
# 2 0      ... 0      0     0     0.000000 0     0     0.000000 0.0000000 0
#   H9_M2
# 1 0
# 2 0

# %%
library(dplyr)

# %%
data = merge(data1,data2,by.x = 'Gene_name_M1',by.y = 'Gene_name_M2') %>% na.omit()

# %%
data = data[!duplicated(data$Gene_name_M1),]

# %%
rownames(data) = data[,1]
data = data[,-1]

# %%
head(data,2)
# Out:
#       CI10_M1    CI11_M1  CI12_M1  CI13_M1     CI14_M1  CI15_M1  CI16_M1
# 1-Dec 0.03458845  0.00000  0.00000  0.01159795  0.00000 0.000000  0.00000
# 1-Mar 6.37533353 14.47555 12.77842 23.51504755 18.84067 6.023943 11.42203
#       CI17_M1  CI18_M1      CI19_M1 ... H18_M2   H1_M2     H2_M2    H3_M2
# 1-Dec  0.00000  0.008862286  0.0000 ...  0.00000 0.0186585  0.00000  0.00000
# 1-Mar 10.56791 50.336592430 11.3183 ... 12.24104 9.8311557 21.52282 17.08353
#       H4_M2    H5_M2      H6_M2      H7_M2       H8_M2    H9_M2
# 1-Dec  0.00000 0.03354671  0.0285174  0.01656607 0.000000  0.00000
# 1-Mar 11.17267 9.84920741 15.5839781 11.82206945 9.107572 17.71799

# %%
anno = data.frame(sample = colnames(data),
          group = c(rep('CI',43),rep('H',42),rep('CI',16),rep('H',18)),
          Matrix = c(rep('Matrix1',85),rep('Matrix2',34) ) )

# %%
rownames(anno) = anno[,1]
anno = anno[,-1]

# %%
head(anno,2)
# Out:
#         group Matrix
# CI10_M1 CI    Matrix1
# CI11_M1 CI    Matrix1

# %%
exp = log(data+1)

cg=names(tail(sort(apply(exp,1,sd)),5000))
n=exp[cg,]

library(pheatmap)

forplot = na.omit(n)
#da=log2(data1+1)
dat=t(scale(t(forplot))) # 'scale'可以对log(fpkm+1)数值进行归一化
#处理数据
dat[dat>2]=2
dat[dat<(-2)]= -2
dim(dat)
dat = dat[complete.cases(dat), ]
# Out:
# [1] 5000  119

# %%
library(pheatmap)

# %%
pheatmap(dat,
         cluster_rows = TRUE,
         cluster_cols = TRUE,
         show_rownames=FALSE,
         show_colnames = FALSE,
          scale="none",
          #cluster_cols = F,
          fontsize_row = 10,
          fontsize_col = 10,
         annotation_col = anno,
          #color = colorRampPalette(c("navy", "white", "firebrick3"))(100),
          color = colorRampPalette(c("#00BCB6", "white", "#FE4300"))(100)#换颜色
         # angle_col = 45 #修改横轴坐标名倾斜度
)
# Out:
# plot without title

# %%
library("FactoMineR")
library("factoextra")
pca.plot = function(dat,col){
  
  df.pca <- PCA(t(dat), graph = FALSE)
  fviz_pca_ind(df.pca,
               geom.ind = "point",
               col.ind = col ,
               addEllipses = TRUE,
               legend.title = "Groups"
  )
}
pca.plot(dat,factor(anno$group))
# Out:
# Warning message:
# "package 'FactoMineR' was built under R version 4.2.3"
# Warning message:
# "package 'factoextra' was built under R version 4.2.3"
# Loading required package: ggplot2
#
# Welcome! Want to learn more? See two factoextra-related books at https://goo.gl/ve3WBa
# plot without title

# %%
pca.plot(dat,factor(anno$Matrix))
# Out:
# plot without title

# %% [markdown]
# ### 去批次

# %%
library(sva)

# %%
batch = anno$Matrix

# %%
combat_edata1 = ComBat(dat=data, batch=batch, mod=NULL, par.prior=TRUE,  prior.plots=FALSE)
# Out:
# Found 1621 genes with uniform expression within a single batch (all zeros); these will not be adjusted for batch.
# Found2batches
#
# Adjusting for0covariate(s) or covariate level(s)
#
# Standardizing Data across genes
#
# Fitting L/S model and finding priors
#
# Finding parametric adjustments
#
# Adjusting the Data

# %%
save(combat_edata1,anno,file = 'combat_edata1.rda')

# %%
library("FactoMineR")
library("factoextra")
pca.plot = function(dat,col){
  
  df.pca <- PCA(t(dat), graph = FALSE)
  fviz_pca_ind(df.pca,
               geom.ind = "point",
               col.ind = col ,
               addEllipses = TRUE,
               legend.title = "Groups"
  )
}
pca.plot(dat,factor(anno$Matrix))
# Out:
# plot without title

# %%
pca.plot(dat,factor(anno$group))
# Out:
# plot without title

# %%
exp = combat_edata1

cg=names(tail(sort(apply(exp,1,sd)),5000))
n=exp[cg,]

library(pheatmap)

forplot = na.omit(n)
#da=log2(data1+1)
dat=t(scale(t(forplot))) # 'scale'可以对log(fpkm+1)数值进行归一化
#处理数据
dat[dat>2]=2
dat[dat<(-2)]= -2
dim(dat)
dat = dat[complete.cases(dat), ]
# Out:
# [1] 5000  119

# %%
pheatmap(dat,
         cluster_rows = TRUE,
         cluster_cols = TRUE,
         show_rownames=FALSE,
         show_colnames = FALSE,
          scale="none",
          #cluster_cols = F,
          fontsize_row = 10,
          fontsize_col = 10,
         annotation_col = anno,
          #color = colorRampPalette(c("navy", "white", "firebrick3"))(100),
          color = colorRampPalette(c("#00BCB6", "white", "#FE4300"))(100)#换颜色
         # angle_col = 45 #修改横轴坐标名倾斜度
)
# Out:
# plot without title

# %%
diff = read.table('./gene16.txt',header =F,sep = '\t',check.names =  F)

# %%
colnames(diff) = 'genename'

# %%
.libPaths(c('/root/miniconda3/envs/metadoc/lib/R/library','/root/miniconda3/envs/Rdoc/lib/R/library'))

# %%
library(HGNChelper)
# expression_matrix_file是一个行为基因，列为样本的基因表达矩阵
mtx <- as.data.frame(combat_edata1)
dim(mtx)
# check gene symtol
t <- checkGeneSymbols(rownames(mtx))
table(t$Approved)
table(is.na(t$Suggested.Symbol))

# delete <NA> and duplicated Suggested.Symbol
mtx$Suggested.Symbol <- t$Suggested.Symbol
mtx <- mtx[!is.na(mtx$Suggested.Symbol), ]
mtx <- mtx[!duplicated(mtx$Suggested.Symbol), ]
# delete multiple Suggested.Symbol
mtx <- mtx[!grepl("///", mtx$Suggested.Symbol), ]

# reset rownames
rownames(mtx) <- mtx$Suggested.Symbol
# delete Suggested.Symbol columns
mtx <- subset(mtx, select = -c(Suggested.Symbol))
dim(mtx)
# Out:
# [1] 28056   119
# Maps last updated on: Fri May 17 15:09:37 2024
#
# Warning message in checkGeneSymbols(rownames(mtx)):
# "Human gene symbols should be all upper-case except for the 'orf' in open reading frames. The case of some letters was corrected."
# Warning message in checkGeneSymbols(rownames(mtx)):
# "x contains non-approved gene symbols"
# FALSE  TRUE
#  6352 21704
# FALSE  TRUE
# 23332  4724
# [1] 23241   119

# %%
expr = combat_edata1[diff$genename,] %>% t() %>%  as.data.frame()

# %%
#expr = mtx[diff$genename,] %>% t() %>%  as.data.frame()

# %%
grep('MAR',rownames(mtx),value = T)
# Out:
#  [1] "MARCHF10"   "MARCHF11"   "MARCHF3"    "MARCHF4"    "MARCHF5"
#  [6] "MARCHF6"    "MARCHF7"    "MARCHF8"    "MARCHF9"    "ERMARD"
# [11] "MARF1"      "MARCKS"     "MARCKSL1"   "MARCKSL1P1" "MARCKSL1P2"
# [16] "MARCO"      "MARK1"      "MARK2"      "MARK2P13"   "MARK2P6"
# [21] "MARK2P9"    "MARK3"      "MARK4"      "MARS1"      "MARS2"
# [26] "MARVELD1"   "MARVELD2"   "MARVELD3"   "SETMAR"     "SIGMAR1"
# [31] "SMARCA1"    "SMARCA2"    "SMARCA4"    "SMARCA5"    "SMARCAD1"
# [36] "SMARCAL1"   "SMARCB1"    "SMARCC1"    "SMARCC2"    "SMARCD1"
# [41] "SMARCD2"    "SMARCD3"    "SMARCE1"    "SMARCE1P1"  "SMARCE1P5"
# [46] "SMARCE1P6"

# %%
library(dplyr)

# %%
Type =  c(rep(1,43),rep(0,42),rep(1,16),rep(0,18))

# %%
head(expr,2)
# Out:
#         ITGA2B   RASD2       MSLN        SEC14L5   OTOF      GAD1
# CI10_M1 2.014364 0.001520324 0.001604972 0.1785623 0.6439801 -0.001133514
# CI11_M1 5.547279 0.001520324 0.001604972 0.3335119 0.1319284  0.015039617
#         MAP1B      POU2F3       SAMD14    IGF2       SCGB1C1    PLXNB3
# CI10_M1 0.04297155 0.0003358557 0.1074810 0.01531470 1.37707736 -0.0008865713
# CI11_M1 0.05555645 0.0122994827 0.4015254 0.08084769 0.08504677  0.0161659861
#         RNF208     HBE1       HIST1H3F CTAGE6
# CI10_M1 0.06803851 0.13897265 3.334643 0.0227968494
# CI11_M1 0.24235892 0.06789091 2.322905 0.0001278669

# %%
save(expr,Type,file = 'expr.rda')

# %%
data1 = data %>% tibble::rownames_to_column(.,'GENE')

# %%
save(mtx,Type,file = 'merged.rda')
