# %%
setwd('/import/liujing/data/')

# %%
data1 = read.table('./train.txt',header =T,sep = '\t',check.names =  F)

# %%
diff = read.table('./gene16.txt',header =T,sep = '\t',check.names =  F)

# %%
colnames(diff) = 'genename'

# %%
library(dplyr)

# %%
expr = data1 %>%  dplyr::filter(Gene_name %in% diff$genename) %>%  tibble::column_to_rownames(.,'Gene_name') %>%
t() %>%  as.data.frame()

# %%
Type = c(rep(1,43),rep(0,42))

# %%
head(expr,2)
# Out:
#      RASD2 HIST1H3F  RNF208     SCGB1C1    OTOF       HBE1       PLXNB3
# CI10 0     1.3921480 0.09467906 1.50519941 0.49365196 0.11739793 0.00000000
# CI11 0     0.7352132 0.26250718 0.09936467 0.08147021 0.04649964 0.01802448
#      CTAGE6    SAMD14    IGF2       MAP1B      POU2F3     MSLN SEC14L5
# CI10 0.0207292 0.1309934 0.03873173 0.04709211 0.00000000 0    0.2003214
# CI11 0.0000000 0.4272851 0.08591007 0.06104459 0.01288974 0    0.3702741
#      GAD1
# CI10 0.00000000
# CI11 0.01558827

# %%
save(expr,Type,file = 'expr.rda')

# %% [markdown]
# ### 差异分析

# %%
count = read.table('../exp.count.txt',header =T,sep = '\t')

# %%
colnames(count) = gsub('_count','',colnames(count))

# %%
count = count[!duplicated(count$GeneName),]

# %%
rownames(count) = count[,1]
count = count[,-1]

# %%
count = count %>% dplyr::select(rownames(expr))

# %%
head(count,2)
# Out:
#        CI10 CI11 CI12 CI13 CI14 CI15 CI16 CI17 CI18 CI19 ... H42 H43 H44 H45
# TSPAN6   5    0    4    1    9    8    6    1    1    2  ...   2   3   3   2
# DPM1   477  376  211  228  595  341  250  410  444  388  ... 181 219 228 330
#        H46 H4  H5  H7  H8  H9
# TSPAN6   0   0   7   8   5   4
# DPM1   348 185 247 172 251 232

# %%
type = c(rep('CI',43),rep('H',42))

# %%
exprSet_by_group <-count
group_list <- type

# %%
data = exprSet_by_group

# %%
group_list = factor(group_list)
design <- model.matrix(~0+group_list)
rownames(design) = colnames(data)
colnames(design) <- levels(group_list)

# %%
library(limma)
library(edgeR)

# %%
DGElist <- DGEList( counts = data, group = group_list )
keep_gene <- rowSums( cpm(DGElist) > 5 ) >= 5 # 自定义
table(keep_gene)
DGElist <- DGElist[ keep_gene, , keep.lib.sizes = FALSE ]

DGElist <- calcNormFactors( DGElist )
v <- voom(DGElist, design, plot = TRUE, normalize = "quantile")
fit <- lmFit(v, design)
cont.matrix <- makeContrasts(contrasts = c('CI-H'), levels = design)

fit2 <- contrasts.fit(fit, cont.matrix)
fit2 <- eBayes(fit2)

nrDEG_limma_voom = topTable(fit2, coef = 'CI-H', n = Inf)
nrDEG_limma_voom = na.omit(nrDEG_limma_voom)
head(nrDEG_limma_voom)
# Out:
# keep_gene
# FALSE  TRUE
#  7077 11300
#         logFC      AveExpr  t         P.Value      adj.P.Val    B
# ZMYM5    0.4847037 5.206244  8.776103 1.247021e-13 1.124413e-09 20.61537
# LRIF1    0.5264861 5.354336  8.662539 2.131821e-13 1.124413e-09 20.10192
# ANAPC13  0.7142260 5.198104  8.568298 3.325733e-13 1.124413e-09 19.66967
# KHNYN   -0.2721883 7.246492 -8.530210 3.980224e-13 1.124413e-09 19.50377
# RABEP2  -0.5296264 4.298057 -8.165504 2.216060e-12 5.008295e-09 17.81613
# OSBPL7  -0.6483906 4.770332 -8.010101 4.595384e-12 5.984078e-09 17.13249
# Plot with title "voom: Mean-variance trend"

# %%
padj = 0.05 # 自定义
foldChange= 1 # 自定义
nrDEG_limma_voom_signif = nrDEG_limma_voom[(nrDEG_limma_voom$adj.P.Val < padj & 
                          (nrDEG_limma_voom$logFC>foldChange | nrDEG_limma_voom$logFC<(-foldChange))),]
nrDEG_limma_voom_signif = nrDEG_limma_voom_signif[order(nrDEG_limma_voom_signif$logFC),]

# %%
dim(nrDEG_limma_voom_signif)
# Out:
# [1] 19  6

# %%
write.csv(nrDEG_limma_voom_signif,file = 'nrDEG_limma_voom_signif.csv')

# %%
data1 = read.table('./train.txt',header =T,sep = '\t',check.names = F)

# %%
data1 = data1[!duplicated(data1$Gene_name),]

# %%
expr2 = data1 %>%  dplyr::filter(Gene_name %in% rownames(nrDEG_limma_voom_signif)) %>%  tibble::column_to_rownames(.,'Gene_name') %>%
t() %>%  as.data.frame()

# %%
expr2 = expr2 %>% dplyr::select(-starts_with("2"))

# %%
save(expr2,Type,file = 'expr2.rda')

# %%
dim(expr2)
# Out:
# [1] 85 19

# %%
colnames(expr2)
# Out:
#  [1] "HIST1H3F" "PPDPF"    "ITGA2B"   "CLDN5"    "MYRF"     "HBQ1"
#  [7] "ITGB3"    "GP9"      "SLC25A39" "IL23R"    "PLEKHH2"  "MPL"
# [13] "PTCRA"    "GATA1"    "SEC14L5"  "CRIP1"    "AQP10"    "ZNF208"
# [19] "MT-ND6"

# %%
nrDEG_limma_voom['CCNA2',]
# Out:
#       logFC     AveExpr  t        P.Value      adj.P.Val    B
# CCNA2 0.8214306 1.802323 6.115067 2.637721e-08 1.216581e-06 8.558415
