# %%
setwd('/import/liujing/data/my')

# %%
library("enrichR")
# Out:
# Welcome to enrichR
# Checking connection ...
#
# Enrichr ...
# Connection is Live!
#
# FlyEnrichr ...
# Connection is Live!
#
# WormEnrichr ...
# Connection is Live!
#
# YeastEnrichr ...
# Connection is Live!
#
# FishEnrichr ...
# Connection is Live!
#
# OxEnrichr ...
# Connection is Live!

# %%
websiteLive <- getOption("enrichR.live")
if (websiteLive) {
    listEnrichrSites()
    setEnrichrSite("Enrichr") # Human genes   
}
# Out:
# Enrichr ...
# Connection is Live!
#
# FlyEnrichr ...
# Connection is Live!
#
# WormEnrichr ...
# Connection is Live!
#
# YeastEnrichr ...
# Connection is Live!
#
# FishEnrichr ...
# Connection is Live!
#
# OxEnrichr ...
# Connection is Live!
#
# Connection changed to https://maayanlab.cloud/Enrichr/
#
# Connection is Live!

# %%
if (websiteLive) dbs <- listEnrichrDbs()

# %%
dbs <- c("DSigDB")
if (websiteLive) {
    enriched <- enrichr(c('TNFSF14','CCNA2','SGO1','SAP130','MARCKS'), dbs)
}
# Out:
# Uploading data to Enrichr... Done.
#   Querying DSigDB... Done.
# Parsing results... Done.

# %%
write.csv(enriched$DSigDB,file = 'target.dsig.csv')

# %%
if (websiteLive) {
    plotEnrich(enriched[[1]], showTerms = 10, numChar = 40, y = "Genes", orderBy = "P.value")+ theme(text=element_text(size= 13 ))
}
# Out:
# plot without title

# %%
library(ggplot2)

# %%
ggsave('./drug.pdf',width = 6,height = 6)

# %%
if (websiteLive) dbs <- listEnrichrDbs()
