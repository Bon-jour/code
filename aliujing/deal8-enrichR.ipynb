# %%
setwd('/import/liujing/data2/')

# %%
library("enrichR")
# Out:
# Welcome to enrichR
# Checking connection ...
#
# Enrichr ...
# Connection is Live!
#
# FlyEnrichr ...
# Connection is Live!
#
# WormEnrichr ...
# Connection is Live!
#
# YeastEnrichr ...
# Connection is Live!
#
# FishEnrichr ...
# Connection is Live!
#
# OxEnrichr ...
# Connection is Live!

# %%
websiteLive <- getOption("enrichR.live")
if (websiteLive) {
    listEnrichrSites()
    setEnrichrSite("Enrichr") # Human genes   
}
# Out:
# Enrichr ...
# Connection is Live!
#
# FlyEnrichr ...
# Connection is Live!
#
# WormEnrichr ...
# Connection is Live!
#
# YeastEnrichr ...
# Connection is Live!
#
# FishEnrichr ...
# Connection is Live!
#
# OxEnrichr ...
# Connection is Live!
#
# Connection changed to https://maayanlab.cloud/Enrichr/
#
# Connection is Live!

# %%
if (websiteLive) dbs <- listEnrichrDbs()

# %%
dbs <- c("DSigDB")
if (websiteLive) {
    enriched <- enrichr(c('FAM200B','BCL2A1','IGJ','TXN'), dbs)
}
# Out:
# Uploading data to Enrichr... Done.
#   Querying DSigDB... Done.
# Parsing results... Done.

# %%
write.csv(enriched$DSigDB,file = 'target.dsig.csv')

# %%
enriched$DSigDB
# Out:
#     Term                                      Overlap P.value
# 1   PARAQUAT CTD 00006471                     2/213   0.0006678648
# 2   indomethacin CTD 00006147                 2/335   0.0016413680
# 3   Vorinostat CTD 00003560                   2/425   0.0026274567
# 4   SODIUM CHROMATE CTD 00001363              1/14    0.0027972247
# 5   DIOSGENIN CTD 00005850                    1/15    0.0029968028
# 6   Diphenylcyclopropenone CTD 00001385       1/18    0.0035953576
# 7   selegiline CTD 00006730                   1/19    0.0037948161
# 8   cytochalasin D CTD 00007076               1/20    0.0039942447
# 9   salicylic acid CTD 00007355               1/20    0.0039942447
# 10  Manumycin A CTD 00002318                  1/20    0.0039942447
# 11  acetate TTD 00001564                      1/21    0.0041936434
# 12  gambogic acid CTD 00002247                1/22    0.0043930122
# 13  HYPOCHLOROUS ACID BOSS                    1/22    0.0043930122
# ...

# %%
library(ggplot2)
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 4.2.3"

# %%
if (websiteLive) {
    plotEnrich(enriched[[1]], showTerms = 10, numChar = 40, y = "Genes", orderBy = "P.value")+ theme(text=element_text(size= 13 ))
}
# Out:
# plot without title

# %%
library(ggplot2)

# %%
ggsave('./drug.pdf',width = 6,height = 6)

# %%
if (websiteLive) dbs <- listEnrichrDbs()
