# %%
setwd('/import/DB/zhang//data')
library(Seurat)

# %%
SCE = readRDS('Mye.final.rds')

# %%
Idents(SCE) ='celltype'

# %%
table(SCE$group,SCE$celltype)
# Out:
#
#           M1_mac M2_mac  OCs TAM1 TAM2 cDC1 cDC2 prof mac
#   OS        1697   4102  516 2124  732  158 2165      317
#   control    664    443   68    8  301  135  561       27

# %%
unique(SCE$celltype)
# Out:
# [1] "M2_mac"   "OCs"      "TAM2"     "cDC2"     "cDC1"     "M1_mac"   "prof mac"
# [8] "TAM1"

# %%
Idents(SCE) = 'celltype'

# %%
scRNA = subset(SCE,idents = c('M2_mac','TAM2','M1_mac','TAM1'))

# %%
scRNA$cells = paste0(scRNA$group,'_',scRNA$celltype)

# %%
table(scRNA$cells)
# Out:
#      OS_M1_mac      OS_M2_mac        OS_TAM1        OS_TAM2 control_M1_mac
#           1697           4102           2124            732            664
# control_M2_mac   control_TAM1   control_TAM2
#            443              8            301

# %%
Idents(scRNA) = 'cells'

# %%
scRNA$cells = factor(scRNA$cells,levels = c('control_M1_mac','OS_M1_mac','control_M2_mac','OS_M2_mac',
                                           'control_TAM1','OS_TAM1','control_TAM2','OS_TAM2'))

# %%
Idents(scRNA) = 'cells'
DefaultAssay(scRNA) = 'RNA'
sce.markers <- FindAllMarkers(object = scRNA, only.pos = TRUE, 
                              min.pct = 0.25, 
                              thresh.use = 0.25)
 

# library(dplyr) 
# # 不同seurat版本的 avg_logFC 不一样 
# top5 <- sce.markers %>% group_by(cluster) %>% top_n(5, avg_log2FC)
# Out:
# Calculating cluster control_M1_mac
#
# Calculating cluster OS_M1_mac
#
# Calculating cluster control_M2_mac
#
# Calculating cluster OS_M2_mac
#
# Calculating cluster control_TAM1
#
# Calculating cluster OS_TAM1
#
# Calculating cluster control_TAM2
#
# Calculating cluster OS_TAM2

# %%
library(dplyr) 
# 不同seurat版本的 avg_logFC 不一样 
top5 <- sce.markers %>% group_by(cluster) %>% top_n(5, avg_log2FC)

# %%
gene_cell_exp <- AverageExpression(scRNA,
                                   features = unique(top5$gene),
                                   group.by = 'cells',
                                   slot = 'data') 
gene_cell_exp <- as.data.frame(gene_cell_exp$RNA)

# %%
colnames(gene_cell_exp)
# Out:
# [1] "control_M1_mac" "OS_M1_mac"      "control_M2_mac" "OS_M2_mac"
# [5] "control_TAM1"   "OS_TAM1"        "control_TAM2"   "OS_TAM2"

# %%
gene_cell_exp = gene_cell_exp[,c('control_M1_mac','OS_M1_mac','control_M2_mac','OS_M2_mac',
                                           'control_TAM1','OS_TAM1','control_TAM2','OS_TAM2')]

# %%
library(ComplexHeatmap)
#顶部细胞类型注释
df <- data.frame(colnames(gene_cell_exp))
colnames(df) <- 'class'

# %%
df$class = factor(df$class,levels = c('control_M1_mac','OS_M1_mac','control_M2_mac','OS_M2_mac',
                                           'control_TAM1','OS_TAM1','control_TAM2','OS_TAM2'))

# %%
top_anno = HeatmapAnnotation(df = df,#细胞名/cluster
                             border = T,
                             show_annotation_name = F,
                             gp = gpar(col = 'black'),
                             col = list(class = c('control_M1_mac' = '#4DAF4A','OS_M1_mac'="#2F528F",
                                        'control_M2_mac' = '#FCCDE5','OS_M2_mac'="#D9D9D9",
                             'control_TAM1' = '#377EB8','OS_TAM1'="#7FC97F",
                                   'control_TAM2' = '#BEAED4','OS_TAM2'="#D95F02")
                                       
                                       
                                       ))#颜色设置

# %%
#数据标准化缩放一下
marker_exp <- t(scale(t(gene_cell_exp),scale = T,center = T))

# %%
Heatmap(marker_exp,
        cluster_rows = F,
        cluster_columns = F,
        show_column_names = F,
        show_row_names = T,
        column_title = NULL,
        heatmap_legend_param = list(
          title=' '),
        col = colorRampPalette(c("#0D72C3","white","#E35B10"))(100),
        border = 'black',
        rect_gp = gpar(col = "black", lwd = 1),
        row_names_gp = gpar(fontsize = 13),
        column_names_gp = gpar(fontsize = 13),
        top_annotation = top_anno)
# Out:
# plot without title

# %%
library(GSVA)
library(tidyverse)
library(org.Hs.eg.db)
Idents(scRNA) <- "cells" 
expr <- AverageExpression(scRNA, assays = "RNA", slot = "data")[[1]]
expr <- expr[rowSums(expr)>0,]  #过滤细胞表达量全为零的基因
expr <- as.matrix(expr)
# library(msigdbr)
# msigdbr_species() #列出有的物种

# %%
d = '/import/DB' 
gmtfs <- list.files(d,pattern = '.gmt')  # 路径下所有结尾为symbols.gmt文件
gmtfs
library(GSEABase)
kegg_list <- getGmt(file.path(d,gmtfs[3])) 
go_list <- getGmt(file.path(d,gmtfs[1])) 
hall_list <- getGmt(file.path(d,gmtfs[2]))
# Out:
# [1] "BP.gmt"                   "h.all.v7.5.1.symbols.gmt"
# [3] "kegg.gmt"
# Warning message in getGmt(file.path(d, gmtfs[1])):
# "2 record(s) contain duplicate ids: GOBP_CIRCULATORY_SYSTEM_DEVELOPMENT, GOBP_PROTEOLYSIS_INVOLVED_IN_PROTEIN_CATABOLIC_PROCESS"

# %%
human_KEGG_Set = hall_list
# #选择基因集合
# human_KEGG = msigdbr(species = "Homo sapiens", #物种
#                       category = "C2",
#                      subcategory = "KEGG") %>% 
#   dplyr::select(gs_name,gene_symbol)#这里可以选择gene symbol或者ID
# human_KEGG_Set = human_KEGG %>% split(x = .$gene_symbol, f = .$gs_name)

library(GSVA)
gsva.kegg <- gsva(expr, gset.idx.list = human_KEGG_Set, 
             kcdf="Gaussian",
             method = "gsva",
             parallel.sz=1)
head(gsva.kegg)

dim(gsva.kegg)

a = c()
ds = as.data.frame(gsva.kegg) 
for (i in 1:dim(ds)[2] ){
    path = ds[ order (-ds[,i]),] %>%  head(8) %>%  rownames()
    a = unique(c(a,path))
 }
gsva.kegg = gsva.kegg[a,]
options(repr.plot.width = 9,repr.plot.height =  8)
rownames(gsva.kegg) = gsub('HALLMARK_','',rownames(gsva.kegg))

rownames(gsva.kegg)= tolower(rownames(gsva.kegg))
# Out:
# Warning message:
# "useNames = NA is deprecated. Instead, specify either useNames = TRUE or useNames = TRUE."
# Estimating GSVA scores for 50 gene sets.
# Estimating ECDFs with Gaussian kernels
#   |======================================================================| 100%
#                              control_M1_mac OS_M1_mac   control_M2_mac
# HALLMARK_ADIPOGENESIS        -0.06928547    -0.23766854 -0.420116141
# HALLMARK_ALLOGRAFT_REJECTION -0.06675384    -0.10733005  0.098741210
# HALLMARK_ANDROGEN_RESPONSE   -0.24753964     0.04319155  0.139528939
# HALLMARK_ANGIOGENESIS        -0.41552121     0.15785814 -0.125152656
# HALLMARK_APICAL_JUNCTION     -0.06573537     0.03123012 -0.008438962
# HALLMARK_APICAL_SURFACE       0.17040468     0.26744730  0.198558958
#                              OS_M2_mac  control_TAM1 OS_TAM1     control_TAM2
# HALLMARK_ADIPOGENESIS        -0.4201032 0.24389989   -0.16373320  0.22158514
# HALLMARK_ALLOGRAFT_REJECTION -0.3834816 0.15177233   -0.44177838  0.31079943
# HALLMARK_ANDROGEN_RESPONSE   -0.2024344 0.09583968   -0.10057558  0.02932405
# HALLMARK_ANGIOGENESIS        -0.2990904 0.40782073    0.01379619 -0.08399081
# HALLMARK_APICAL_JUNCTION     -0.1185526 0.02610093   -0.28228930  0.18941464
# HALLMARK_APICAL_SURFACE      -0.1831457 0.07014124   -0.13585050 -0.06048589
#                              OS_TAM2
# HALLMARK_ADIPOGENESIS        -0.082698232
# HALLMARK_ALLOGRAFT_REJECTION -0.297518554
# HALLMARK_ANDROGEN_RESPONSE   -0.337066127
# HALLMARK_ANGIOGENESIS         0.143871408
# HALLMARK_APICAL_JUNCTION      0.008229795
# HALLMARK_APICAL_SURFACE      -0.189744408
# [1] 50  8

# %%
options(repr.plot.width = 8,repr.plot.height = 9)

# %%
library(pheatmap)
p = pheatmap(as.matrix(gsva.kegg), scale = "row",angle_col = "45",cluster_cols  = FALSE,cluster_rows = FALSE,
        
        show_column_names = F,
        show_row_names = T,
         color = colorRampPalette(c("navy", "white", "firebrick3"))(100))
# Out:
# plot without title

# %% [markdown]
# ### kegg

# %%
#human_KEGG_Set = kegg_list

library(msigdbr)

# #选择基因集合
human_KEGG = msigdbr(species = "Homo sapiens", #物种
                      category = "C2",
                     subcategory = "KEGG") %>% 
  dplyr::select(gs_name,gene_symbol)#这里可以选择gene symbol或者ID
human_KEGG_Set = human_KEGG %>% split(x = .$gene_symbol, f = .$gs_name)

library(GSVA)
gsva.kegg <- gsva(expr, gset.idx.list = human_KEGG_Set, 
             kcdf="Gaussian",
             method = "gsva",
             parallel.sz=1)
head(gsva.kegg)

dim(gsva.kegg)

a = c()
ds = as.data.frame(gsva.kegg) 
for (i in 1:dim(ds)[2] ){
    path = ds[ order (-ds[,i]),] %>%  head(10) %>%  rownames()
    a = unique(c(a,path))
 }
gsva.kegg = gsva.kegg[a,]
options(repr.plot.width = 9,repr.plot.height =  8)
rownames(gsva.kegg) = gsub('KEGG_','',rownames(gsva.kegg))

rownames(gsva.kegg)= tolower(rownames(gsva.kegg))
# Out:
# Warning message:
# "useNames = NA is deprecated. Instead, specify either useNames = TRUE or useNames = TRUE."
# Estimating GSVA scores for 186 gene sets.
# Estimating ECDFs with Gaussian kernels
#   |======================================================================| 100%
#                                                 control_M1_mac OS_M1_mac
# KEGG_ABC_TRANSPORTERS                           -0.388868155   -0.52535981
# KEGG_ACUTE_MYELOID_LEUKEMIA                     -0.007087999    0.16030092
# KEGG_ADHERENS_JUNCTION                          -0.314515219   -0.03495613
# KEGG_ADIPOCYTOKINE_SIGNALING_PATHWAY            -0.033080156    0.02187189
# KEGG_ALANINE_ASPARTATE_AND_GLUTAMATE_METABOLISM -0.099034274   -0.13209178
# KEGG_ALDOSTERONE_REGULATED_SODIUM_REABSORPTION  -0.159167532    0.20380427
#                                                 control_M2_mac OS_M2_mac
# KEGG_ABC_TRANSPORTERS                           -0.35332426    -0.3023411
# KEGG_ACUTE_MYELOID_LEUKEMIA                      0.15143677    -0.4243597
# KEGG_ADHERENS_JUNCTION                          -0.26607715    -0.4700266
# KEGG_ADIPOCYTOKINE_SIGNALING_PATHWAY            -0.11670731    -0.5180627
# KEGG_ALANINE_ASPARTATE_AND_GLUTAMATE_METABOLISM  0.05570394     0.1312484
# KEGG_ALDOSTERONE_REGULATED_SODIUM_REABSORPTION   0.55480142     0.1354397
#                                                 control_TAM1 OS_TAM1
# KEGG_ABC_TRANSPORTERS                           -0.31056784  -0.3916426
# KEGG_ACUTE_MYELOID_LEUKEMIA                      0.04373607  -0.4154390
# KEGG_ADHERENS_JUNCTION                           0.16363082  -0.3562772
# KEGG_ADIPOCYTOKINE_SIGNALING_PATHWAY            -0.31860307  -0.4580981
# KEGG_ALANINE_ASPARTATE_AND_GLUTAMATE_METABOLISM  0.05132316   0.0871793
# KEGG_ALDOSTERONE_REGULATED_SODIUM_REABSORPTION   0.13523240  -0.2846840
#                                                 control_TAM2 OS_TAM2
# KEGG_ABC_TRANSPORTERS                           -0.33110483  -0.1213125
# KEGG_ACUTE_MYELOID_LEUKEMIA                     -0.21999294  -0.3586572
# KEGG_ADHERENS_JUNCTION                          -0.07062663  -0.3351100
# KEGG_ADIPOCYTOKINE_SIGNALING_PATHWAY            -0.24079312  -0.4447559
# KEGG_ALANINE_ASPARTATE_AND_GLUTAMATE_METABOLISM -0.25069080   0.2261254
# KEGG_ALDOSTERONE_REGULATED_SODIUM_REABSORPTION  -0.32131731  -0.3787698
# [1] 186   8

# %%
options(repr.plot.width = 8,repr.plot.height = 12)

# %%
library(pheatmap)
p = pheatmap(as.matrix(gsva.kegg), scale = "row",angle_col = "45",cluster_cols  = FALSE,cluster_rows = FALSE,
        show_column_names = F,
        show_row_names = T,
         color = colorRampPalette(c("navy", "white", "firebrick3"))(100))
# Out:
# plot without title
