# %%
mmu_kegg_compound <- read.csv('/data/workdirV6//KEGG_COMPOUND_PATHWAY_mmu.csv')

disease2gene=mmu_kegg_compound[, c("Pathway", "COMPOUND")]

disease2name=mmu_kegg_compound[, c("Pathway", "PATHWAY_MAP")]

cnumber = read.csv('/data/workdirV6/cnumber.csv',check.names = F,row.names = 1)

# %%
kind = read.csv('./allmetebolit.kind.wtclp.csv')

# %%
kind = na.omit(cnumber[kind[,2],])
library(clusterProfiler)
x = enricher(kind, TERM2GENE=disease2gene, TERM2NAME=disease2name)
x@result$p.adjust	= x@result$pvalue
library(ggplot2)
dotplot(x, font.size=15, showCategory=10, title="Enrichment KEGG Top10") + scale_size(rang=c(5.20))
# Out:
# Warning message:
# “package ‘clusterProfiler’ was built under R version 4.2.2”
#
#
# Registered S3 methods overwritten by 'treeio':
#   method              from
#   MRCA.phylo          tidytree
#   MRCA.treedata       tidytree
#   Nnode.treedata      tidytree
#   Ntip.treedata       tidytree
#   ancestor.phylo      tidytree
#   ancestor.treedata   tidytree
#   child.phylo         tidytree
#   child.treedata      tidytree
#   full_join.phylo     tidytree
#   full_join.treedata  tidytree
#   groupClade.phylo    tidytree
#   groupClade.treedata tidytree
#   groupOTU.phylo      tidytree
#   groupOTU.treedata   tidytree
#   is.rooted.treedata  tidytree
#   nodeid.phylo        tidytree
#   nodeid.treedata     tidytree
#   nodelab.phylo       tidytree
#   nodelab.treedata    tidytree
#   offspring.phylo     tidytree
#   offspring.treedata  tidytree
#   parent.phylo        tidytree
#   parent.treedata     tidytree
#   root.treedata       tidytree
#   rootnode.phylo      tidytree
#   sibling.phylo       tidytree
#
# clusterProfiler v4.6.0  For help: https://yulab-smu.top/biomedical-knowledge-mining-book/
#
# If you use clusterProfiler in published research, please cite:
# T Wu, E Hu, S Xu, M Chen, P Guo, Z Dai, T Feng, L Zhou, W Tang, L Zhan, X Fu, S Liu, X Bo, and G Yu. clusterProfiler 4.0: A universal enrichment tool for interpreting omics data. The Innovation. 2021, 2(3):100141
#
#
# Attaching package: ‘clusterProfiler’
#
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
#
# Warning message:
# “package ‘ggplot2’ was built under R version 4.2.3”
# Scale for size is already present.
# Adding another scale for size, which will replace the existing scale.
# plot without title

# %%
bad = read.csv('./allmetebolit.bad.wtclp.csv')

# %%
bad = na.omit(cnumber[bad[,2],])

library(clusterProfiler)

x = enricher(bad, TERM2GENE=disease2gene, TERM2NAME=disease2name)

x@result$p.adjust	= x@result$pvalue

library(ggplot2)

dotplot(x, font.size=15, showCategory=10, title="Enrichment KEGG Top10") + scale_size(rang=c(5.20))
# Out:
# Scale for size is already present.
# Adding another scale for size, which will replace the existing scale.
# plot without title

# %%
all = read.csv('./all.conectwith.otu.wtclp.csv')

# %%
all = na.omit(cnumber[all[,2],])

library(clusterProfiler)

x = enricher(all, TERM2GENE=disease2gene, TERM2NAME=disease2name)

x@result$p.adjust	= x@result$pvalue

library(ggplot2)

dotplot(x, font.size=15, showCategory=10, title="Enrichment KEGG Top10") + scale_size(rang=c(5.20))
# Out:
# Scale for size is already present.
# Adding another scale for size, which will replace the existing scale.
# plot without title

# %%
x@result
# Out:
#          ID       Description                                         GeneRatio
# mmu00590 mmu00590 Arachidonic acid metabolism                         25/233
# mmu00350 mmu00350 Tyrosine metabolism                                 16/233
# mmu04974 mmu04974 Protein digestion and absorption                    12/233
# mmu04726 mmu04726 Serotonergic synapse                                11/233
# mmu00260 mmu00260 Glycine, serine and threonine metabolism            10/233
# mmu04080 mmu04080 Neuroactive ligand-receptor interaction             10/233
# mmu00240 mmu00240 Pyrimidine metabolism                               11/233
# mmu00770 mmu00770 Pantothenate and CoA biosynthesis                   7/233
# mmu00140 mmu00140 Steroid hormone biosynthesis                        14/233
# mmu00400 mmu00400 Phenylalanine, tyrosine and tryptophan biosynthesis 7/233
# mmu00410 mmu00410 beta-Alanine metabolism                             6/233
# mmu00620 mmu00620 Pyruvate metabolism                                 6/233
# mmu04913 mmu04913 Ovarian steroidogenesis                             5/233
# mmu01040 mmu01040 Biosynthesis of unsaturated fatty acids             10/233
# mmu00982 mmu00982 Drug metabolism - cytochrome P450                   12/233
# mmu05230 mmu05230 Central carbon metabolism in cancer                 6/233
# mmu00591 mmu00591 Linoleic acid metabolism                            5/233
# mmu00360 mmu00360 Phenylalanine metabolism                            7/233
# mmu04971 mmu04971 Gastric acid secretion                              3/233
# mmu00290 mmu00290 Valine, leucine and isoleucine biosynthesis         4/233
# mmu04714 mmu04714 Thermogenesis                                       4/233
# mmu00592 mmu00592 alpha-Linolenic acid metabolism                     6/233
# mmu02010 mmu02010 ABC transporters                                    14/233
# mmu00564 mmu00564 Glycerophospholipid metabolism                      7/233
# mmu04750 mmu04750 Inflammatory mediator regulation of TRP channels    5/233
# mmu00830 mmu00830 Retinol metabolism                                  4/233
# mmu00330 mmu00330 Arginine and proline metabolism                     8/233
# mmu00470 mmu00470 D-Amino acid metabolism                             8/233
# mmu04270 mmu04270 Vascular smooth muscle contraction                  3/233
# mmu04977 mmu04977 Vitamin digestion and absorption                    5/233
# ⋮        ⋮        ⋮                                                   ⋮
# mmu04924 mmu04924 Renin secretion                                     1/233
# mmu00760 mmu00760 Nicotinate and nicotinamide metabolism              3/233
# mmu00910 mmu00910 Nitrogen metabolism                                 1/233
# mmu05415 mmu05415 Diabetic cardiomyopathy                             2/233
# mmu00040 mmu00040 Pentose and glucuronate interconversions            3/233
# mmu04918 mmu04918 Thyroid hormone synthesis                           1/233
# mmu00640 mmu00640 Propanoate metabolism                               2/233
# mmu00983 mmu00983 Drug metabolism - other enzymes                     3/233
# mmu00785 mmu00785 Lipoic acid metabolism                              2/233
# mmu00630 mmu00630 Glyoxylate and dicarboxylate metabolism             3/233
# mmu00430 mmu00430 Taurine and hypotaurine metabolism                  1/233
# mmu00900 mmu00900 Terpenoid backbone biosynthesis                     2/233
# mmu04976 mmu04976 Bile secretion                                      9/233
# mmu00650 mmu00650 Butanoate metabolism                                2/233
# mmu00531 mmu00531 Glycosaminoglycan degradation                       1/233
# mmu00730 mmu00730 Thiamine metabolism                                 1/233
# mmu04216 mmu04216 Ferroptosis                                         1/233
# mmu05022 mmu05022 Pathways of neurodegeneration - multiple diseases   1/233
# mmu00520 mmu00520 Amino sugar and nucleotide sugar metabolism         5/233
# mmu00030 mmu00030 Pentose phosphate pathway                           1/233
# mmu00500 mmu00500 Starch and sucrose metabolism                       1/233
# mmu00510 mmu00510 N-Glycan biosynthesis                               1/233
# mmu00062 mmu00062 Fatty acid elongation                               1/233
# mmu00562 mmu00562 Inositol phosphate metabolism                       1/233
# mmu00071 mmu00071 Fatty acid degradation                              1/233
# mmu00051 mmu00051 Fructose and mannose metabolism                     1/233
# mmu00440 mmu00440 Phosphonate and phosphinate metabolism              1/233
# mmu00100 mmu00100 Steroid biosynthesis                                1/233
# mmu05208 mmu05208 Chemical carcinogenesis - reactive oxygen species   1/233
# mmu00860 mmu00860 Porphyrin metabolism                                3/233
#          BgRatio  pvalue       p.adjust     qvalue
# mmu00590 79/3531  9.059049e-12 9.059049e-12 1.058478e-09
# mmu00350 78/3531  3.311619e-05 3.311619e-05 1.317071e-03
# mmu04974 47/3531  3.381669e-05 3.381669e-05 1.317071e-03
# mmu04726 42/3531  5.611383e-05 5.611383e-05 1.639115e-03
# mmu00260 48/3531  9.076915e-04 9.076915e-04 2.121132e-02
# mmu04080 53/3531  2.020569e-03 2.020569e-03 3.934793e-02
# mmu00240 64/3531  2.668881e-03 2.668881e-03 3.987580e-02
# mmu00770 30/3531  2.730235e-03 2.730235e-03 3.987580e-02
# mmu00140 99/3531  4.877223e-03 4.877223e-03 6.331833e-02
# mmu00400 35/3531  6.798502e-03 6.798502e-03 7.943513e-02
# mmu00410 32/3531  1.642579e-02 1.642579e-02 1.599353e-01
# mmu00620 32/3531  1.642579e-02 1.642579e-02 1.599353e-01
# mmu04913 24/3531  1.809213e-02 1.809213e-02 1.626094e-01
# mmu01040 74/3531  2.203224e-02 2.203224e-02 1.838781e-01
# mmu00982 100/3531 3.005963e-02 3.005963e-02 2.321065e-01
# mmu05230 37/3531  3.203381e-02 3.203381e-02 2.321065e-01
# mmu00591 28/3531  3.377044e-02 3.377044e-02 2.321065e-01
# mmu00360 49/3531  3.970388e-02 3.970388e-02 2.577269e-01
# mmu04971 14/3531  6.009454e-02 6.009454e-02 3.378947e-01
# mmu00290 23/3531  6.072973e-02 6.072973e-02 3.378947e-01
# mmu04714 23/3531  6.072973e-02 6.072973e-02 3.378947e-01
# mmu00592 44/3531  6.650400e-02 6.650400e-02 3.383273e-01
# mmu02010 139/3531 7.173567e-02 7.173567e-02 3.383273e-01
# mmu00564 56/3531  7.286131e-02 7.286131e-02 3.383273e-01
# mmu04750 35/3531  7.700905e-02 7.700905e-02 3.383273e-01
# mmu00830 25/3531  7.836661e-02 7.836661e-02 3.383273e-01
# mmu00330 69/3531  8.187856e-02 8.187856e-02 3.383273e-01
# mmu00470 69/3531  8.187856e-02 8.187856e-02 3.383273e-01
# mmu04270 16/3531  8.397224e-02 8.397224e-02 3.383273e-01
# mmu04977 39/3531  1.107987e-01 1.107987e-01 4.315317e-01
# ⋮        ⋮        ⋮            ⋮            ⋮
# mmu04924 17/3531  0.6875257    0.6875257    0.8033195
# mmu00760 55/3531  0.7142999    0.7142999    0.8263397
# mmu00910 19/3531  0.7275954    0.7275954    0.8334684
# mmu05415 39/3531  0.7396123    0.7396123    0.8390083
# mmu00040 59/3531  0.7581853    0.7581853    0.8427385
# mmu04918 21/3531  0.7625460    0.7625460    0.8427385
# mmu00640 41/3531  0.7645385    0.7645385    0.8427385
# mmu00983 63/3531  0.7964899    0.7964899    0.8554102
# mmu00785 44/3531  0.7980489    0.7980489    0.8554102
# mmu00630 64/3531  0.8052394    0.8052394    0.8554102
# mmu00430 24/3531  0.8067760    0.8067760    0.8554102
# mmu00900 46/3531  0.8179863    0.8179863    0.8554102
# mmu04976 174/3531 0.8238324    0.8238324    0.8554102
# mmu00650 47/3531  0.8272819    0.8272819    0.8554102
# mmu00531 27/3531  0.8427961    0.8427961    0.8638076
# mmu00730 31/3531  0.8806352    0.8806352    0.8870282
# mmu04216 31/3531  0.8806352    0.8806352    0.8870282
# mmu05022 32/3531  0.8885815    0.8885815    0.8873824
# mmu00520 118/3531 0.8994676    0.8994676    0.8906414
# mmu00030 37/3531  0.9210722    0.9210722    0.8945041
# mmu00500 37/3531  0.9210722    0.9210722    0.8945041
# mmu00510 38/3531  0.9263356    0.9263356    0.8945041
# mmu00062 40/3531  0.9358367    0.9358367    0.8947787
# mmu00562 47/3531  0.9604535    0.9604535    0.8947787
# mmu00071 50/3531  0.9678709    0.9678709    0.8947787
# mmu00051 55/3531  0.9772821    0.9772821    0.8947787
# mmu00440 56/3531  0.9788049    0.9788049    0.8947787
# mmu00100 57/3531  0.9802260    0.9802260    0.8947787
# mmu05208 57/3531  0.9802260    0.9802260    0.8947787
# mmu00860 148/3531 0.9976716    0.9976716    0.9036438
#          geneID
# mmu00590 C14748/C13809/C00157/C05960/C05957/C05959/C05965/C14769/C14811/C04577/C00696/C14775/C05964/C02198/C14810/C14809/C14812/C14814/C14813/C14774/C06315/C04671/C05950/C14823/C14781
# mmu00350 C05580/C06044/C05576/C01179/C06199/C03765/C00483/C05596/C00530/C00082/C05593/C02442/C04185/C05594/C05589/C05585
# mmu04974 C00064/C00049/C00188/C00065/C00388/C00079/C00483/C00246/C02632/C00099/C00082/C18319
# mmu04726 C05957/C05965/C00575/C14769/C00696/C14775/C05964/C02198/C14812/C14774/C14823
# mmu00260 C01102/C00049/C00188/C00300/C00065/C00430/C00581/C03508/C02291/C00441
# mmu04080 C13856/C00049/C00388/C00398/C00483/C00099/C16512/C00696/C02198/C01996
# mmu00240 C00064/C00364/C00526/C00239/C00055/C00178/C00214/C02376/C00099/C00475/C00105
# mmu00770 C00864/C00049/C03492/C05944/C00099/C00054/C00831
# mmu00140 C11133/C01227/C00535/C01953/C00523/C13713/C05487/C05141/C05291/C05485/C05482/C05490/C05477/C05489
# mmu00400 C01179/C00079/C00082/C00074/C00587/C00251/C00441
# mmu00410 C00864/C00049/C03492/C00315/C00099/C05340
# mmu00620 C00424/C01251/C02488/C00074/C02504/C16255
# mmu04913 C01227/C00535/C01953/C00575/C14769
# mmu01040 C08281/C16533/C06427/C06425/C00249/C00712/C01595/C08316/C01530/C16513
# mmu00982 C16658/C16648/C07185/C16655/C07501/C16591/C16650/C16651/C16654/C16587/C11785/C16610
# mmu05230 C00064/C00049/C00065/C00079/C00082/C00074
# mmu00591 C14835/C00157/C04717/C14827/C01595
# mmu00360 C00079/C00082/C05593/C05629/C05852/C00601/C12623
# mmu04971 C00388/C00575/C01996
# mmu00290 C00188/C04236/C06007/C02504
# mmu04714 C13856/C00318/C00745/C00575
# mmu00592 C00157/C06427/C19757/C16322/C11512/C16323
# mmu02010 C00064/C00049/C00188/C00526/C00065/C00079/C00315/C00559/C00430/C00475/C00120/C01606/C00140/C00208
# mmu00564 C00157/C00065/C01210/C03372/C06771/C04230/C01996
# mmu04750 C00388/C09844/C05965/C00575/C14769
# mmu00830 C02075/C16679/C11061/C16682
# mmu00330 C15767/C00300/C00431/C02946/C00315/C05932/C00581/C00441
# mmu00470 C00064/C00049/C00188/C00431/C00065/C00079/C00666/C00402
# mmu04270 C14748/C00575/C14769
# mmu04977 C00864/C00016/C00120/C02075/C05377
# ⋮        ⋮
# mmu04924 C00575
# mmu00760 C00049/C05842/C00745
# mmu00910 C00064
# mmu05415 C00318/C00236
# mmu00040 C03033/C05412/C00199
# mmu04918 C00575
# mmu00640 C00424/C00099
# mmu00983 C07054/C16622/C16616
# mmu00785 C16241/C16255
# mmu00630 C00064/C00065/C01732
# mmu00430 C05844
# mmu00900 C06081/C19691
# mmu04976 C03033/C01921/C00318/C01443/C07185/C00315/C00805/C00575/C01996
# mmu00650 C00246/C02630
# mmu00531 C00634
# mmu00730 C00082
# mmu04216 C00669
# mmu05022 C01996
# mmu00520 C00329/C02713/C03410/C00140/C00203
# mmu00030 C00199
# mmu00500 C00208
# mmu00510 C06081
# mmu00062 C00249
# mmu00562 C03659
# mmu00071 C00249
# mmu00051 C00424
# mmu00440 C00074
# mmu00100 C01753
# mmu05208 C00530
# mmu00860 C00188/C03114/C00430
#          Count
# mmu00590 25
# mmu00350 16
# mmu04974 12
# mmu04726 11
# mmu00260 10
# mmu04080 10
# mmu00240 11
# mmu00770  7
# mmu00140 14
# mmu00400  7
# mmu00410  6
# mmu00620  6
# mmu04913  5
# mmu01040 10
# mmu00982 12
# mmu05230  6
# mmu00591  5
# mmu00360  7
# mmu04971  3
# mmu00290  4
# mmu04714  4
# mmu00592  6
# mmu02010 14
# mmu00564  7
# mmu04750  5
# mmu00830  4
# mmu00330  8
# mmu00470  8
# mmu04270  3
# mmu04977  5
# ⋮        ⋮
# mmu04924 1
# mmu00760 3
# mmu00910 1
# mmu05415 2
# mmu00040 3
# mmu04918 1
# mmu00640 2
# mmu00983 3
# mmu00785 2
# mmu00630 3
# mmu00430 1
# mmu00900 2
# mmu04976 9
# mmu00650 2
# mmu00531 1
# mmu00730 1
# mmu04216 1
# mmu05022 1
# mmu00520 5
# mmu00030 1
# mmu00500 1
# mmu00510 1
# mmu00062 1
# mmu00562 1
# mmu00071 1
# mmu00051 1
# mmu00440 1
# mmu00100 1
# mmu05208 1
# mmu00860 3
