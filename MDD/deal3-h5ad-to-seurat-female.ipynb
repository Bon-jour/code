# %%
setwd('/import/GSE213982_fel/')

# %%
library(sceasy)
# Out:
# Loading required package: reticulate
#
# Warning message:
# "package 'reticulate' was built under R version 4.2.3"

# %%
h5ad_file = './res.h5ad'

# %%
sceasy::convertFormat(h5ad_file, from="anndata", to="seurat",
                       outFile='female.rds')
# Out:
# X -> counts
# An object of class Seurat
# 33562 features across 160711 samples within 1 assay
# Active assay: RNA (33562 features, 0 variable features)
#  2 layers present: counts, data
#  1 dimensional reduction calculated: umap

# %%
library(Seurat)
# Out:
# Warning message:
# "package 'Seurat' was built under R version 4.2.3"
# The legacy packages maptools, rgdal, and rgeos, underpinning the sp package,
# which was just loaded, will retire in October 2023.
# Please refer to R-spatial evolution reports for details, especially
# https://r-spatial.org/r/2023/05/15/evolution4.html.
# It may be desirable to make the sf package available;
# package maintainers should consider adding sf to Suggests:.
# The sp package is now running under evolution status 2
#      (status 2 uses the sf package in place of rgdal)
#
# Attaching SeuratObject

# %%
sce = readRDS('./female.rds')

# %%
DefaultAssay(sce) = 'RNA'

# %%
FeaturePlot(sce,features = 'VIM',raster = F)
# Out:
# plot without title

# %%
DimPlot(sce,raster=FALSE,group.by = 'celltype')
# Out:
# plot without title

# %%
library(future)
plan("multisession",workers = 40) # 使用multisession策略

# %%
options(future.globals.maxSize = 3987822434)

# %%
# Idents(sce) = 'celltype'
# FindMarkers(sce,ident.1= 'Oli' )
# Out:
#            p_val         avg_log2FC pct.1 pct.2 p_val_adj
# GABRD      0             -0.2563481 0.022 0.212 0
# KCNAB2     0             -0.3814669 0.048 0.330 0
# CHD5       0             -0.5677697 0.056 0.447 0
# TNFRSF25   0             -0.2894485 0.016 0.223 0
# CAMTA1     0             -0.2516717 0.408 0.645 0
# CLSTN1     0             -0.4928754 0.197 0.553 0
# FBXO44     0             -0.3349014 0.049 0.306 0
# KAZN       0             -0.5729981 0.431 0.742 0
# ATP13A2    0             -0.2662850 0.058 0.285 0
# PADI2      0              0.4624639 0.241 0.043 0
# IGSF21     0             -0.3740770 0.034 0.289 0
# MICOS10    0             -0.2791055 0.047 0.259 0
# RAP1GAP    0             -0.4407815 0.077 0.400 0
# LUZP1      0             -0.3952095 0.042 0.335 0
# CLIC4      0              0.5999640 0.319 0.060 0
# MAN1C1     0             -0.2513837 0.066 0.272 0
# STMN1      0             -0.2742110 0.206 0.436 0
# ATP5IF1    0             -0.2632270 0.056 0.261 0
# EPB41      0             -0.2565778 0.027 0.219 0
# ADGRB2     0             -0.3394417 0.064 0.319 0
# MARCKSL1   0              0.4947333 0.288 0.104 0
# SYNC       0             -0.2909545 0.040 0.252 0
# CSMD2      0             -0.2722697 0.155 0.378 0
# NCDN       0             -0.3715446 0.063 0.321 0
# GRIK3      0             -0.2618935 0.021 0.175 0
# COL9A2     0              0.3056082 0.154 0.027 0
# RIMS3      0             -0.2836690 0.031 0.250 0
# SCMH1      0             -0.3447854 0.137 0.419 0
# HIVEP3     0             -0.3198918 0.191 0.449 0
# RNF220     0              1.5998540 0.853 0.213 0
# ...        ...           ...        ...   ...   ...
# ZBED5      2.060305e-190 0.2771799  0.219 0.164 6.914797e-186
# VPS35L     9.558659e-186 0.2951598  0.329 0.298 3.208077e-181
# ADAM10     2.373708e-184 0.2898843  0.359 0.337 7.966638e-180
# TRPC4AP    4.860894e-178 0.2961967  0.311 0.275 1.631413e-173
# AC106791.1 7.756852e-173 0.2579311  0.196 0.144 2.603355e-168
# MEGF9      1.705246e-167 0.2921934  0.333 0.309 5.723147e-163
# ARHGEF2    2.563719e-166 0.2733570  0.227 0.179 8.604355e-162
# USP47      1.423579e-161 0.2627621  0.382 0.380 4.777815e-157
# TUBB4A     9.750694e-161 0.2610190  0.261 0.210 3.272528e-156
# NUTM2A-AS1 2.660327e-160 0.2857412  0.352 0.338 8.928590e-156
# ARHGAP22   1.200572e-158 0.2732949  0.257 0.211 4.029358e-154
# DIXDC1     1.002433e-156 0.2709887  0.257 0.213 3.364365e-152
# BACE1      2.268826e-156 0.2708374  0.228 0.182 7.614634e-152
# FANCL      3.427336e-155 0.2745905  0.246 0.202 1.150283e-150
# INF2       4.360453e-152 0.2628656  0.225 0.176 1.463455e-147
# ZNF652     1.053455e-148 0.2825670  0.312 0.284 3.535604e-144
# TUBA1A     2.786786e-146 0.2795683  0.319 0.287 9.353011e-142
# TTLL11     8.215408e-142 0.2619576  0.310 0.288 2.757255e-137
# AC118549.1 1.471122e-140 0.2612059  0.363 0.359 4.937380e-136
# CDK6       6.684743e-138 0.2635373  0.294 0.263 2.243534e-133
# FEZ1       1.216848e-135 0.2805078  0.309 0.284 4.083985e-131
# IFT80      4.239868e-127 0.2849241  0.263 0.233 1.422984e-122
# PPP1R21    1.574256e-121 0.2505032  0.348 0.345 5.283518e-117
# FCHSD2     3.241519e-121 0.2616445  0.388 0.398 1.087919e-116
# SLC13A3    7.687271e-114 0.2643756  0.269 0.244 2.580002e-109
# ANAPC5      6.600046e-99 0.2596457  0.324 0.319  2.215107e-94
# PTP4A2      7.918842e-96 0.2512098  0.275 0.253  2.657722e-91
# DNAJB2      4.777305e-92 0.2521697  0.287 0.264  1.603359e-87
# MTMR2       2.747537e-87 0.2550764  0.242 0.220  9.221283e-83
# TMEFF1      6.612467e-85 0.2508075  0.299 0.294  2.219276e-80

# %%
sce$group = substr(sce$sample,1,1)

# %%
table(sce$sample)
# Out:
#    F1    F2    F3    F4    F5    F6    F7    F8    F9   F10   F11   F12   F13
#  3864  1843  2211  5599  6413   512   516  2655  1639  2147  2405  1948  1360
#   F14   F15   F16   F17   F18   F19   F20   F21   F22   F23   F24   F25   F26
#  3453  3454   571  5671   849   942  1045  1215   957   972  1053  2756   957
#   F27   F28   F29   F30   F31   F32   F33   F34   F35   F36   F37   F38    M1
#   846  1250  2136   748  1261  1351  4110  2483  4583  3266   954  1658  2863
#    M2    M3    M4    M5    M6    M7    M8    M9   M10   M11   M12   M13   M14
#  2038  1388  2428  1307  2665  2264  1926  1320  2530  3901  2169  2182  1838
#   M15   M16   M17   M18   M19   M20   M21   M22   M23   M24 M24_2   M26   M27
#  3815  1274  3579  1560  2579  4430  2175  2121  4059   691   672  1944  1201
#   M28   M29   M30   M31   M32   M33   M34
#  2389  2087  2237  3305  2566  2363  3192

# %%
groupinfo = read.table('./groupinfo.txt',header =T,sep = '\t')

# %%
Idents(sce)  ='sample'

# %%
for(i in 1:nrow(groupinfo)){
  sce@meta.data[which(sce@meta.data$sample == groupinfo$sample[i]),'Condition'] <- groupinfo$Condition[i]}

# %%
scRNA = sce

# %%
scedata = scRNA
table(sce$Condition)#查看各组细胞数
# Out:
#    Case Control
#   93273   67438

# %%
saveRDS(sce,file = 'final.rds')

# %%
scedata = sce

# %%
Idents(scedata) = 'celltype'

# %%
prop.table(table(Idents(scedata)))
# Out:
#        Ast        End        ExN        InN        Mic        Mix        OPC
# 0.08219724 0.02456584 0.48197074 0.17631649 0.02329648 0.02364493 0.04777520
#        Oli
# 0.14023309

# %%
table(Idents(scedata), scedata$Condition)#各组不同细胞群细胞数
# Out:
#
#        Case Control
#   Ast  5819    7391
#   End  2207    1741
#   ExN 46914   30544
#   InN 16112   12224
#   Mic  2465    1279
#   Mix  2262    1538
#   OPC  3682    3996
#   Oli 13812    8725

# %%
Cellratio <- prop.table(table(Idents(scedata), scedata$Condition), margin = 2)#计算各组样本不同细胞群比例
Cellratio <- as.data.frame(Cellratio)

# %%
Cellratio$Var2 = factor(Cellratio$Var2,levels = c('Control','Case'))

allcolour=c("#DC143C","#0000FF","#20B2AA","#FFA500","#9370DB","#98FB98","#F08080","#1E90FF","#7CFC00","#FFFF00",
            "#808000","#FF00FF","#FA8072","#7B68EE","#9400D3","#800080","#A0522D","#D2B48C","#D2691E","#87CEEB","#40E0D0","#5F9EA0",
            "#FF1493","#0000CD","#008B8B","#FFE4B5","#8A2BE2","#228B22","#E9967A","#4682B4","#32CD32","#F0E68C","#FFFFE0","#EE82EE",
            "#FF6347","#6A5ACD","#9932CC","#8B008B","#8B4513","#DEB887")
library(ggplot2)
# ggplot(Cellratio) + 
#   geom_bar(aes(x =Var2, y= Freq, fill = Var1),stat = "identity",width = 0.7,size = 0.5,colour = '#222222')+ 
#   theme_classic() +
#   labs(x='Sample',y = 'Ratio')+
#   scale_fill_manual(values = allcolour)+
#   theme(panel.border = element_rect(fill=NA,color="black", size=0.5, linetype="solid"))

library(Seurat)
library(ggplot2)
library(dplyr)
library(ggalluvial)

# %%
ggplot(Cellratio, aes(x =Var2, y= Freq, fill = Var1,
                  stratum=Var1, alluvium=Var1)) +
  geom_col(width = 0.5, color='black')+
  geom_flow(width=0.5,alpha=0.4, knot.pos=0.5)+ # 参数knot.pos设置为0.5使连接为曲线面积，就像常见的桑基图
  theme_classic() +
  labs(x='Sample',y = 'Ratio')+
  scale_fill_manual(values = allcolour) + theme(axis.text.x = element_text(angle = 45, 
 vjust = 0.5, hjust=0.5))
# Out:
# plot without title

# %%
ggsave('figure2.pdf',height =  5,width = 4)

# %% [markdown]
# ## DA analysis

# %%
merged = as.SingleCellExperiment(sce)
abundances <- table(merged$celltype, merged$sample) 
abundances <- unclass(abundances) 
#library(scater)
library(SingleCellExperiment)
colLabels(merged) <- sce$celltype
# Out:
# Warning message:
# "package 'SingleCellExperiment' was built under R version 4.2.2"
# Loading required package: SummarizedExperiment
#
# Warning message:
# "package 'SummarizedExperiment' was built under R version 4.2.2"
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
# Warning message:
# "package 'matrixStats' was built under R version 4.2.3"
#
# Attaching package: 'matrixStats'
#
#
# The following object is masked from 'package:dplyr':
#
#     count
#
#
#
# Attaching package: 'MatrixGenerics'
#
#
# The following objects are masked from 'package:matrixStats':
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# Loading required package: GenomicRanges
#
# Warning message:
# "package 'GenomicRanges' was built under R version 4.2.3"
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: 'BiocGenerics'
#
#
# The following objects are masked from 'package:dplyr':
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from 'package:stats':
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from 'package:base':
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
# Warning message:
# "package 'S4Vectors' was built under R version 4.2.3"
#
# Attaching package: 'S4Vectors'
#
#
# The following objects are masked from 'package:dplyr':
#
#     first, rename
#
#
# The following objects are masked from 'package:base':
#
#     I, expand.grid, unname
#
#
# Loading required package: IRanges
#
# Warning message:
# "package 'IRanges' was built under R version 4.2.3"
#
# Attaching package: 'IRanges'
#
#
# The following objects are masked from 'package:dplyr':
#
#     collapse, desc, slice
#
#
# Loading required package: GenomeInfoDb
#
# Warning message:
# "package 'GenomeInfoDb' was built under R version 4.2.3"
# Loading required package: Biobase
#
# Warning message:
# "package 'Biobase' was built under R version 4.2.3"
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#
# Attaching package: 'Biobase'
#
#
# The following object is masked from 'package:MatrixGenerics':
#
#     rowMedians
#
#
# The following objects are masked from 'package:matrixStats':
#
#     anyMissing, rowMedians
#
#
#
# Attaching package: 'SummarizedExperiment'
#
#
# The following object is masked from 'package:SeuratObject':
#
#     Assays
#
#
# The following object is masked from 'package:Seurat':
#
#     Assays

# %%
merged
# Out:
# class: SingleCellExperiment
# dim: 33562 160711
# metadata(0):
# assays(2): counts logcounts
# rownames(33562): MIR1302-2HG AL627309.1 ... AC007325.4 AC007325.2
# rowData names(0):
# colnames(160711): F1.AAACCCACACCTCTGT-1.Mic.Mic1
#   F1.AAACCCATCGGCATTA-1.ExN.ExN7 ... M9.TTTGTCACATGCCTTC-1.InN.InN5_SST
#   M9.TTTGTCATCCTCAACC-1.Oli.Oli2
# colData names(19): orig.ident nCount_RNA ... ident label
# reducedDimNames(1): UMAP
# mainExpName: RNA
# altExpNames(0):

# %%
library(DESeq2)
library(limma)
library(edgeR)

# %%
table(colLabels(merged), merged$Condition)

extra.info <- colData(merged)[match(colnames(abundances), merged$sample),]

y.ab <- DGEList(abundances, samples=extra.info)

keep <- filterByExpr(y.ab, group=y.ab$samples$Condition)
y.ab <- y.ab[keep,]

design <- model.matrix(~factor(celltype) + factor(Condition), y.ab$samples)
y.ab <- estimateDisp(y.ab, design, trend="none")
# Out:
#
#        Case Control
#   Ast  5819    7391
#   End  2207    1741
#   ExN 46914   30544
#   InN 16112   12224
#   Mic  2465    1279
#   Mix  2262    1538
#   OPC  3682    3996
#   Oli 13812    8725

# %%
fit.ab <- glmQLFit(y.ab, design, robust=TRUE, abundance.trend=FALSE)
res <- glmQLFTest(fit.ab, coef=ncol(design))
summary(decideTests(res))

    diff=topTags(res)$table

diff$logFC = -(diff$logFC)
# Out:
#        factor(Condition)Control
# Down                          0
# NotSig                        6
# Up                            2

# %%
padj = 0.05
foldChange = 0


    diff$group = as.factor(ifelse(diff$PValue < padj & abs(diff$logFC) >= foldChange, 
                                 ifelse(diff$logFC> foldChange ,'Up','Down'),'NoSignifi'))
    table(diff$group)
    res = diff

library("edgeR")  
    library(dplyr)
    library(ggrepel)
    library(ggplot2)
    library(cowplot)
# Out:
#      Down NoSignifi        Up
#         2         5         1

# %%
    res$group<-factor(res$group,levels=c("Down","NoSignifi","Up"))

    
    top_5 <- bind_rows(   
      res %>%
        filter(group == 'Up') %>%
        arrange(PValue, desc(logFC)) %>%
        head(5),
      res %>%
        filter(group == 'Down') %>%
        arrange(PValue, desc(logFC)) %>%
        head(5)
    )
    ggplot(data=res,aes(x=logFC,y=-log10(PValue)))+
    geom_point(aes(color=group),size=2)+
    geom_hline(yintercept = -log10(0.05), linetype="dashed",color="grey30")+
    geom_vline(xintercept = c(0),linetype="dashed",color="grey30")+
    geom_text_repel(data=top_5,aes(x= logFC,y= -log10(PValue),label= rownames(top_5)))+
    scale_color_manual(values = c("blue","grey80","red"))+
    theme_half_open() 
ggsave('Volcano.pdf',height = 8,width = 8)
# Out:
# plot without title

# %% [markdown]
# ### 鉴定MCP

# %%
setwd('/import/GSE213982_fel/')
library(DIALOGUE)
library(Seurat)
sce = readRDS('./final.rds')
table(sce$celltype)
# Out:
# Loading required package: lme4
#
# Warning message:
# "package 'lme4' was built under R version 4.2.3"
# Loading required package: Matrix
#
# Warning message:
# "package 'Matrix' was built under R version 4.2.3"
# Loading required package: lmerTest
#
# Warning message:
# "package 'lmerTest' was built under R version 4.2.3"
#
# Attaching package: 'lmerTest'
#
#
# The following object is masked from 'package:lme4':
#
#     lmer
#
#
# The following object is masked from 'package:stats':
#
#     step
#
#
# Loading required package: PMA
#
# Loading required package: plyr
#
# Loading required package: matrixStats
#
# Warning message:
# "package 'matrixStats' was built under R version 4.2.3"
#
# Attaching package: 'matrixStats'
#
#
# The following object is masked from 'package:plyr':
#
#     count
#
#
# Loading required package: psych
#
# Warning message:
# "package 'psych' was built under R version 4.2.3"
# Loading required package: stringi
#
# Warning message:
# "package 'stringi' was built under R version 4.2.2"
# Loading required package: RColorBrewer
#
# Loading required package: unikn
#
# Welcome to unikn (v1.0.0)!
#
# unikn.guide() opens user guides.
#
# Loading required package: reshape2
#
# Warning message:
# "package 'reshape2' was built under R version 4.2.3"
# Loading required package: ggplot2
#
# Warning message:
# "package 'ggplot2' was built under R version 4.2.3"
#
# Attaching package: 'ggplot2'
#
#
# The following objects are masked from 'package:psych':
#
#     %+%, alpha
#
#
# Loading required package: ppcor
#
# Loading required package: MASS
#
# Warning message:
# "package 'MASS' was built under R version 4.2.3"
# Loading required package: Hmisc
#
# Warning message:
# "package 'Hmisc' was built under R version 4.2.3"
#
# Attaching package: 'Hmisc'
#
#
# The following object is masked from 'package:psych':
#
#     describe
#
#
# The following objects are masked from 'package:plyr':
#
#     is.discrete, summarize
#
#
# The following objects are masked from 'package:base':
#
#     format.pval, units
#
#
# Loading required package: grid
#
# Loading required package: beanplot
#
# Loading required package: UpSetR
#
# Warning message:
# "package 'Seurat' was built under R version 4.2.3"
# The legacy packages maptools, rgdal, and rgeos, underpinning the sp package,
# which was just loaded, will retire in October 2023.
# Please refer to R-spatial evolution reports for details, especially
# https://r-spatial.org/r/2023/05/15/evolution4.html.
# It may be desirable to make the sf package available;
# package maintainers should consider adding sf to Suggests:.
# The sp package is now running under evolution status 2
#      (status 2 uses the sf package in place of rgdal)
#
# Attaching SeuratObject
#
#
# Attaching package: 'Seurat'
#
#
# The following object is masked from 'package:Hmisc':
#
#     Key
#   Ast   End   ExN   InN   Mic   Mix   OPC   Oli
# 13210  3948 77458 28336  3744  3800  7678 22537

# %%
Idents(sce) = 'group'
female = subset(sce,idents  = 'F')

# %%
female
# Out:
# An object of class Seurat
# 33562 features across 81653 samples within 1 assay
# Active assay: RNA (33562 features, 0 variable features)
#  1 dimensional reduction calculated: umap

# %%
female
# Out:
# An object of class Seurat
# 33562 features across 81653 samples within 1 assay
# Active assay: RNA (33562 features, 0 variable features)
#  1 dimensional reduction calculated: umap

# %%
Idents(female) <- "celltype"
# Downsample the number of cells per identity class
#ob1 <- subset(x = female, downsample = 1000)
ob1 = female
library(Seurat)
ob1 <- FindVariableFeatures(ob1, selection.method = "vst", nfeatures = 5000)
ob1
# Out:
# An object of class Seurat
# 33562 features across 81653 samples within 1 assay
# Active assay: RNA (33562 features, 5000 variable features)
#  1 dimensional reduction calculated: umap

# %%
sum(b1)
# Out:
# [1] 18345

# %%
set.seed(1263)
# Simulating data based on Seurat object of PBMCs
obj<-ob1
obj@meta.data$samples <- obj@meta.data$sample
obj@meta.data$cell.subtypes<-obj@meta.data$celltype
b1<-is.element(obj@meta.data$cell.subtypes,c("Ast",'InN'))
b2<-is.element(obj@meta.data$cell.subtypes,c("Mic","Mix"))
b3<-is.element(obj@meta.data$cell.subtypes,c('End', 'ExN'))
b4<-is.element(obj@meta.data$cell.subtypes,c("OPC","Oli"))




obj@meta.data$samples[b1] <- sample(obj@meta.data$sample, size = sum(b1), replace =FALSE)
obj@meta.data$samples[b2] <- sample(obj@meta.data$sample, size = sum(b2), replace =FALSE)
obj@meta.data$samples[b3] <- sample(obj@meta.data$sample, size = sum(b3), replace =FALSE)
obj@meta.data$samples[b4] <- sample(obj@meta.data$sample, size = sum(b4), replace =FALSE)

DIALOGUE_make.cell.type.seurat<- function(obj, cell.subtypes, name){
  # Given a Seurat object with "cell.subtypes" and "samples" information provided in the meta.data field
  
  if(is.null(obj@meta.data$cell.subtypes)){return("Cell subtypes information is missing")}
  if(is.null(obj@meta.data$samples)){return("Sample information is missing")}
  
  sub_obj<- subset(x = obj,cells = rownames(obj@meta.data)[is.element(obj@meta.data$cell.subtypes,cell.subtypes)])
  sub_obj<- NormalizeData(sub_obj,normalization.method = "LogNormalize", scale.factor = 100000)
  sub_obj<-FindVariableFeatures(sub_obj,selection.method = "vst", nfeatures = 5000)
  sub_obj<-ScaleData(sub_obj)
  sub_obj<-RunPCA(sub_obj,npcs = 30) 
  
  tpm<- as.matrix(sub_obj@assays$RNA@data)
  
  X<- sub_obj@reductions$pca@cell.embeddings
  assertthat::are_equal(rownames(X),colnames(tpm))
  n_cells<- ncol(tpm)
  samples<- sub_obj@meta.data$sample
  n_count<- as.vector(scale(log(sub_obj@meta.data$nCount_RNA)))
  metadata<- data.frame(nFeatures = sub_obj@meta.data$nFeature_RNA,
                        samples = samples,
                        group = sub_obj@meta.data$group,
                        Condition = sub_obj@meta.data$Condition,
                        cell.subtypes = as.character(sub_obj@meta.data$cell.subtypes))
  r<-make.cell.type(name = name ,tpm,samples,X,metadata, cellQ = n_count)
  return(r)
}

# %%
r1<- DIALOGUE_make.cell.type.seurat(obj, cell.subtypes = c('ExN'), name = "ExN")
r2<- DIALOGUE_make.cell.type.seurat(obj, cell.subtypes = c("Ast"), name = "Ast")
r3<- DIALOGUE_make.cell.type.seurat(obj, cell.subtypes = c("InN"), name = "InN")
r4<- DIALOGUE_make.cell.type.seurat(obj, cell.subtypes = c("Mic"), name = "Mic")
r5<- DIALOGUE_make.cell.type.seurat(obj, cell.subtypes = c("End"), name = "End")
r6<- DIALOGUE_make.cell.type.seurat(obj, cell.subtypes = c("OPC"), name = "OPC")
r7<- DIALOGUE_make.cell.type.seurat(obj, cell.subtypes = c("Oli"), name = "Oli")

rA<- list(ExN = r1,Ast = r2,Oli = r7,Mic= r4,End= r5,OPC = r6,InN = r3)  #
library(DIALOGUE)
results.dir = './female_condition/'
# Out:
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  ST18, ERBB4, FRMD4B, ZNF536, PLP1, DOCK5, MOG, SLC1A3, C10orf90, COL4A5
# 	   LINC01608, DOCK10, LPAR1, FA2H, UGT8, ADARB2, RFTN2, NCKAP5, NXPH1, SHROOM4
# 	   AC008571.2, CD22, ABCA8, DAAM2, FBXL7, SLC5A11, ASPA, CNDP1, VRK2, KCNH8
# Negative:  RGS4, YWHAH, STMN1, CALM3, EIF4A2, BEX1, TUBB2A, ATP6V1B2, BEX3, CFL1
# 	   FAIM2, OAZ1, NORAD, YWHAB, NAPB, THY1, NGRN, AP2M1, SARAF, NEFL
# 	   YWHAG, PFN2, TOMM20, ARF3, ATP6V0C, SERINC1, RAB3A, DYNLL1, VAMP2, PEBP1
# PC_ 2
# Positive:  NEFL, TUBA1B, TUBB2A, HSP90AB1, NEFM, CALM3, ATP6V0C, NORAD, BEX1, THY1
# 	   CALM1, RGS4, TSPYL1, B4GAT1, RAB3A, VAMP2, GAPDH, NAP1L5, ARL6IP1, TUBB
# 	   SNCB, TUBB3, VGF, ACTB, ATP6AP1, PNMA8B, NAP1L3, ACTG1, PEBP1, CFL1
# Negative:  SGCD, DAB1, ASIC2, AC107223.1, PDE10A, NPAS3, FRMD5, CNTNAP5, LINGO2, KIRREL3
# 	   SOX5, DSCAML1, GRID2, PHLPP1, IQCJ-SCHIP1, KCNH7, FSTL4, GRM7, SYN3, ASTN2
# 	   RGS6, PDE4B, RYR3, GPC6, AC007563.2, GALNT13, AC011287.1, GALNTL6, MGAT4C, RPS6KA2
# PC_ 3
# Positive:  SYN3, CUX2, AC011287.1, RGS6, AC034268.2, TAFA1, IQCJ-SCHIP1, ST6GALNAC5, LINGO2, GRM7
# 	   AL157944.1, CBLN2, AC107223.1, CA10, GALNTL6, TENM2, HS6ST3, FSTL4, LINC02306, DGKB
# 	   GPC6, SORCS1, CDH12, ASIC2, AC019211.1, KCTD16, EPHA6, AC007563.2, UNC5D, AC013287.1
# Negative:  ST18, DOCK5, FRMD4B, C10orf90, PLP1, DOCK1, RNF220, NCKAP5, ZNF536, MOG
# 	   FA2H, LPAR1, DAAM2, DOCK10, UGT8, COL4A5, RFTN2, BCAS1, SHROOM4, LINC01608
# 	   KCNH8, CERCAM, MOBP, FAM107B, MYRF, PTGDS, ABCA8, SLCO1A2, TMEM144, CLDN11
# PC_ 4
# Positive:  FOXP2, HS3ST4, SEMA3E, PCDH11X, TLL1, RXFP1, GRIK3, SLC35F1, PDZRN4, KLHL5
# 	   HS3ST2, VWC2L, CLMP, CHRM2, TSHZ2, TOX, GPRIN3, IL1RAPL2, FSTL5, CLSTN2
# 	   GRIP1, LINC02232, AC008415.1, PLCXD3, PWRN1, FGFR1, AC109466.1, PWRN4, PTCHD4, KIAA1211
# Negative:  CUX2, LINC02306, SERPINE2, CBLN2, EPHA6, STXBP6, PCDH8, FGFR2, PCSK6, GNAL
# 	   PDE7B, LAMA2, AL157944.1, PTPRK, GLIS3, KCNMB2, AC093607.1, THSD7A, LINC01090, RASGRF2
# 	   ST18, LINC02822, LINC00326, CA10, AC110614.1, ADAMTS9-AS2, TAFA1, CDH13, CCK, PDZD2
# PC_ 5
# Positive:  MEIS2, KIAA1217, DGKG, GNAL, BCL11B, PCSK5, SERPINE2, HPCAL1, NFIA, SDK1
# 	   MMD2, LHFPL3, ROBO1, RPS6KA2, SULF1, ITPR2, TRPC6, PARD3, MAML2, CDC14A
# 	   CDH9, MCTP2, PDZD2, ZFHX3, ITGA8, CCN2, STXBP6, HPSE2, CALCRL, CALN1
# Negative:  IL1RAPL2, RORB, AC008415.1, AC109466.1, TMTC2, AC073091.3, COBLL1, CDK18, CPNE4, POU6F2
# 	   AC021134.1, CNTN5, AL589693.1, PLCH1, CASC15, AP003066.1, TSHZ2, PTPRK, FOXP2, DCC
# 	   PLD1, TLL1, LINC01725, RXFP1, FSTL5, UNC5D, MBP, EDIL3, PTPRT, HS3ST2
#
# Warning message in asMethod(object):
# "sparse->dense coercion: allocating vector of size 8.4 GiB"
# [1] "Cell type name: ExN"
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  COL5A3, ZNF98, HPSE2, WIF1, GLUL, GJA1, CACNB2, ATP1B2, AC097518.2, CABLES1
# 	   FGFR3, AC016716.2, EMX2, LRRC3B, FAM167A-AS1, PREX2, LINC01727, SLC4A4, NDRG2, LINC00299
# 	   TPD52L1, AC008957.2, NAT8L, AC005520.5, AC002429.2, RERG, LINC00499, AL356737.2, RGS20, PAMR1
# Negative:  SHISA9, XKR4, DGKI, LRRTM3, ANK3, SYNDIG1, TMEM132D, MYT1L, KIRREL3, CNTNAP5
# 	   SLC24A2, HECW2, SRRM4, SH3GL3, DSCAM, AK5, ASIC2, GRIA3, DSCAML1, ELMO1
# 	   GRIN2B, MDGA2, FGF12, RAPGEF5, SLC35F3, SORCS1, ATP8A2, SNTG1, CA10, TMEFF2
# PC_ 2
# Positive:  SLCO1C1, RORB, ETNPPL, SLC7A11, BMPR1B, RANBP3L, PDE7B, ARHGAP24, RGS20, NHSL1
# 	   SHROOM3, TPD52L1, PREX2, GABRA2, VAV3, GJA1, SLC35F1, RFX4, PTN, DGKG
# 	   TOX, AC007389.1, ESRRG, AC073050.1, GLUL, RERG, AC114971.1, ELOVL5, LRRC3B, EPHB1
# Negative:  KCNIP4, CNTNAP2, CSMD1, ROBO2, RBFOX1, SYT1, RALYL, KCNQ5, CHRM3, NRXN3
# 	   KCNH7, LINGO2, ATRNL1, RYR2, OPCML, CNTN4, AC011287.1, DCLK1, NRG1, CNTN5
# 	   MDGA2, ASIC2, LDB2, HS6ST3, SNTG1, GRIN2A, SLC4A10, RIMS2, IL1RAPL1, DPP10
# PC_ 3
# Positive:  CACNB2, CABLES1, GRM3, ZNF98, HPSE2, WIF1, RERG, COL5A3, ARHGAP24, PDE4D
# 	   LINC01727, PDE3B, LINC00499, DNM3, PTN, SYNE1, PLCB1, AC097518.2, GLUL, TMEM132C
# 	   VAV3, SGCD, FRMD4A, AC007389.1, LRRC3B, CACNA1A, GABRA2, TMEM108, OLFM2, ADAMTS17
# Negative:  AC012405.1, TNC, LINC00609, AC073941.1, VCAN, GFAP, CD44, ADAMTSL3, WDR49, LINC00836
# 	   SLC38A1, AL627316.1, L3MBTL4, SLC24A4, COL21A1, DPP10, GALNT15, AQP1, ADAMTS9, TJP2
# 	   DCLK1, HSPA1A, AL162511.1, IGFBP5, SERPINI2, CRYAB, DPYSL3, AL133304.3, ABI3BP, ANGPT1
# PC_ 4
# Positive:  ST18, FRMD4B, LINC01608, KCNH8, MOG, ENPP2, ZNF536, CNDP1, UGT8, DOCK10
# 	   MOBP, BCAS1, MYRF, HHIP, SLC7A14-AS1, AC012494.1, CTNNA3, AC008571.2, CERCAM, PLP1
# 	   EDIL3, ELMO1, PDE1C, SPOCK3, MBP, SLC24A2, LINC01170, CREB5, C10orf90, TF
# Negative:  DCLK1, SIDT1, CLU, C11orf87, SLC6A17, HSPB1, CABP1, TESPA1, SCN3B, SLC22A10
# 	   FOS, HTR1E, LY86-AS1, SH3GL2, SYNPO2, KCNN2, CBLN2, AL117329.1, MLIP, SYT5
# 	   SLC12A5, SRRM4, GRIN1, VSTM2L, AL591501.1, ADCY1, TMEM130, LINC02217, PACSIN1, PCSK2
# PC_ 5
# Positive:  KCNIP4, ROBO2, CSMD1, FGF14, RALYL, LRRTM4, RBFOX1, CNTN1, GRIK2, MDGA2
# 	   OPCML, ATRNL1, CNTNAP2, CCSER1, DLGAP1, SMYD3, NEGR1, PTPRD, PCDH7, AL137139.2
# 	   SNTG1, STXBP5L, AL160272.1, GPC6, DGKB, RBMS3, NHSL1, RIMS2, ANKS1B, AC073050.1
# Negative:  LINC00486, AC016716.2, TMSB4X, FOS, NR4A3, EGR1, NR4A1, FOSL2, FTH1, SNHG25
# 	   FOSB, RPS27, PCDH9-AS2, HSPH1, NR4A2, UBB, DNAJB1, TUBA1B, AC002463.1, HSP90AB1
# 	   HSPB1, BEX1, RPL41, ZNF331, JUND, STMN1, MYRF, SNCB, YWHAH, RPL32
#
# Warning message in asMethod(object):
# "sparse->dense coercion: allocating vector of size 1.9 GiB"
# [1] "Cell type name: Ast"
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  SOX6, NXPH1, GRIK3, MYO5B, SPARCL1, PRKG1, CNTNAP3, SATB1-AS1, KIAA1217, SCN1A-AS1
# 	   STXBP6, TAC1, OPRD1, PLCH1, RSPO2, GPC6, PRDM1, CUX2, TMEM132C, FLT3
# 	   DPP10, SATB1, CNTNAP3B, ANKRD34C-AS1, SULF1, EPB41, XYLT1, TSHZ3, RASGRF2, SAMD5
# Negative:  KCNT2, ADARB2, PROX1, NFIB, NFIX, RGS12, MAPK4, COBL, EGFR, DOCK10
# 	   NEDD4L, MAGI3, DSCAM, CNTNAP4, PROX1-AS1, SLC25A48, LINGO2, CXCL14, AL391832.4, PCSK2
# 	   AC087564.1, AP1S2, ARPP21, AL589740.1, ADRA1B, AC013265.1, NR2F2-AS1, CCNH, LRRC3B, KIAA1958
# PC_ 2
# Positive:  ADARB2, CXCL14, PROX1, NFIB, LINGO2, VIP, NR2F2-AS1, CALB2, PROX1-AS1, AC013265.1
# 	   LAMA3, RGS12, KCNT2, AL391832.4, EGFR, NFIX, SHISA8, AC087564.1, CHRNA2, DSCAM
# 	   ASIC4, MAPK4, AC016766.1, TSHZ2, PDE3A, SLC25A48, SLC22A3, KCNIP4, SYNPR, KMO
# Negative:  CNTNAP3, SPARCL1, RAPGEF5, ANKRD34C-AS1, SOX6, RUNX2, XYLT1, SAMD5, LINC02389, OPRD1
# 	   AL033504.1, SATB1-AS1, GRIK3, TENM1, MYO5B, CNTNAP3B, STXBP5-AS1, GRIA3, ST8SIA4, ETV6
# 	   MIR181A1HG, PPARGC1A, SASH1, PRKG1, SCN1A-AS1, RASGRF2, ADCY8, SLC26A4, KLHL5, RSPO2
# PC_ 3
# Positive:  SV2C, EYA4, LAMP5, PDGFD, FBXL7, TRPC3, ARHGAP31, NTNG1, LINC00298, KIT
# 	   AC132803.1, ROR2, FGF13, ATP11C, ID2, AC137770.1, LINC01344, SPHKAP, SOX13, PDGFRA
# 	   CPLX3, HPCAL1, PTPRT, CTXND1, CA2, TOX2, MYO16, TACR1, LTBP1, PRELID2
# Negative:  KCNMB2, PDE4B, L3MBTL4, CDH10, KIAA1217, LINC01322, ASIC2, ROBO1, STARD13, PTPRE
# 	   AC013265.1, SPOCK3, CNTN3, PCDH11X, CALB2, VWC2L, VIP, LDLRAD4, PTPRZ1, CHRNA2
# 	   RGS6, CHST15, HS6ST3, 1-Mar, ADAMTS6, GALNTL6, SNTG1, GRM7, ARPP21, RYR3
# PC_ 4
# Positive:  ERBB4, CALN1, ZNF804A, SHISA9, PLD5, PLXNA4, SDK1, LRRC4C, HS6ST3, ADAMTS17
# 	   MYO16, VWC2L, NEAT1, SLC4A4, PLCXD3, CEMIP, COL12A1, GRIA4, BTBD11, RARB
# 	   ZNF536, TAFA2, VWC2, LYPD6B, PVALB, TMEM132C, AC092422.1, AL596087.2, SULF1, MYO1B
# Negative:  SST, PDE1A, RALYL, MAN1A1, COL25A1, LINC01122, GRM1, SYNPR, ILDR2, SHISA6
# 	   TRHDE, CACNA2D3, SLC8A1, CDH8, MCUB, GRID2, GRIK1, PAWR, TMTC2, FRMD3
# 	   SEMA6A, NETO1, UST, KCNIP1, LINC01482, RAB31, CHRM3, GRIN3A, KCNB2, ROBO1
# PC_ 5
# Positive:  SLC44A5, GAD2, ANKRD55, THSD7A, DLX6-AS1, NETO2, AL136114.1, VAMP2, CNTN4, FXYD6
# 	   PTPRO, PNOC, EXT1, SCG2, TOX3, IQGAP2, BTBD11, PTPRE, TENM3, EEF1A1
# 	   SLC24A3, PLPPR1, SYNPR, AP001347.1, EYS, PDE10A, CDH9, MYO5B, MAFB, KIF26B
# Negative:  C10orf90, RFTN2, DOCK5, ABCA8, MOG, SHROOM4, FA2H, ST18, LINC01608, CD22
# 	   COL4A5, SLC1A3, BCAS1, ASPA, LINC00639, DOCK1, PLP1, MOBP, SLCO1A2, MYRF
# 	   UGT8, CNDP1, PLLP, OPALIN, TTYH2, MEGF10, AC012494.1, ZCCHC24, MAG, SH3TC2
#
# Warning message in asMethod(object):
# "sparse->dense coercion: allocating vector of size 2.7 GiB"
# [1] "Cell type name: InN"
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  NTM, NCAM1, PPP2R2B, CDH20, FBXL7, CTNND2, ASTN2, MAGI2, NCAM2, SLC24A2
# 	   SPOCK1, SOX2-OT, GPM6B, FRMD5, TRIM2, LSAMP, FYN, ANO4, NPAS3, C10orf90
# 	   IL1RAPL1, ADGRL3, AKAP6, NTRK2, ANK3, KAZN, NLGN1, EDIL3, TMTC2, DMD
# Negative:  C3, RASGEF1C, AC008691.1, SLCO2B1, FLI1, ETV6, RBM47, PALD1, ABCC4, RUNX1
# 	   MYO1F, CSF2RA, LY86, SYNDIG1, CTSB, CMKLR1, PTPRC, SAMSN1, BMP2K, CD74
# 	   ARHGAP22, FYB1, SLC2A5, MAF, KCNK13, SRGN, LPCAT2, LYN, A2M, CD86
# PC_ 2
# Positive:  ST18, C10orf90, CERCAM, SLC7A14-AS1, LINC01608, ZNF536, RNF220, ENPP2, TF, MOBP
# 	   PDE1C, CTNNA3, AC012494.1, TMEM144, PCSK6, AC008571.2, TMTC2, EDIL3, PLP1, SLC5A11
# 	   FRMD5, SLC24A2, SPOCK3, DOCK5, ANO4, MAP7, SH3GL3, PRUNE2, SLC44A1, LINC00609
# Negative:  SKAP1, SLFN12L, SAMD3, STAT4, CD247, ITGA4, TC2N, RUNX3, PTPN22, RIPOR2
# 	   PTGDR, CD96, SYNE2, BCL11B, CD44, PYHIN1, IKZF3, MYBL1, CEMIP2, ATP10A
# 	   CRYBG1, RASGRP1, MCTP2, ITK, CD6, LINC01934, TXK, PRF1, RPS27A, KLRF1
# PC_ 3
# Positive:  FTL, CD74, CTSB, BMP2K, ETV6, PAG1, RBM47, FGD4, HIF1A, PADI2
# 	   ARHGAP15, LYN, SLC11A1, TLR2, ACSL1, PIP4K2A, GNA13, RAB31, CD86, NCKAP5
# 	   SRGN, RUNX1, SLCO2B1, SHTN1, ELL2, CHSY1, LPCAT2, BCL2, LHFPL2, PPARD
# Negative:  RBFOX1, KCNIP4, LRRTM4, SYT1, ROBO2, CSMD1, DLGAP1, DPP10, RALYL, CCSER1
# 	   NRG3, FRMPD4, MEG3, FAM155A, FGF14, OPCML, CNTNAP2, ATRNL1, NRG1, GALNT17
# 	   KCNQ5, NEGR1, RIMS2, PLCB1, TENM2, GRIN2A, ZNF385B, RYR2, CNTN5, FGF12
# PC_ 4
# Positive:  SKAP1, SLFN12L, SAMD3, ITGA4, TC2N, CD247, PTPN22, RUNX3, SLC7A14-AS1, DOCK5
# 	   CERCAM, ST18, PTGDR, CD96, LINC01608, RNF220, CD44, C10orf90, DPYD, MOBP
# 	   ENPP2, ZNF536, CRYBG1, SYNE2, PYHIN1, AC012494.1, ITK, PCSK6, CD6, TF
# Negative:  SYNDIG1, AC008691.1, RASGEF1C, P2RY12, LINC01374, PALD1, LRRK1, ABCC4, FOXP2, DSCAM
# 	   HS3ST4, LINC02712, ARHGAP22, SLCO2B1, LHFPL2, DLEU1, C3, CACNB4, CPED1, KHDRBS3
# 	   A2M, CSGALNACT1, SH3RF3, KCNMA1, CSF2RA, MAF, MERTK, SDK1, BMP2K, FAM149A
# PC_ 5
# Positive:  RPL32, RPS27, RPL26, RPL19, FTL, RPS24, RPS18, RPS25, RPS6, RPLP2
# 	   RPS4X, RPS15, RPS27A, RPL37A, RPLP1, RPL28, RPL36A, RPL11, RPL23A, RPL37
# 	   RPL13A, RPS20, RPL12, TPT1, RPL24, FTH1, AIF1, RPL38, RPS11, RPS8
# Negative:  SKAP1, SLFN12L, SAMD3, CD247, PTPN22, TC2N, CD96, PTGDR, ITGA4, RUNX3
# 	   PYHIN1, IKZF3, STAT4, MCTP2, ITK, CRYBG1, MYBL1, ARHGAP15, ETS1, SPON2
# 	   KLRF1, SYNE2, THEMIS, PRF1, CD6, SYTL3, LCK, CD44, LINC01934, RIPOR2
# [1] "Cell type name: Mic"
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  CLDN5, FLT1, IFI27, ATP10A, TMSB10, ABCB1, VWF, ITM2A, DUSP1, MECOM
# 	   KLF2, MT2A, SOX18, HSPA1A, FOS, SLC7A1, ANKRD37, THSD4, HLA-B, HSPA1B
# 	   TMSB4X, CGNL1, SRGN, ABCG2, MT1M, STC2, AC015819.2, UBC, ST6GALNAC3, SLC5A6
# Negative:  SRGAP3, NCAM1, NALCN, LINC00461, TRIM9, CACNA1B, ASTN1, GRIA1, SYNDIG1, RBFOX3
# 	   DMD, PPP2R2B, NAV3, IL1RAPL1, GRID1, NLGN4X, MAPT, AKAP6, PGBD5, DPP6
# 	   DOCK3, MIR99AHG, ANK3, COBL, ANKS1B, LSAMP, AC092691.1, NLGN1, ATP2B2, NTM
# PC_ 2
# Positive:  CSMD1, CACNA1B, RBFOX1, RYR2, NRXN3, PEX5L, AC092691.1, ST6GALNAC3, KCNIP4, CNTNAP2
# 	   NRXN1, ROBO2, RALYL, CSMD3, LRRC7, PPP2R2B, LRRTM4, GRIN2A, NKAIN2, SLC35F3
# 	   ATP10A, FLT1, KCNH1, DSCAM, STXBP5L, ASIC2, CTNND2, HS6ST3, CADM2, CADPS
# Negative:  SLC19A1, SLC38A11, PDGFRB, PRKG1, SLC6A1, ARHGAP42, PDE8B, NOTCH3, GPC5, SLC6A12
# 	   SLC30A10, COLEC12, GRM8, CARMN, ARHGAP10, NR2F2-AS1, TRPC3, GRM3, CACNA1C, SNTB1
# 	   CASC15, PDE7B, GJC1, SLC1A3, EPS8, PLCE1, ATP1A2, PLXDC1, LAMA2, PTH1R
# PC_ 3
# Positive:  SLC6A1, PRKG1, COLEC12, SLC19A1, ATP1A2, CACNA1C, GPC5, GRM8, LAMA2, SLC38A11
# 	   NR2F2-AS1, MIR99AHG, PDGFRB, CARMN, SLC1A3, GRM3, NOTCH3, KCNIP4, TRPC3, DGKB
# 	   PDE8B, ARHGAP10, SLC6A12, ARHGAP42, EPS8, SGIP1, ADGRB3, LSAMP, CACNA2D3, CASC15
# Negative:  MECOM, ELOVL7, ABCB1, ST6GALNAC3, THSD4, ATP10A, PTPRB, SLC7A1, ANO2, FLT1
# 	   MYRIP, VWF, ITGA6, ABCG2, ADIPOR2, CGNL1, FLI1, ST8SIA6, INPP5D, CLDN5
# 	   SLC39A10, LIMCH1, RNF144B, SORBS2, SORBS1, SGPP2, GALNT18, ST6GAL1, STXBP6, GRB10
# PC_ 4
# Positive:  AC011995.2, CFAP61, CACNG2, AC005906.2, SLC8A2, FXYD7, LRFN2, PRKCG, USP43, LINC00599
# 	   FAM153CP, MPPED1, DGCR9, UNC13A, NWD2, EPHB6, PLXNA4, CPNE5, U91319.1, LINC01106
# 	   CDH22, ADD2, ST8SIA3, TESPA1, L1CAM, SRRM3, PVT1, ZBBX, BAAT, CABP1
# Negative:  SLC7A14-AS1, C10orf90, LPAR1, MOG, CLDN11, KCNH8, LINC00609, AC079352.1, CERCAM, UGT8
# 	   ST18, AC008571.2, TF, FGFR2, PLD1, MOBP, NCKAP5, FOLH1, LINC01608, TMEM144
# 	   ATP10B, MYRF, CREB5, SLC5A11, AC012494.1, BCAS1, ZNF536, GLDN, CARNS1, CNTN2
# PC_ 5
# Positive:  SPOCK3, ZNF385B, GPCPD1, ADGRL3, PCDH9, ADGRB3, GRM8, ANO3, IL1RAPL1, GRM3
# 	   NET1, ATP10A, CSMD1, SLC16A1, GPC5, SLC39A10, LSAMP, CADM2, SLCO1A2, TFRC
# 	   ST18, SORBS2, CNTNAP2, PLCL1, RBFOX1, KCNIP4, HIF1A-AS3, ABCG2, TRPC3, DACH1
# Negative:  COL15A1, LINC01088, SLC6A20, PAMR1, BICC1, COL6A3, PDGFRA, C7, MCTP2, ROR2
# 	   IQGAP2, CYP1B1, VIT, FBLN5, HSD11B1, KCNK2, WDR86, FLRT2, SRPX2, ALDH1A2
# 	   CEMIP, COL12A1, CLMP, KCNIP1, THBS2, LHCGR, COL13A1, LINC02058, F3, ADAMTS12
# [1] "Cell type name: End"
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  AC002463.1, AC008080.4, AC016716.2, AL049569.1, PKP4-AS1, MNX1, LINC02345, AC073957.1, AL158212.2, HCG15
# 	   OTX2-AS1, Z82217.1, AL353768.2, AC244100.3, ADGRF1, AC104688.1, AC024651.1, AC093765.2, AP1M2, CD52
# 	   AC116667.2, LINC01447, AL353693.1, CLEC12A, AL512452.1, AL133444.1, ADAM33, AL356756.1, AC090970.2, C17orf64
# Negative:  NEBL, C1orf21, TBC1D5, FBXL17, GDAP1, TAFA2, RPS6KA2, MEG8, DTNA, RIMS1
# 	   PBX1, KLF12, SPATA6, DOCK4, ZFPM2, CDH10, EDIL3, PEAK1, RUNX1T1, MLLT3
# 	   LPP, UBE2E2, SPOCK1, SGMS1, NFIB, PARD3, HECW1, ERC2, FAM110B, MSRA
# PC_ 2
# Positive:  ZEB1, NTNG1, PDGFRA, SEMA5A, NKAIN3, TMEM132C, LRRN1, NXPH1, BRINP3, SORCS3
# 	   KLF12, MTSS1, DCC, GRIK1, PLPPR1, PID1, MEGF11, SPATA6, KAT2B, PEAK1
# 	   CASK, SLC24A3, SCN1A, CHL1, STK32A, KCNH8, ARHGAP42, AL589740.1, PRRX1, NLGN4X
# Negative:  RBFOX3, RGS6, DLGAP2, SLIT3, GALNT18, DAPK1, GABRG3, MTUS2, CACNA1B, PTPRR
# 	   EPHA4, TENM2, ST6GALNAC5, MGAT4C, SRCIN1, DCLK1, LINGO2, SV2B, ADGRL2, CACNG3
# 	   EFNA5, GRIN2A, CAMK2A, CHD5, RASGRF1, PRKG1, FRMPD4, OLFM3, MLIP, RYR2
# PC_ 3
# Positive:  ST18, DAAM2, CDK18, LPAR1, RNF220, CLDN11, CD22, CLMN, MYRF, MOBP
# 	   COL4A5, CERCAM, EYA1, LINC01608, LINC00609, SLC7A14-AS1, AC008571.2, AL137139.2, FGFR2, SH3TC2
# 	   SEMA3B, ABCA8, PLP1, SLC5A11, NEAT1, PTGDS, EFHD1, TMEM144, PIEZO2, CTNNA3
# Negative:  RBFOX3, AL117329.1, SLIT3, CACNG3, CHD5, CBLN2, LY86-AS1, SV2B, BCL11A, AL591501.1
# 	   LINC00507, SRRM4, AC019211.1, AC034268.2, LINC02263, COL26A1, ST6GALNAC5, AL157944.1, TESPA1, LINC01331
# 	   DGCR9, CAMK2A, MLIP, AC093607.1, VSNL1, HTR2A, GRIN1, MTUS2, CNGB1, HCN1
# PC_ 4
# Positive:  EYA1, SLC14A1, AL137139.2, GJA1, SLCO1C1, GLI3, FAM189A2, RANBP3L, MLC1, ADGRV1
# 	   ALDH1A1, AC002429.2, OBI1-AS1, LINC00499, SNTB1, BMPR1B, HPSE2, RGS20, PRDM16, STON2
# 	   CDHR3, PAMR1, RYR3, SDC4, ARHGAP24, AC097518.2, SHROOM3, SDC2, RREB1, ZNF98
# Negative:  ST18, CDK18, CLDN11, MYRF, PLP1, AC008571.2, CERCAM, LINC01608, GLDN, CD22
# 	   SLC7A14-AS1, MOBP, SH3TC2, MOG, NKAIN2, SRCIN1, LDB3, TF, CNDP1, AC012494.1
# 	   CTNNA3, GPR37, PALM2-AKAP2, MAG, MYO1D, PLD1, CNTN2, FOLH1, RNF220, SLC24A2
# PC_ 5
# Positive:  DOCK8, SLCO2B1, C3, RPS27, RPS27A, RPL13A, TMSB4X, RPL32, FTH1, RPS16
# 	   RPS15, INPP5D, RPS19, RPL3, EEF1A1, AC008691.1, HSPA1A, A2M, TBXAS1, RPL8
# 	   COX7C, RPS4X, RPS25, TUBA1B, GAPDH, SEMA3E, RPL19, ADAM33, RPS21, RPL35
# Negative:  AL137139.2, OBI1-AS1, HPSE2, LINC00499, ADGRV1, RANBP3L, SHROOM3, GPC5, GLI3, RGS20
# 	   BMPR1B, MGAT4C, FAM189A2, SLCO1C1, RYR3, FGFR2, PRDM16, SLC14A1, TENM2, CARMIL1
# 	   GRM3, LINC00299, PRKG1, GNA14, EFNA5, CACNB2, EYA1, CDHR3, GJA1, ROBO2
#
# Warning message in asMethod(object):
# "sparse->dense coercion: allocating vector of size 1.0 GiB"
# [1] "Cell type name: OPC"
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  MOBP, NCKAP5, SLC7A14-AS1, LINC01608, POLR2F, CREB5, AC012494.1, HIP1, LPAR1, CERCAM
# 	   SCD, LINC00609, CNP, NEAT1, CDH20, FAM107B, HHIP, GLDN, CDK18, FGFR2
# 	   FBXL7, CLDND1, SLC5A11, AC079352.1, GRM3, PLD1, ALCAM, SYNJ2, MTUS1, PALM2-AKAP2
# Negative:  MEG3, CELF2, DLGAP2, STXBP5L, KCNMA1, ASIC2, CACNA2D3, MYT1L, CACNA1A, OPCML
# 	   DSCAM, DLGAP1, CACNA1B, FAM155A, RBFOX3, NTRK3, FGF14, PLCB1, PTPRN2, GRIN2B
# 	   MIAT, SRRM3, SHISA9, GRIA1, FRMPD4, CACNA1C, TMEM132D, CNTNAP5, XKR4, SNTG1
# PC_ 2
# Positive:  MTUS1, SHROOM4, FAM107B, LINC00609, MVB12B, PLD1, SYNJ2, SLC25A13, RFFL, VRK2
# 	   GAB2, LPGAT1, NCKAP5, KIF13B, GRM3, CDK19, FGFR2, PCSK6, LPAR1, CNTNAP4
# 	   CDH20, SGMS1, MIR100HG, SLC39A11, NEAT1, NT5DC1, MOBP, MIR181A1HG, MYO1E, SLC9A9
# Negative:  MEG3, MIAT, DLGAP2, GRIN1, KIFC2, CABP1, CORO6, FRMPD4, NRGN, LINC00599
# 	   SRRM3, DLGAP1, CELF2, SYT1, ST6GALNAC5, CHD5, KCNIP4, PNMA3, MAPK11, RGS6
# 	   AL117329.1, KCNT1, GALNT17, FSTL4, KCNQ5, AJ009632.2, RBFOX3, ROBO2, LINGO2, STXBP5L
# PC_ 3
# Positive:  RGS4, NPTX1, NRGN, CALM3, DIRAS2, SULT4A1, PHYHIP, CPLX2, TUBA1B, SLC12A5
# 	   SLC17A7, TUBB2A, SNCB, STX1A, OLFM1, SYT4, SLC6A17, TSPYL1, BEX1, SLC25A22
# 	   NDRG4, PACSIN1, TMSB4X, HPCAL4, DIRAS1, STMN2, TMEM155, MAPK8IP2, ENC1, CTXN1
# Negative:  AC004852.2, BX284613.2, NRG3, KCNIP4, VCAN, MEGF11, NKAIN3, NXPH1, FAM155A, LRRTM4
# 	   CSMD1, LHFPL3, PDGFRA, PTPRZ1, PCDH15, NRXN1, DSCAM, CHST11, FGF14, SOX6
# 	   DPP10, SOX5, KCNMB2, CTNNA2, OPCML, GRIK1, RALYL, KCND2, GRIK2, DLGAP1
# PC_ 4
# Positive:  ROBO2, RBFOX1, KCNQ5, FRMPD4, RALYL, LINGO2, IQCJ-SCHIP1, RYR2, SYT1, KCNIP4
# 	   DLGAP2, NRG1, CDH12, KCNH7, TENM2, ADGRL2, CNTNAP2, CCSER1, RGS6, PDE4D
# 	   KCNB2, CHRM3, AL117329.1, NEGR1, AC011287.1, GALNT17, ST6GALNAC5, MTUS2, AGBL4, SNHG14
# Negative:  AC004852.2, MEGF11, BX284613.2, PDGFRA, VCAN, CHST11, SLC24A3, PTPRZ1, KCNIP1, NKAIN3
# 	   DGKG, LHFPL3, MIR3681HG, UST, PARD3, CABLES1, ADAMTS17, COL20A1, PCDH15, ATP1A2
# 	   SOX6, LINC00511, LUZP2, COL11A1, RFX4, GPR17, PITPNC1, LRMDA, PDE3A, PID1
# PC_ 5
# Positive:  PLEKHG1, ACSBG1, SLC5A11, AFF3, AL591115.1, LINC02343, DPYSL5, SEMA5A, SAMD4A, AL392086.3
# 	   DTNA, LINC00609, AL133304.3, RBFOX1, KCTD8, ZDHHC14, LDLRAD3, HIVEP3, RASGRF2, MACROD2
# 	   LINC01505, NAV2, PRKCA, TANC2, MSRA, HHATL, AL033523.1, AL589740.1, LINC00511, PRELID2
# Negative:  FCHSD2, LINC01608, NLGN1, PLXDC2, ANO4, PALM2-AKAP2, LAMA2, CTNND2, OPALIN, DYSF
# 	   HHIP, SVEP1, LRRC7, PPFIA2, ROR1, KANK1, FIGN, QDPR, ASTN2, ROBO1
# 	   SGK1, TIAM1, L3MBTL4, CCNH, TNIK, ERBB4, LPAR1, GNAO1, STARD13, LTBP1
#
# Warning message in asMethod(object):
# "sparse->dense coercion: allocating vector of size 4.2 GiB"
# [1] "Cell type name: Oli"

# %%
#saveRDS(rA,file = 'rA.rds')

# %%
R <- DIALOGUE.run(rA = rA, main = 'res',# list of cell.type objects
                  param = DLG.get.param( pheno = "Condition",k = 5, # number of MCPs to identify
                                        results.dir = results.dir,
                                        spatial.flag = F,plot.flag = T,
                                        conf = "cellQ"))
# Out:
# [1] "#************DIALOGUE Step I: PMD ************#"
# Warning message in dir.create(param$results.dir):
# "'./female_condition' already exists"
# [1] "ExN: Removing 0 of 30 features."
# [1] "Ast: Removing 0 of 30 features."
# [1] "Oli: Removing 0 of 30 features."
# [1] "Mic: Removing 0 of 30 features."
# [1] "End: Removing 0 of 30 features."
# [1] "OPC: Removing 0 of 30 features."
# [1] "InN: Removing 0 of 30 features."
# Warning message in cor(t(r@tpm), r@scores):
# "the standard deviation is zero"
# Warning message in cor(t(r@tpm), r@scores):
# "the standard deviation is zero"
# Warning message in cor(t(r@tpm), r@scores):
# "the standard deviation is zero"
# Warning message in cor(t(r@tpm), r@scores):
# "the standard deviation is zero"
# Warning message in cor(t(r@tpm), r@scores):
# "the standard deviation is zero"
# Warning message in cor(t(r@tpm), r@scores):
# "the standard deviation is zero"
# Warning message in cor(t(r@tpm), r@scores):
# "the standard deviation is zero"
# [1] "#************DIALOGUE Step II: HLM ************#"
# [1] "y ~ (1 | samples) + x + cellQ + tme.qc"
# [1] "#************DIALOGUE Step II (multilevel modeling): ExN vs. Ast ************#"
# [1] "5 MCPs identified for these cell types."
# [1] "#************DIALOGUE Step II (multilevel modeling): ExN vs. Oli ************#"
# [1] "5 MCPs identified for these cell types."
# [1] "#************DIALOGUE Step II (multilevel modeling): ExN vs. Mic ************#"
# [1] "3 MCPs identified for these cell types."
# [1] "#************DIALOGUE Step II (multilevel modeling): ExN vs. End ************#"
# [1] "3 MCPs identified for these cell types."
# Warning message in checkConv(attr(opt, "derivs"), opt$par, ctrl = control$checkConv, :
# "Model failed to converge with max|grad| = 0.00425566 (tol = 0.002, component 1)"
# [1] "#************DIALOGUE Step II (multilevel modeling): ExN vs. OPC ************#"
# [1] "5 MCPs identified for these cell types."
# Warning message in checkConv(attr(opt, "derivs"), opt$par, ctrl = control$checkConv, :
# "Model failed to converge with max|grad| = 0.00444194 (tol = 0.002, component 1)"
# [1] "#************DIALOGUE Step II (multilevel modeling): ExN vs. InN ************#"
# [1] "4 MCPs identified for these cell types."
# [1] "#************DIALOGUE Step II (multilevel modeling): Ast vs. Oli ************#"
# [1] "5 MCPs identified for these cell types."
# [1] "#************DIALOGUE Step II (multilevel modeling): Ast vs. Mic ************#"
# [1] "3 MCPs identified for these cell types."
# [1] "#************DIALOGUE Step II (multilevel modeling): Ast vs. End ************#"
# [1] "3 MCPs identified for these cell types."
# [1] "#************DIALOGUE Step II (multilevel modeling): Ast vs. OPC ************#"
# [1] "5 MCPs identified for these cell types."
# [1] "#************DIALOGUE Step II (multilevel modeling): Ast vs. InN ************#"
# [1] "4 MCPs identified for these cell types."
# [1] "#************DIALOGUE Step II (multilevel modeling): Oli vs. Mic ************#"
# [1] "3 MCPs identified for these cell types."
# Warning message in checkConv(attr(opt, "derivs"), opt$par, ctrl = control$checkConv, :
# "Model failed to converge with max|grad| = 0.00212252 (tol = 0.002, component 1)"
# [1] "#************DIALOGUE Step II (multilevel modeling): Oli vs. End ************#"
# [1] "3 MCPs identified for these cell types."
# [1] "#************DIALOGUE Step II (multilevel modeling): Oli vs. OPC ************#"
# [1] "5 MCPs identified for these cell types."
# Warning message in checkConv(attr(opt, "derivs"), opt$par, ctrl = control$checkConv, :
# "Model failed to converge with max|grad| = 0.00424794 (tol = 0.002, component 1)"
# [1] "#************DIALOGUE Step II (multilevel modeling): Oli vs. InN ************#"
# [1] "4 MCPs identified for these cell types."
# [1] "#************DIALOGUE Step II (multilevel modeling): Mic vs. End ************#"
# [1] "3 MCPs identified for these cell types."
# [1] "#************DIALOGUE Step II (multilevel modeling): Mic vs. OPC ************#"
# [1] "3 MCPs identified for these cell types."
# [1] "#************DIALOGUE Step II (multilevel modeling): Mic vs. InN ************#"
# [1] "2 MCPs identified for these cell types."
# [1] "#************DIALOGUE Step II (multilevel modeling): End vs. OPC ************#"
# [1] "3 MCPs identified for these cell types."
# [1] "#************DIALOGUE Step II (multilevel modeling): End vs. InN ************#"
# [1] "2 MCPs identified for these cell types."
# [1] "#************DIALOGUE Step II (multilevel modeling): OPC vs. InN ************#"
# [1] "4 MCPs identified for these cell types."
# [1] "#************Finalizing the scores************#"
# [1] "./female_condition//DIALOGUE2_res.rds"
# Warning message in cor.test.default(v1[, i], x, method = method, use = use, alternative = alternative):
# "Cannot compute exact p-value with ties"
# Warning message in cor.test.default(v1[, i], x, method = method, use = use, alternative = alternative):
# "Cannot compute exact p-value with ties"
# Plot with title "NNLS fitting - 0.333333333333333
# R = 0.91 P = 0e+00"
# Plot with title "NNLS fitting - 0.333333333333333
# R = 0.93 P = 0e+00"
# Plot with title "NNLS fitting - 0.5
# R = 0.72 P = 0e+00"
# Plot with title "NNLS fitting - 0.4
# R = 0.78 P = 0e+00"
# Plot with title "NNLS fitting - 0.5
# R = 0.88 P = 0e+00"
# Plot with title "NNLS fitting - 0.333333333333333
# R = 0.83 P = 0e+00"
# Plot with title "NNLS fitting - 0.333333333333333
# R = 0.89 P = 0e+00"
# Plot with title "NNLS fitting - 0.5
# R = 0.82 P = 0e+00"
# Plot with title "NNLS fitting - 0.4
# R = 0.84 P = 0e+00"
# Plot with title "NNLS fitting - 0.5
# R = 0.81 P = 0e+00"
# Plot with title "NNLS fitting - 0.333333333333333
# R = 0.84 P = 0e+00"
# Plot with title "NNLS fitting - 0.333333333333333
# R = 0.92 P = 0e+00"
# Plot with title "NNLS fitting - 0.4
# R = 0.84 P = 0e+00"
# Plot with title "NNLS fitting - 0.333333333333333
# R = 0.81 P = 0e+00"
# Plot with title "NNLS fitting - 0.333333333333333
# R = 0.89 P = 0e+00"
# Plot with title "NNLS fitting - 0.4
# R = 0.85 P = 0e+00"
# Plot with title "NNLS fitting - 0.333333333333333
# R = 0.94 P = 0e+00"
# Plot with title "NNLS fitting - 0.4
# R = 0.9 P = 0e+00"
# Plot with title "NNLS fitting - 0.333333333333333
# R = 0.84 P = 0e+00"
# Plot with title "NNLS fitting - 0.333333333333333
# R = 0.93 P = 0e+00"
# Plot with title "NNLS fitting - 0.5
# R = 0.86 P = 0e+00"
# Warning message in cor.test.default(v1[, i], x, method = method, use = use, alternative = alternative):
# "Cannot compute exact p-value with ties"
# Plot with title "NNLS fitting - 0.5
# R = 0.87 P = 0e+00"
# Plot with title "NNLS fitting - 0.333333333333333
# R = 0.92 P = 0e+00"
# Plot with title "NNLS fitting - 0.333333333333333
# R = 0.85 P = 0e+00"
# [1] "Removing MCP5"
# NULL
# NULL
# NULL
# `geom_line()`: Each group consists of only one observation.
# i Do you need to adjust the group aesthetic?
# [[1]]
# [[1]][[1]]
#
# [[1]][[2]]
#
#
# [[2]]
# [[2]][[1]]
#
# [[2]][[2]]
#
#
# [[3]]
# [[3]][[1]]
#
# [[3]][[2]]
#
#
# [[4]]
# [[4]][[1]]
#
# [[4]][[2]]
# Plot with title "NNLS fitting - 0.5
# R = 0.84 P = 0e+00"
# Plot with title "NNLS fitting - 0.5
# R = 0.98 P = 0e+00"

# %%
par(mfrow=c(1,2),oma = c(8, 1, 0, 5),xpd = T)
summary(R)

print(round(R$phenoZ,5))
# Out:
#                Length Class  Mode
# name             1    -none- character
# param           24    -none- list
# cell.types       7    -none- character
# k                8    -none- numeric
# emp.p          105    -none- numeric
# MCP.cell.types   5    -none- list
# gene.pval        7    -none- list
# pref            21    -none- list
# scores           7    -none- list
# MCPs.full        5    -none- list
# MCPs             5    -none- list
# phenoZ          40    -none- numeric
#         MCP1     MCP2    MCP3    MCP4     MCP5
# ExN -0.73238 -2.42360 2.32815 2.45801 -0.88217
# Ast -2.08719 -3.15114 1.93143 1.02342 -2.37447
# Oli -0.53197 -1.84365 2.02943 0.51622  0.91048
# Mic -0.74941 -2.51579 2.61775 1.04899 -0.62733
# End -1.67096 -1.53824 4.40768 1.46983 -1.37212
# OPC -0.80350 -2.69923 1.74367 1.06280  1.00811
# InN -1.08345 -1.53065 2.14522 1.67949 -0.48131
# All -1.04710 -2.99577 2.26532 1.95248 -0.69019

# %%
MCP1 = as.data.frame(do.call(cbind, R$MCPs$MCP1))
# Out:
# Warning message in (function (..., deparse.level = 1) :
# "number of rows of result is not a multiple of vector length (arg 1)"

# %%
head(MCP1,2)
# Out:
#   ExN.up     Ast.up     Oli.up     Mic.up End.up OPC.up     InN.up     ExN.down
# 1 AC002463.1 AC002463.1 AC009163.1 DNAJB1 A2M    AC002463.1 AC002463.1 ABCA10
# 2 AC016716.2 AC005520.5 ACTB       RPL18A ACTB   AC009163.1 AC016716.2 ABCA9
#   Mic.down End.down   OPC.down InN.down
# 1 MCF2L    1-Mar      AMZ1     4-Mar
# 2 P2RY12   AC008571.2 CACNA1A  ABCB9

# %%
write.csv(MCP1,file = './female_condition/MCP1.csv',row.names =F)

# %%
MCP2 = as.data.frame(do.call(cbind, R$MCPs$MCP2))
# Out:
# Warning message in (function (..., deparse.level = 1) :
# "number of rows of result is not a multiple of vector length (arg 1)"

# %%
write.csv(MCP2,file = './female_condition/MCP2.csv',row.names =F)

# %%
MCP3 = as.data.frame(do.call(cbind, R$MCPs$MCP3))
# Out:
# Warning message in (function (..., deparse.level = 1) :
# "number of rows of result is not a multiple of vector length (arg 1)"

# %%
write.csv(MCP3,file = './female_condition/MCP3.csv',row.names =F)

# %%
MCP4 = as.data.frame(do.call(cbind, R$MCPs$MCP4))
# Out:
# Warning message in (function (..., deparse.level = 1) :
# "number of rows of result is not a multiple of vector length (arg 1)"

# %%
write.csv(MCP4,file = './female_condition/MCP4.csv',row.names =F)

# %%
# MCP5 = as.data.frame(do.call(cbind, R$MCPs$MCP5))

# write.csv(MCP5,file = './female_condition/MCP5.csv',row.names =F)
