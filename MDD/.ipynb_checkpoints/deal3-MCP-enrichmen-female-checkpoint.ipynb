# %%
setwd('/import/GSE213982_fel/condition/')

# %%
MCP1 = read.csv('./MCP1.csv')

head(MCP1,3)

library(tidyverse)
library(dplyr)

gathered <- MCP1 %>% 
 pivot_longer(everything())

library('clusterProfiler')

group <- data.frame(gene=gathered$value,
                    group=gathered$name)

Gene_ID <- bitr(gathered$value, fromType="SYMBOL", 
            toType="ENTREZID", 
            OrgDb="org.Hs.eg.db")
data  <- merge(Gene_ID,group,by.x='SYMBOL',by.y='gene')


data_GO <- compareCluster(
  ENTREZID~group, 
  data=data, 
  fun="enrichGO", 
  OrgDb="org.Hs.eg.db",
  ont = "ALL",
  pAdjustMethod = "BH",
  pvalueCutoff = 0.05,
  qvalueCutoff = 0.5,
  readable = TRUE
)

options(repr.plot.height = 14,repr.plot.width = 12)

dotplot(data_GO)+ theme(axis.text.x = element_text(angle = 45, 
                                    vjust = 0.5, hjust=0.5))
ggsave(file = 'MCP1.pdf',height = 14,width = 12)
# Out:
#   ExN.up     Ast.up     Oli.up     Mic.up End.up OPC.up     InN.up
# 1 ABL1       ABLIM1     1-Mar      3-Mar  ABCB1  AC007376.2 ABCB9
# 2 AC004951.1 ABR        AC008571.2 ABCC4  ABLIM3 AC023282.1 ABLIM2
# 3 AC005225.2 AC002429.2 AC012494.1 ABR    ACER2  AC124254.2 AC004951.1
#   ExN.down   Ast.down   Oli.down   Mic.down   End.down   OPC.down   InN.down
# 1 AC002463.1 AC016716.2 AC016716.2 ABCA2      ACTB       AC004797.1 AC016716.2
# 2 AC004594.1 AC104827.1 AC068587.4 AC009041.2 ACTG1      AC012404.1 AC026202.2
# 3 AC004797.1 ACADVL     AC104827.1 AC092691.1 AL359091.1 AC015923.1 AC104827.1
# 'select()' returned 1:many mapping between keys and columns
#
# Warning message in bitr(gathered$value, fromType = "SYMBOL", toType = "ENTREZID", :
# "9.54% of input gene IDs are fail to map..."
# plot without title

# %%
write.csv(data_GO@compareClusterResult,file = 'MCP1.enrichment.csv',row.names =F)

# %%
MCP2 = read.csv('./MCP2.csv')
gathered <- MCP2 %>% 
 pivot_longer(everything())
group <- data.frame(gene=gathered$value,
                    group=gathered$name)
Gene_ID <- bitr(gathered$value, fromType="SYMBOL", 
            toType="ENTREZID", 
            OrgDb="org.Hs.eg.db")
data  <- merge(Gene_ID,group,by.x='SYMBOL',by.y='gene')
data_GO <- compareCluster(
  ENTREZID~group, 
  data=data, 
  fun="enrichGO", 
  OrgDb="org.Hs.eg.db",
  ont = "ALL",
  pAdjustMethod = "BH",
  pvalueCutoff = 0.05,
  qvalueCutoff = 0.5,
  readable = TRUE
)
options(repr.plot.height = 14,repr.plot.width = 12)
dotplot(data_GO)+ theme(axis.text.x = element_text(angle = 45, 
                                    vjust = 0.5, hjust=0.5))
ggsave(file = 'MCP2.pdf',height = 14,width = 12)
write.csv(data_GO@compareClusterResult,file = 'MCP2.enrichment.csv',row.names =F)
# Out:
# 'select()' returned 1:1 mapping between keys and columns
# plot without title

# %%
MCP3 = read.csv('./MCP3.csv')
gathered <- MCP3 %>% 
 pivot_longer(everything())
group <- data.frame(gene=gathered$value,
                    group=gathered$name)
Gene_ID <- bitr(gathered$value, fromType="SYMBOL", 
            toType="ENTREZID", 
            OrgDb="org.Hs.eg.db")
data  <- merge(Gene_ID,group,by.x='SYMBOL',by.y='gene')
data_GO <- compareCluster(
  ENTREZID~group, 
  data=data, 
  fun="enrichGO", 
  OrgDb="org.Hs.eg.db",
  ont = "ALL",
  pAdjustMethod = "BH",
  pvalueCutoff = 0.05,
  qvalueCutoff = 0.5,
  readable = TRUE
)
options(repr.plot.height = 14,repr.plot.width = 12)
dotplot(data_GO)+ theme(axis.text.x = element_text(angle = 45, 
                                    vjust = 0.5, hjust=0.5))
ggsave(file = 'MCP3.pdf',height = 14,width = 12)
write.csv(data_GO@compareClusterResult,file = 'MCP3.enrichment.csv',row.names =F)
# Out:
# 'select()' returned 1:1 mapping between keys and columns
#
# Warning message in bitr(gathered$value, fromType = "SYMBOL", toType = "ENTREZID", :
# "4.16% of input gene IDs are fail to map..."
# plot without title

# %%
MCP4 = read.csv('./MCP4.csv')
gathered <- MCP4 %>% 
 pivot_longer(everything())
group <- data.frame(gene=gathered$value,
                    group=gathered$name)
Gene_ID <- bitr(gathered$value, fromType="SYMBOL", 
            toType="ENTREZID", 
            OrgDb="org.Hs.eg.db")
data  <- merge(Gene_ID,group,by.x='SYMBOL',by.y='gene')
data_GO <- compareCluster(
  ENTREZID~group, 
  data=data, 
  fun="enrichGO", 
  OrgDb="org.Hs.eg.db",
  ont = "ALL",
  pAdjustMethod = "BH",
  pvalueCutoff = 0.05,
  qvalueCutoff = 0.5,
  readable = TRUE
)
options(repr.plot.height = 14,repr.plot.width = 12)
dotplot(data_GO)+ theme(axis.text.x = element_text(angle = 45, 
                                    vjust = 0.5, hjust=0.5))
ggsave(file = 'MCP4.pdf',height = 14,width = 12)
write.csv(data_GO@compareClusterResult,file = 'MCP4.enrichment.csv',row.names =F)
# Out:
# 'select()' returned 1:1 mapping between keys and columns
#
# Warning message in bitr(gathered$value, fromType = "SYMBOL", toType = "ENTREZID", :
# "2.85% of input gene IDs are fail to map..."
# plot without title

# %%
MCP5 = read.csv('./MCP5.csv')
gathered <- MCP5 %>% 
 pivot_longer(everything())
group <- data.frame(gene=gathered$value,
                    group=gathered$name)
Gene_ID <- bitr(gathered$value, fromType="SYMBOL", 
            toType="ENTREZID", 
            OrgDb="org.Hs.eg.db")
data  <- merge(Gene_ID,group,by.x='SYMBOL',by.y='gene')
data_GO <- compareCluster(
  ENTREZID~group, 
  data=data, 
  fun="enrichGO", 
  OrgDb="org.Hs.eg.db",
  ont = "ALL",
  pAdjustMethod = "BH",
  pvalueCutoff = 0.05,
  qvalueCutoff = 0.5,
  readable = TRUE
)
options(repr.plot.height = 14,repr.plot.width = 12)
dotplot(data_GO)+ theme(axis.text.x = element_text(angle = 45, 
                                    vjust = 0.5, hjust=0.5))
ggsave(file = 'MCP5.pdf',height = 14,width = 12)
write.csv(data_GO@compareClusterResult,file = 'MCP5.enrichment.csv',row.names =F)
# Out:
# 'select()' returned 1:1 mapping between keys and columns
#
# Warning message in bitr(gathered$value, fromType = "SYMBOL", toType = "ENTREZID", :
# "17.47% of input gene IDs are fail to map..."
# plot without title
