# %%
setwd('/import/GSE213982_fel/male_condition/')

# %%
MCP1 = read.csv('./MCP1.csv')

head(MCP1,3)

library(tidyverse)
library(dplyr)

gathered <- MCP1 %>% 
 pivot_longer(everything())

library('clusterProfiler')

group <- data.frame(gene=gathered$value,
                    group=gathered$name)

Gene_ID <- bitr(gathered$value, fromType="SYMBOL", 
            toType="ENTREZID", 
            OrgDb="org.Hs.eg.db")
data  <- merge(Gene_ID,group,by.x='SYMBOL',by.y='gene')


data_GO <- compareCluster(
  ENTREZID~group, 
  data=data, 
  fun="enrichGO", 
  OrgDb="org.Hs.eg.db",
  ont = "ALL",
  pAdjustMethod = "BH",
  pvalueCutoff = 0.05,
  qvalueCutoff = 0.5,
  readable = TRUE
)

options(repr.plot.height = 14,repr.plot.width = 12)

dotplot(data_GO)+ theme(axis.text.x = element_text(angle = 45, 
                                    vjust = 0.5, hjust=0.5))
ggsave(file = 'MCP1.pdf',height = 14,width = 12)
# Out:
#   Oli.up     End.up   OPC.up Ast.up Oli.down   End.down OPC.down ExN.down
# 1 AC079352.1 HSP90AA1 APOD   ACTG1  ADAM23     CSMD1    SNRNP70  MEG3
# 2 APLP1      HSPA1A   ASCL1  APOE   AL117329.1 MAST1    SNRNP70  SLC25A29
# 3 CLDND1     JUN      CNP    AQP4   ATRNL1     CSMD1    SNRNP70  MEG3
#   Ast.down
# 1 AC007368.1
# 2 AC011287.1
# 3 AC013287.1
# 'select()' returned 1:1 mapping between keys and columns
#
# Warning message in bitr(gathered$value, fromType = "SYMBOL", toType = "ENTREZID", :
# "4.92% of input gene IDs are fail to map..."

# %%
write.csv(data_GO@compareClusterResult,file = 'MCP1.enrichment.csv',row.names =F)

# %%
MCP2 = read.csv('./MCP2.csv')
gathered <- MCP2 %>% 
 pivot_longer(everything())
group <- data.frame(gene=gathered$value,
                    group=gathered$name)
Gene_ID <- bitr(gathered$value, fromType="SYMBOL", 
            toType="ENTREZID", 
            OrgDb="org.Hs.eg.db")
data  <- merge(Gene_ID,group,by.x='SYMBOL',by.y='gene')
data_GO <- compareCluster(
  ENTREZID~group, 
  data=data, 
  fun="enrichGO", 
  OrgDb="org.Hs.eg.db",
  ont = "ALL",
  pAdjustMethod = "BH",
  pvalueCutoff = 0.05,
  qvalueCutoff = 0.5,
  readable = TRUE
)
options(repr.plot.height = 14,repr.plot.width = 12)
dotplot(data_GO)+ theme(axis.text.x = element_text(angle = 45, 
                                    vjust = 0.5, hjust=0.5))
ggsave(file = 'MCP2.pdf',height = 14,width = 12)
write.csv(data_GO@compareClusterResult,file = 'MCP2.enrichment.csv',row.names =F)

# %%
MCP3 = read.csv('./MCP3.csv')
gathered <- MCP3 %>% 
 pivot_longer(everything())
group <- data.frame(gene=gathered$value,
                    group=gathered$name)
Gene_ID <- bitr(gathered$value, fromType="SYMBOL", 
            toType="ENTREZID", 
            OrgDb="org.Hs.eg.db")
data  <- merge(Gene_ID,group,by.x='SYMBOL',by.y='gene')
data_GO <- compareCluster(
  ENTREZID~group, 
  data=data, 
  fun="enrichGO", 
  OrgDb="org.Hs.eg.db",
  ont = "ALL",
  pAdjustMethod = "BH",
  pvalueCutoff = 0.05,
  qvalueCutoff = 0.5,
  readable = TRUE
)
options(repr.plot.height = 14,repr.plot.width = 12)
dotplot(data_GO)+ theme(axis.text.x = element_text(angle = 45, 
                                    vjust = 0.5, hjust=0.5))
ggsave(file = 'MCP3.pdf',height = 14,width = 12)
write.csv(data_GO@compareClusterResult,file = 'MCP3.enrichment.csv',row.names =F)

# %%
MCP4 = read.csv('./MCP4.csv')
gathered <- MCP4 %>% 
 pivot_longer(everything())
group <- data.frame(gene=gathered$value,
                    group=gathered$name)
Gene_ID <- bitr(gathered$value, fromType="SYMBOL", 
            toType="ENTREZID", 
            OrgDb="org.Hs.eg.db")
data  <- merge(Gene_ID,group,by.x='SYMBOL',by.y='gene')
data_GO <- compareCluster(
  ENTREZID~group, 
  data=data, 
  fun="enrichGO", 
  OrgDb="org.Hs.eg.db",
  ont = "ALL",
  pAdjustMethod = "BH",
  pvalueCutoff = 0.05,
  qvalueCutoff = 0.5,
  readable = TRUE
)
options(repr.plot.height = 14,repr.plot.width = 12)
dotplot(data_GO)+ theme(axis.text.x = element_text(angle = 45, 
                                    vjust = 0.5, hjust=0.5))
ggsave(file = 'MCP4.pdf',height = 14,width = 12)
write.csv(data_GO@compareClusterResult,file = 'MCP4.enrichment.csv',row.names =F)
# Out:
# 'select()' returned 1:1 mapping between keys and columns
#
# Warning message in bitr(gathered$value, fromType = "SYMBOL", toType = "ENTREZID", :
# "5.58% of input gene IDs are fail to map..."
# plot without title

# %%
# MCP5 = read.csv('./MCP5.csv')
# gathered <- MCP5 %>% 
#  pivot_longer(everything())
# group <- data.frame(gene=gathered$value,
#                     group=gathered$name)
# Gene_ID <- bitr(gathered$value, fromType="SYMBOL", 
#             toType="ENTREZID", 
#             OrgDb="org.Hs.eg.db")
# data  <- merge(Gene_ID,group,by.x='SYMBOL',by.y='gene')
# data_GO <- compareCluster(
#   ENTREZID~group, 
#   data=data, 
#   fun="enrichGO", 
#   OrgDb="org.Hs.eg.db",
#   ont = "ALL",
#   pAdjustMethod = "BH",
#   pvalueCutoff = 0.05,
#   qvalueCutoff = 0.5,
#   readable = TRUE
# )
# options(repr.plot.height = 14,repr.plot.width = 12)
# dotplot(data_GO)+ theme(axis.text.x = element_text(angle = 45, 
#                                     vjust = 0.5, hjust=0.5))
# ggsave(file = 'MCP5.pdf',height = 14,width = 12)
# write.csv(data_GO@compareClusterResult,file = 'MCP5.enrichment.csv',row.names =F)
# Out:
# 'select()' returned 1:1 mapping between keys and columns
#
# Warning message in bitr(gathered$value, fromType = "SYMBOL", toType = "ENTREZID", :
# "17.47% of input gene IDs are fail to map..."
# plot without title
