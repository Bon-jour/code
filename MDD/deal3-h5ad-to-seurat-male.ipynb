# %%
setwd('/import/GSE213982_fel/')

# %%
library(sceasy)
# Out:
# Loading required package: reticulate
#
# Warning message:
# "package 'reticulate' was built under R version 4.2.3"

# %%
h5ad_file = './res.h5ad'

# %%
sceasy::convertFormat(h5ad_file, from="anndata", to="seurat",
                       outFile='female.rds')
# Out:
# X -> counts
# An object of class Seurat
# 33562 features across 160711 samples within 1 assay
# Active assay: RNA (33562 features, 0 variable features)
#  2 layers present: counts, data
#  1 dimensional reduction calculated: umap

# %%
library(Seurat)
# Out:
# Warning message:
# "package 'Seurat' was built under R version 4.2.3"
# The legacy packages maptools, rgdal, and rgeos, underpinning the sp package,
# which was just loaded, will retire in October 2023.
# Please refer to R-spatial evolution reports for details, especially
# https://r-spatial.org/r/2023/05/15/evolution4.html.
# It may be desirable to make the sf package available;
# package maintainers should consider adding sf to Suggests:.
# The sp package is now running under evolution status 2
#      (status 2 uses the sf package in place of rgdal)
#
# Attaching SeuratObject

# %%
sce = readRDS('./female.rds')

# %%
DefaultAssay(sce) = 'RNA'

# %%
FeaturePlot(sce,features = 'VIM',raster = F)
# Out:
# plot without title

# %%
DimPlot(sce,raster=FALSE,group.by = 'celltype')
# Out:
# plot without title

# %%
library(future)
plan("multisession",workers = 40) # 使用multisession策略

# %%
options(future.globals.maxSize = 3987822434)

# %%
# Idents(sce) = 'celltype'
# FindMarkers(sce,ident.1= 'Oli' )
# Out:
#            p_val         avg_log2FC pct.1 pct.2 p_val_adj
# GABRD      0             -0.2563481 0.022 0.212 0
# KCNAB2     0             -0.3814669 0.048 0.330 0
# CHD5       0             -0.5677697 0.056 0.447 0
# TNFRSF25   0             -0.2894485 0.016 0.223 0
# CAMTA1     0             -0.2516717 0.408 0.645 0
# CLSTN1     0             -0.4928754 0.197 0.553 0
# FBXO44     0             -0.3349014 0.049 0.306 0
# KAZN       0             -0.5729981 0.431 0.742 0
# ATP13A2    0             -0.2662850 0.058 0.285 0
# PADI2      0              0.4624639 0.241 0.043 0
# IGSF21     0             -0.3740770 0.034 0.289 0
# MICOS10    0             -0.2791055 0.047 0.259 0
# RAP1GAP    0             -0.4407815 0.077 0.400 0
# LUZP1      0             -0.3952095 0.042 0.335 0
# CLIC4      0              0.5999640 0.319 0.060 0
# MAN1C1     0             -0.2513837 0.066 0.272 0
# STMN1      0             -0.2742110 0.206 0.436 0
# ATP5IF1    0             -0.2632270 0.056 0.261 0
# EPB41      0             -0.2565778 0.027 0.219 0
# ADGRB2     0             -0.3394417 0.064 0.319 0
# MARCKSL1   0              0.4947333 0.288 0.104 0
# SYNC       0             -0.2909545 0.040 0.252 0
# CSMD2      0             -0.2722697 0.155 0.378 0
# NCDN       0             -0.3715446 0.063 0.321 0
# GRIK3      0             -0.2618935 0.021 0.175 0
# COL9A2     0              0.3056082 0.154 0.027 0
# RIMS3      0             -0.2836690 0.031 0.250 0
# SCMH1      0             -0.3447854 0.137 0.419 0
# HIVEP3     0             -0.3198918 0.191 0.449 0
# RNF220     0              1.5998540 0.853 0.213 0
# ...        ...           ...        ...   ...   ...
# ZBED5      2.060305e-190 0.2771799  0.219 0.164 6.914797e-186
# VPS35L     9.558659e-186 0.2951598  0.329 0.298 3.208077e-181
# ADAM10     2.373708e-184 0.2898843  0.359 0.337 7.966638e-180
# TRPC4AP    4.860894e-178 0.2961967  0.311 0.275 1.631413e-173
# AC106791.1 7.756852e-173 0.2579311  0.196 0.144 2.603355e-168
# MEGF9      1.705246e-167 0.2921934  0.333 0.309 5.723147e-163
# ARHGEF2    2.563719e-166 0.2733570  0.227 0.179 8.604355e-162
# USP47      1.423579e-161 0.2627621  0.382 0.380 4.777815e-157
# TUBB4A     9.750694e-161 0.2610190  0.261 0.210 3.272528e-156
# NUTM2A-AS1 2.660327e-160 0.2857412  0.352 0.338 8.928590e-156
# ARHGAP22   1.200572e-158 0.2732949  0.257 0.211 4.029358e-154
# DIXDC1     1.002433e-156 0.2709887  0.257 0.213 3.364365e-152
# BACE1      2.268826e-156 0.2708374  0.228 0.182 7.614634e-152
# FANCL      3.427336e-155 0.2745905  0.246 0.202 1.150283e-150
# INF2       4.360453e-152 0.2628656  0.225 0.176 1.463455e-147
# ZNF652     1.053455e-148 0.2825670  0.312 0.284 3.535604e-144
# TUBA1A     2.786786e-146 0.2795683  0.319 0.287 9.353011e-142
# TTLL11     8.215408e-142 0.2619576  0.310 0.288 2.757255e-137
# AC118549.1 1.471122e-140 0.2612059  0.363 0.359 4.937380e-136
# CDK6       6.684743e-138 0.2635373  0.294 0.263 2.243534e-133
# FEZ1       1.216848e-135 0.2805078  0.309 0.284 4.083985e-131
# IFT80      4.239868e-127 0.2849241  0.263 0.233 1.422984e-122
# PPP1R21    1.574256e-121 0.2505032  0.348 0.345 5.283518e-117
# FCHSD2     3.241519e-121 0.2616445  0.388 0.398 1.087919e-116
# SLC13A3    7.687271e-114 0.2643756  0.269 0.244 2.580002e-109
# ANAPC5      6.600046e-99 0.2596457  0.324 0.319  2.215107e-94
# PTP4A2      7.918842e-96 0.2512098  0.275 0.253  2.657722e-91
# DNAJB2      4.777305e-92 0.2521697  0.287 0.264  1.603359e-87
# MTMR2       2.747537e-87 0.2550764  0.242 0.220  9.221283e-83
# TMEFF1      6.612467e-85 0.2508075  0.299 0.294  2.219276e-80

# %%
sce$group = substr(sce$sample,1,1)

# %%
table(sce$sample)
# Out:
#    F1    F2    F3    F4    F5    F6    F7    F8    F9   F10   F11   F12   F13
#  3864  1843  2211  5599  6413   512   516  2655  1639  2147  2405  1948  1360
#   F14   F15   F16   F17   F18   F19   F20   F21   F22   F23   F24   F25   F26
#  3453  3454   571  5671   849   942  1045  1215   957   972  1053  2756   957
#   F27   F28   F29   F30   F31   F32   F33   F34   F35   F36   F37   F38    M1
#   846  1250  2136   748  1261  1351  4110  2483  4583  3266   954  1658  2863
#    M2    M3    M4    M5    M6    M7    M8    M9   M10   M11   M12   M13   M14
#  2038  1388  2428  1307  2665  2264  1926  1320  2530  3901  2169  2182  1838
#   M15   M16   M17   M18   M19   M20   M21   M22   M23   M24 M24_2   M26   M27
#  3815  1274  3579  1560  2579  4430  2175  2121  4059   691   672  1944  1201
#   M28   M29   M30   M31   M32   M33   M34
#  2389  2087  2237  3305  2566  2363  3192

# %%
groupinfo = read.table('./groupinfo.txt',header =T,sep = '\t')

# %%
Idents(sce)  ='sample'

# %%
for(i in 1:nrow(groupinfo)){
  sce@meta.data[which(sce@meta.data$sample == groupinfo$sample[i]),'Condition'] <- groupinfo$Condition[i]}

# %%
scRNA = sce

# %%
scedata = scRNA
table(sce$Condition)#查看各组细胞数
# Out:
#    Case Control
#   93273   67438

# %%
saveRDS(sce,file = 'final.rds')

# %%
scedata = sce

# %%
Idents(scedata) = 'celltype'

# %%
prop.table(table(Idents(scedata)))
# Out:
#        Ast        End        ExN        InN        Mic        Mix        OPC
# 0.08219724 0.02456584 0.48197074 0.17631649 0.02329648 0.02364493 0.04777520
#        Oli
# 0.14023309

# %%
table(Idents(scedata), scedata$Condition)#各组不同细胞群细胞数
# Out:
#
#        Case Control
#   Ast  5819    7391
#   End  2207    1741
#   ExN 46914   30544
#   InN 16112   12224
#   Mic  2465    1279
#   Mix  2262    1538
#   OPC  3682    3996
#   Oli 13812    8725

# %%
Cellratio <- prop.table(table(Idents(scedata), scedata$Condition), margin = 2)#计算各组样本不同细胞群比例
Cellratio <- as.data.frame(Cellratio)

# %%
Cellratio$Var2 = factor(Cellratio$Var2,levels = c('Control','Case'))

allcolour=c("#DC143C","#0000FF","#20B2AA","#FFA500","#9370DB","#98FB98","#F08080","#1E90FF","#7CFC00","#FFFF00",
            "#808000","#FF00FF","#FA8072","#7B68EE","#9400D3","#800080","#A0522D","#D2B48C","#D2691E","#87CEEB","#40E0D0","#5F9EA0",
            "#FF1493","#0000CD","#008B8B","#FFE4B5","#8A2BE2","#228B22","#E9967A","#4682B4","#32CD32","#F0E68C","#FFFFE0","#EE82EE",
            "#FF6347","#6A5ACD","#9932CC","#8B008B","#8B4513","#DEB887")
library(ggplot2)
# ggplot(Cellratio) + 
#   geom_bar(aes(x =Var2, y= Freq, fill = Var1),stat = "identity",width = 0.7,size = 0.5,colour = '#222222')+ 
#   theme_classic() +
#   labs(x='Sample',y = 'Ratio')+
#   scale_fill_manual(values = allcolour)+
#   theme(panel.border = element_rect(fill=NA,color="black", size=0.5, linetype="solid"))

library(Seurat)
library(ggplot2)
library(dplyr)
library(ggalluvial)

# %%
ggplot(Cellratio, aes(x =Var2, y= Freq, fill = Var1,
                  stratum=Var1, alluvium=Var1)) +
  geom_col(width = 0.5, color='black')+
  geom_flow(width=0.5,alpha=0.4, knot.pos=0.5)+ # 参数knot.pos设置为0.5使连接为曲线面积，就像常见的桑基图
  theme_classic() +
  labs(x='Sample',y = 'Ratio')+
  scale_fill_manual(values = allcolour) + theme(axis.text.x = element_text(angle = 45, 
 vjust = 0.5, hjust=0.5))
# Out:
# plot without title

# %%
ggsave('figure2.pdf',height =  5,width = 4)

# %% [markdown]
# ## DA analysis

# %%
merged = as.SingleCellExperiment(sce)
abundances <- table(merged$celltype, merged$sample) 
abundances <- unclass(abundances) 
#library(scater)
library(SingleCellExperiment)
colLabels(merged) <- sce$celltype
# Out:
# Warning message:
# "package 'SingleCellExperiment' was built under R version 4.2.2"
# Loading required package: SummarizedExperiment
#
# Warning message:
# "package 'SummarizedExperiment' was built under R version 4.2.2"
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
# Warning message:
# "package 'matrixStats' was built under R version 4.2.3"
#
# Attaching package: 'matrixStats'
#
#
# The following object is masked from 'package:dplyr':
#
#     count
#
#
#
# Attaching package: 'MatrixGenerics'
#
#
# The following objects are masked from 'package:matrixStats':
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# Loading required package: GenomicRanges
#
# Warning message:
# "package 'GenomicRanges' was built under R version 4.2.3"
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: 'BiocGenerics'
#
#
# The following objects are masked from 'package:dplyr':
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from 'package:stats':
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from 'package:base':
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
# Warning message:
# "package 'S4Vectors' was built under R version 4.2.3"
#
# Attaching package: 'S4Vectors'
#
#
# The following objects are masked from 'package:dplyr':
#
#     first, rename
#
#
# The following objects are masked from 'package:base':
#
#     I, expand.grid, unname
#
#
# Loading required package: IRanges
#
# Warning message:
# "package 'IRanges' was built under R version 4.2.3"
#
# Attaching package: 'IRanges'
#
#
# The following objects are masked from 'package:dplyr':
#
#     collapse, desc, slice
#
#
# Loading required package: GenomeInfoDb
#
# Warning message:
# "package 'GenomeInfoDb' was built under R version 4.2.3"
# Loading required package: Biobase
#
# Warning message:
# "package 'Biobase' was built under R version 4.2.3"
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#
# Attaching package: 'Biobase'
#
#
# The following object is masked from 'package:MatrixGenerics':
#
#     rowMedians
#
#
# The following objects are masked from 'package:matrixStats':
#
#     anyMissing, rowMedians
#
#
#
# Attaching package: 'SummarizedExperiment'
#
#
# The following object is masked from 'package:SeuratObject':
#
#     Assays
#
#
# The following object is masked from 'package:Seurat':
#
#     Assays

# %%
merged
# Out:
# class: SingleCellExperiment
# dim: 33562 160711
# metadata(0):
# assays(2): counts logcounts
# rownames(33562): MIR1302-2HG AL627309.1 ... AC007325.4 AC007325.2
# rowData names(0):
# colnames(160711): F1.AAACCCACACCTCTGT-1.Mic.Mic1
#   F1.AAACCCATCGGCATTA-1.ExN.ExN7 ... M9.TTTGTCACATGCCTTC-1.InN.InN5_SST
#   M9.TTTGTCATCCTCAACC-1.Oli.Oli2
# colData names(19): orig.ident nCount_RNA ... ident label
# reducedDimNames(1): UMAP
# mainExpName: RNA
# altExpNames(0):

# %%
library(DESeq2)
library(limma)
library(edgeR)

# %%
table(colLabels(merged), merged$Condition)

extra.info <- colData(merged)[match(colnames(abundances), merged$sample),]

y.ab <- DGEList(abundances, samples=extra.info)

keep <- filterByExpr(y.ab, group=y.ab$samples$Condition)
y.ab <- y.ab[keep,]

design <- model.matrix(~factor(celltype) + factor(Condition), y.ab$samples)
y.ab <- estimateDisp(y.ab, design, trend="none")
# Out:
#
#        Case Control
#   Ast  5819    7391
#   End  2207    1741
#   ExN 46914   30544
#   InN 16112   12224
#   Mic  2465    1279
#   Mix  2262    1538
#   OPC  3682    3996
#   Oli 13812    8725

# %%
fit.ab <- glmQLFit(y.ab, design, robust=TRUE, abundance.trend=FALSE)
res <- glmQLFTest(fit.ab, coef=ncol(design))
summary(decideTests(res))

    diff=topTags(res)$table

diff$logFC = -(diff$logFC)
# Out:
#        factor(Condition)Control
# Down                          0
# NotSig                        6
# Up                            2

# %%
padj = 0.05
foldChange = 0


    diff$group = as.factor(ifelse(diff$PValue < padj & abs(diff$logFC) >= foldChange, 
                                 ifelse(diff$logFC> foldChange ,'Up','Down'),'NoSignifi'))
    table(diff$group)
    res = diff

library("edgeR")  
    library(dplyr)
    library(ggrepel)
    library(ggplot2)
    library(cowplot)
# Out:
#      Down NoSignifi        Up
#         2         5         1

# %%
    res$group<-factor(res$group,levels=c("Down","NoSignifi","Up"))

    
    top_5 <- bind_rows(   
      res %>%
        filter(group == 'Up') %>%
        arrange(PValue, desc(logFC)) %>%
        head(5),
      res %>%
        filter(group == 'Down') %>%
        arrange(PValue, desc(logFC)) %>%
        head(5)
    )
    ggplot(data=res,aes(x=logFC,y=-log10(PValue)))+
    geom_point(aes(color=group),size=2)+
    geom_hline(yintercept = -log10(0.05), linetype="dashed",color="grey30")+
    geom_vline(xintercept = c(0),linetype="dashed",color="grey30")+
    geom_text_repel(data=top_5,aes(x= logFC,y= -log10(PValue),label= rownames(top_5)))+
    scale_color_manual(values = c("blue","grey80","red"))+
    theme_half_open() 
ggsave('Volcano.pdf',height = 8,width = 8)
# Out:
# plot without title

# %% [markdown]
# ### 鉴定MCP

# %%
setwd('/import/GSE213982_fel/')
library(DIALOGUE)
library(Seurat)
sce = readRDS('./final.rds')
table(sce$celltype)
# Out:
#   Ast   End   ExN   InN   Mic   Mix   OPC   Oli
# 13210  3948 77458 28336  3744  3800  7678 22537

# %%
Idents(sce) = 'group'
male = subset(sce,idents  = 'M')

# %%
male
# Out:
# An object of class Seurat
# 33562 features across 79058 samples within 1 assay
# Active assay: RNA (33562 features, 0 variable features)
#  1 dimensional reduction calculated: umap

# %%
Idents(male) <- "celltype"
# Downsample the number of cells per identity class
#ob1 <- subset(x = male, downsample = 500)
ob1 = male
library(Seurat)
ob1 <- FindVariableFeatures(ob1, selection.method = "vst", nfeatures = 5000)
ob1
# Out:
# An object of class Seurat
# 33562 features across 79058 samples within 1 assay
# Active assay: RNA (33562 features, 5000 variable features)
#  1 dimensional reduction calculated: umap

# %%
set.seed(123)
# Simulating data based on Seurat object of PBMCs
obj<-ob1
obj@meta.data$samples <- obj@meta.data$sample
obj@meta.data$cell.subtypes<-obj@meta.data$celltype
b1<-is.element(obj@meta.data$cell.subtypes,c("Ast",'InN'))
b2<-is.element(obj@meta.data$cell.subtypes,c("Mic","Mix"))
b3<-is.element(obj@meta.data$cell.subtypes,c('End', 'ExN'))
b4<-is.element(obj@meta.data$cell.subtypes,c("OPC","Oli"))




obj@meta.data$samples[b1] <- sample(obj@meta.data$sample, size = sum(b1), replace =FALSE)
obj@meta.data$samples[b2] <- sample(obj@meta.data$sample, size = sum(b2), replace =FALSE)
obj@meta.data$samples[b3] <- sample(obj@meta.data$sample, size = sum(b3), replace =FALSE)
obj@meta.data$samples[b4] <- sample(obj@meta.data$sample, size = sum(b4), replace =FALSE)

DIALOGUE_make.cell.type.seurat<- function(obj, cell.subtypes, name){
  # Given a Seurat object with "cell.subtypes" and "samples" information provided in the meta.data field
  
  if(is.null(obj@meta.data$cell.subtypes)){return("Cell subtypes information is missing")}
  if(is.null(obj@meta.data$samples)){return("Sample information is missing")}
  
  sub_obj<- subset(x = obj,cells = rownames(obj@meta.data)[is.element(obj@meta.data$cell.subtypes,cell.subtypes)])
  sub_obj<- NormalizeData(sub_obj,normalization.method = "LogNormalize", scale.factor = 100000)
  sub_obj<-FindVariableFeatures(sub_obj,selection.method = "vst", nfeatures = 6000)
  sub_obj<-ScaleData(sub_obj)
  sub_obj<-RunPCA(sub_obj,npcs = 30) 
  
  tpm<- as.matrix(sub_obj@assays$RNA@data)
  
  X<- sub_obj@reductions$pca@cell.embeddings
  assertthat::are_equal(rownames(X),colnames(tpm))
  n_cells<- ncol(tpm)
  samples<- sub_obj@meta.data$sample
  n_count<- as.vector(scale(log(sub_obj@meta.data$nCount_RNA)))
  metadata<- data.frame(nFeatures = sub_obj@meta.data$nFeature_RNA,
                        samples = samples,
                        group = sub_obj@meta.data$group,
                        Condition = sub_obj@meta.data$Condition,
                        cell.subtypes = as.character(sub_obj@meta.data$cell.subtypes))
  r<-make.cell.type(name = name ,tpm,samples,X,metadata, cellQ = n_count)
  return(r)
}

# %%
r1<- DIALOGUE_make.cell.type.seurat(obj, cell.subtypes = c('ExN'), name = "ExN")
r2<- DIALOGUE_make.cell.type.seurat(obj, cell.subtypes = c("Ast"), name = "Ast")
r3<- DIALOGUE_make.cell.type.seurat(obj, cell.subtypes = c("InN"), name = "InN")
r4<- DIALOGUE_make.cell.type.seurat(obj, cell.subtypes = c("Mic"), name = "Mic")
r5<- DIALOGUE_make.cell.type.seurat(obj, cell.subtypes = c("End"), name = "End")
r6<- DIALOGUE_make.cell.type.seurat(obj, cell.subtypes = c("OPC"), name = "OPC")
r7<- DIALOGUE_make.cell.type.seurat(obj, cell.subtypes = c("Oli"), name = "Oli")

rA<- list(Oli = r7,Mic= r4,End= r5,OPC = r6, ExN = r1,Ast = r2,InN = r3)  # 
library(DIALOGUE)
results.dir = './male_condition/'
# Out:
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  MALAT1, KCNIP4, LRRTM4, TENM2, IQCJ-SCHIP1, IL1RAPL1, LRP1B, DPP10, AC009041.2, ROBO2
# 	   LINC02306, LINGO2, ARL17B, PDZD2, LINC01515, CTNNA2, LINC02153, LTK, PDGFD, MEIS2
# 	   AC134312.4, LINC01500, ADAMTS9-AS2, CNTNAP5, AP001825.1, PAX2, AC117503.1, SLC25A21, HS6ST3, ATP4A
# Negative:  NEFL, TUBB2A, RAB3A, CFL1, TUBA1B, NDUFA4, GAPDH, PCSK1N, SELENOW, HSP90AA1
# 	   NGRN, PEBP1, COX6A1, TMSB10, UQCRH, ATP6V1F, SOD1, TPI1, STMN2, CYCS
# 	   BEX1, CALM3, OAZ1, DYNLL1, GNG3, ATP6V0C, BEX3, ATP6AP2, UQCR10, COX6B1
# PC_ 2
# Positive:  GAPDH, PPP2R1A, RAB3A, TUBB2A, PPIA, NEFL, ALDOC, HSP90AB1, TUBB4A, TUBB
# 	   ATP6V0C, NAP1L3, PRDX2, UBB, PNMA8B, FAIM2, GNG3, B4GAT1, CTSD, ATP6AP1
# 	   CFL1, ACTG1, PGAM1, PCP4, PEBP1, LDHA, TUBB3, NEFH, ACTB, SNCB
# Negative:  IL1RAPL1, IQCJ-SCHIP1, LINGO2, DGKB, RGS6, LRRTM4, AC011287.1, TMEM108, TMEM132D, AP001825.1
# 	   TAFA1, CACNA2D3, TENM2, AC107223.1, PCDH9-AS2, DPYD, DAB1, CNTN4, CDH18, GRM7
# 	   RFX3, LRRC4C, GPC6, AC092691.1, AC110296.1, GRIK2, HS6ST3, EPHA6, LINC00513, AC013287.1
# PC_ 3
# Positive:  CBLN2, PDZD2, LINC02306, SERPINE2, CDH9, AC009041.2, TESPA1, ENC1, RASGRF2, LINC00507
# 	   GNAL, HS6ST3, CUX2, KCNIP2, STXBP6, PCDH8, EPHA6, KCNMB2, LAMP5, KCTD16
# 	   CDH12, MEIS2, ROBO1, CAMK2N1, AL132633.1, AC008574.1, HOPX, CA10, DGKB, LINC02822
# Negative:  IL1RAPL2, FOXP2, AC109466.1, AC008415.1, TSHZ2, RORB, TOX, RXFP1, TLL1, CPNE4
# 	   CASC15, TRMT9B, FSTL5, PTPRT, SLC35F1, CLSTN2, POU6F2, FNBP1L, AL109930.1, TMTC2
# 	   NRG1, DCC, PDZRN4, HS3ST4, PHLDB2, CNTN5, RORA, GABRG3, PTCHD4, PCDH11X
# PC_ 4
# Positive:  PKD1, ACAP3, KIFC2, SNRNP70, WASHC1, MRPL41, GPC1, PDIA2, SHC2, DPP7
# 	   CORO6, NSMF, CHD5, ARFGAP1, TUBGCP6, TNK2, PABPN1, RGS11, SOHLH1, ABCA7
# 	   MVD, MAPK11, ACADVL, TMEM259, QTRT1, GP1BB, LENG8, PCBP4, LINC00599, KAT2A
# Negative:  AC110296.1, PCDH9-AS2, AC027288.3, SNAP25-AS1, AC091885.2, PDE5A, NECAB1, CHRM3-AS2, AC090579.1, P2RY14
# 	   SPARCL1, ZFPM2-AS1, RPL7, NDUFA4, RTN4, LINC00513, ATP5MD, GAP43, AC008696.2, HOPX
# 	   C1orf56, ATP5MPL, KCTD16, PTPRK, RPL34, HSP90AA1, UQCRB, AC008574.1, SERPINI1, COX6C
# PC_ 5
# Positive:  RORB, COL5A2, NTNG1, AJ009632.2, UNC5D, PTPRK, CNTN5, PLCH1, LAMA2, TAFA1
# 	   GRM7, COBLL1, SLC38A11, DCC, PTPRT, IQCJ-SCHIP1, RMST, AC109466.1, LINC02296, POU6F2
# 	   AC008415.1, SEMA6D, AC246817.1, CUX2, ST6GALNAC5, AC117453.1, KCNH5, PARM1, TNNT2, TRHDE
# Negative:  KIAA1217, SEMA3E, SDK1, HS3ST4, MEIS2, DLC1, ITGA8, DGKG, PCSK5, IFNG-AS1
# 	   LHFPL3, ZNF385D, RPS6KA2, HTR2C, NFIA, BCL11B, DSCAML1, TLE4, PCDH11Y, NXPH2
# 	   CCN2, MCTP2, LINC02153, GRIK3, ZNF385D-AS2, AL133346.1, CALN1, SULF1, PDZRN4, PLXDC2
#
# Warning message in asMethod(object):
# "sparse->dense coercion: allocating vector of size 11.0 GiB"
# [1] "Cell type name: ExN"
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  DSCAM, FGF14, MDGA2, SNTG1, FGF12, CSMD1, IL1RAPL1, OPCML, NLGN1, RIMS2
# 	   ATRNL1, ANKS1B, RALYL, CNTNAP2, KAZN, NEGR1, CCSER1, KCNQ5, PTPRD, NRXN3
# 	   GRIK2, FRMPD4, NKAIN2, CNTN5, KCNIP4, LINGO2, IQCJ-SCHIP1, HS6ST3, RBFOX1, ROBO2
# Negative:  NDRG2, LINC01785, FGFR3, AL121894.2, IGFN1, NXNL1, MUC1, CRYBB3, LINC02123, AL590617.2
# 	   REN, AC245100.6, AC003666.1, AC005840.4, GSTZ1, AC083864.5, XIST, AC000085.1, SLC12A4, LGR6
# 	   AC006459.1, AC110769.2, IBA57-DT, ATP6V1FNB, CCN4, AL022162.1, HSPA1L, AC007950.2, MMEL1, AC105450.1
# PC_ 2
# Positive:  MDGA2, DSCAM, FGF12, NLGN1, OPCML, SNTG1, IL1RAPL1, KAZN, DCLK1, CCSER1
# 	   CSMD1, FRMPD4, KCNQ5, RIMS2, DLGAP1, GRID2, RALYL, ATRNL1, GRIN1, LINGO2
# 	   CAMK2A, CNTN5, CNTNAP2, HS6ST3, ROBO2, SYT1, DPP6, RBFOX1, FGF14, NRG1
# Negative:  HPSE2, PREX2, OBI1-AS1, RYR3, TPD52L1, CDH20, AL589740.1, ZNF98, NKAIN3, SLC4A4
# 	   FBXL7, SLCO1C1, ARHGAP24, LSAMP-AS1, LINC00299, CARMIL1, ATP1A2, AL137139.2, BMPR1B, CACNB2
# 	   TRPS1, PARD3, HEPN1, NHSL1, AC092691.1, RANBP3L, LINC00499, SLC14A1, MSI2, NFIA
# PC_ 3
# Positive:  GFAP, SERPINA3, HILPDA, CRYAB, CLU, AQP1, ANGPTL4, MT1X, IFITM3, MT2A
# 	   AQP4, ITM2B, GADD45B, AGT, APOE, MT1G, ZFP36, DEPP1, ID3, CD44
# 	   MT1M, MT1E, HSPA1A, GAPDH, CST3, CHI3L1, TNC, HSP90AA1, S100B, GJA1
# Negative:  HPSE2, SGCD, PLCB1, PDE4D, CACNB2, FRMD4A, FLRT2, COL5A3, RIMS2, MACROD2
# 	   TENM2, SNTG1, RBFOX1, CSMD1, MDGA2, LRRC4C, LRRTM4, FRMPD4, KCNIP4, OPCML
# 	   AC092691.1, CCSER1, ANKS1B, ARHGAP24, RALYL, IL1RAPL1, KCNQ5, GRIA2, FGF12, FGF14
# PC_ 4
# Positive:  COL5A3, NDRG2, GLUL, NAT8L, SDC4, GPR37L1, APOE, TTYH1, HTRA1, ATP1B2
# 	   ADGRG1, BSG, FGFR3, GRIN2C, MICALL2, HPSE2, ITM2C, CKB, KCNJ10, LCNL1
# 	   DGKZ, SLC1A4, OLFM2, PLXNB1, PSAP, CABLES1, WIF1, HEPACAM, B4GALNT4, SERPINE2
# Negative:  DPP10, ID3, TNC, AC012405.1, SLC38A1, FOS, LINC00609, WDR49, AC093610.1, VCAN
# 	   JUN, JUNB, TJP2, IGFBP5, GFAP, PRKG1, DPP10-AS3, CRYAB, AC073941.1, GPC6
# 	   SPARC, SERPINI2, GLIS3, PFKFB2, 1-Dec, APLNR, CFAP47, DCLK1, PLXDC2, LINC01411
# PC_ 5
# Positive:  HILPDA, SERPINA3, DEPP1, ANGPTL4, ZFP36, CHI3L1, SNAP25, TMSB10, MT1X, SRPX2
# 	   RPL34, AP000462.1, GADD45B, PCDH9-AS2, AQP1, CCK, RPL38, HEPN1, RPL31, SYT1
# 	   FTL, HSP90AA1, PLCB1, RIMS2, ATP1B1, C1orf56, NRXN3, KCNQ5, RPL11, CHN1
# Negative:  DOCK8, FGFR3, ADAM28, LCNL1, APBB1IP, CSF1R, HIP1R, PLXDC2, SLC25A18, MTSS2
# 	   ARHGEF4, COL16A1, FYB1, MMD2, PTPRC, NDRG2, AC007325.2, PLXNB1, METRN, PFKFB2
# 	   MFGE8, WASHC1, ID3, DAAM2, SEMA5A, EMID1, SNORC, LRMDA, NSMF, LCAT
#
# Warning message in asMethod(object):
# "sparse->dense coercion: allocating vector of size 1.4 GiB"
# [1] "Cell type name: Ast"
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  SOX6, KIAA1217, NXPH1, SPARCL1, PRKG1, TAC1, TMEM132C, CNTNAP3B, SLC9A9, DPP10
# 	   SLIT2, TENM1, RASGRF2, GRIK3, SULF1, AC093610.1, SATB1-AS1, SOX5, SATB1, GPC6
# 	   RSPO2, KIF26B, PVALB, ADAMTS17, CPLX1, DTNA, SCN1A-AS1, SLC24A2, MMP16, EYS
# Negative:  ADARB2, CXCL14, NFIB, DSCAM, KCNT2, RGS12, LINGO2, PROX1, CNTNAP4, CCK
# 	   DOCK10, NRXN1, VIP, FXYD6, CHRM3, AL589740.1, NEDD4L, CNR1, SYNPR, AP1S2
# 	   NRG1, ARPP21, EGFR, CCNH, NFIX, KIT, DLX6-AS1, NR2F2-AS1, NKAIN3, DGKB
# PC_ 2
# Positive:  VIP, TAC3, SYNPR, CALB2, ROBO1, SHISA8, CHRNA2, GALNTL6, AC013265.1, SLC22A3
# 	   NR2F2-AS1, ASIC4, L3MBTL4, RGS12, ADAM33, ROBO2, RGS6, CHRM3, AL589740.1, AL391832.4
# 	   KMO, GRID2, PDE4B, GRM7, PDE3A, COL21A1, ADAMTS6, TSHZ2, PROX1, AC016766.1
# Negative:  NXPH1, MYO16, FGF13, PTCHD4, UNC5D, GRM5, PTPRT, GAD2, PTPRM, MCTP1
# 	   UNC5C, SV2C, BCL11B, GRIA4, LAMP5, FBXL7, DPP6, ALK, NTNG1, SPHKAP
# 	   KCTD16, TRPC3, LUZP2, SPOCK1, RBMS3, GOLIM4, FMN1, EYA4, CACNA2D1, RAB3C
# PC_ 3
# Positive:  FBXL7, EYA4, SV2C, KIT, LAMP5, TRPC3, AC132803.1, PRELID2, PDGFD, NTNG1
# 	   FGF13, CPLX3, AC137770.1, NXPH2, PTPRT, CACNA2D1, UNC13C, SPHKAP, ID2, CA2
# 	   FREM1, HPCAL1, NRG1, ATP11C, ARHGAP31, LINC00298, ROR2, LINC01344, FSTL5, TPD52L1
# Negative:  KCNMB2, HS6ST3, KCNMB2-AS1, SNTG1, OXR1, ASIC2, ZNF804A, KHDRBS2, KIAA1217, LRRTM4
# 	   SPOCK3, SLC44A5, NPAS3, FRMD5, PDE4B, GRM7, PLXNA4, VWC2L, TENM2, PCDH7
# 	   PTPRE, EDIL3, NEAT1, KLF12, MMP16, LINC01322, CALN1, ZFPM2, CDH10, PLD5
# PC_ 4
# Positive:  SST, PDE1A, TRHDE, RALYL, SYNPR, GRIK1, CACNA2D3, ROBO1, COL25A1, SLC8A1
# 	   GRM1, LINC01122, PLCH1, GRID2, MAN1A1, ST6GALNAC5, PCDH11X, EPHB6, NETO1, CDH8
# 	   STXBP6, PCDH11Y, CHRM3, NMU, SHISA6, PAWR, GRIN3A, WLS, PCDH15, GPC6
# Negative:  ERBB4, LRRC4C, ZNF804A, GRIA4, SDK1, MYO16, CALN1, ZNF536, HS6ST3, SHISA9
# 	   NEAT1, PLD5, TAFA2, AC093610.1, TMEM132C, INPP4B, SLC9A9, PLCXD3, ADAMTS17, PVALB
# 	   PLXNA4, SOX5, KCNH7, BTBD11, CNTNAP5, CSMD3, RARB, PLCL1, AC092422.1, SGK1
# PC_ 5
# Positive:  GAPDH, ACTB, CKB, PHYHIP, YWHAG, PPIA, ZBTB18, CALM3, SNCB, PEBP1
# 	   HSP90AB1, TMSB4X, NAP1L3, VIP, CLU, VAMP2, ATP6V0C, CAMK2N1, PKM, NRGN
# 	   JUND, NBL1, CPLX2, CDK5R1, CALM2, PCP4, BEX3, PTMA, EEF1A1, PRNP
# Negative:  GRIK2, KCTD16, INPP4B, EPHA6, DCC, ZNF385B, ENOX1, ZMAT4, MGAT4C, SPOCK3
# 	   XKR4, SGO1-AS1, AC139720.1, NKAIN2, MSRA, MTUS2, PTPRM, GRIK1, DPP6, SLC44A5
# 	   EXT1, SLC8A1, NR2F2-AS1, NLGN1, ADAMTS9-AS2, ROBO1, AL136114.1, IL1RAPL2, AC092691.1, LRFN5
#
# Warning message in asMethod(object):
# "sparse->dense coercion: allocating vector of size 4.4 GiB"
# [1] "Cell type name: InN"
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  SPP1, AC131944.1, FYB1, C1QB, ARHGAP24, C1QC, HAMP, B2M, LPAR6, TMSB4X
# 	   PTPRC, LYN, SLC11A1, CD74, FCGR3A, APOE, TLR2, DOCK8, CYBA, NFATC2
# 	   C3, FTL, S100A11, SLC1A3, ADAM28, C1QA, SRGN, S100A8, TYMP, PFN1
# Negative:  IL1RAPL1, PCDH9, MAGI2, CADM2, NLGN1, LSAMP, NRXN3, ANKS1B, DLG2, NCAM2
# 	   PTPRD, LRP1B, OPCML, NRXN1, FAM155A, NTM, PPP2R2B, CSMD1, SNTG1, CTNNA2
# 	   FGF14, NRG3, ADGRB3, CNTNAP2, ERBB4, LRRC4C, LRRTM4, DLGAP1, CTNNA3, NPAS3
# PC_ 2
# Positive:  RPS6, GAPDH, NRGN, ISG15, SNAP25, S100A8, CHN1, TMSB10, TUBA1B, SYT1
# 	   CALM1, RPL37A, ATP5F1E, CLU, RPS18, RPL35, MAP1B, ATP5MD, RPL23A, ACTB
# 	   HAMP, RPS15, STMN2, RPLP1, SERF2, CALM2, YWHAH, RPS24, RPL31, GPM6A
# Negative:  ELMO1, DLEU1, AC120193.1, ST18, LPAR1, PLP1, LINC01374, SFMBT2, TMEM144, SYNDIG1
# 	   MAML3, CSGALNACT1, LINC01608, CERCAM, MOG, DOCK10, AL359091.1, FAM177B, ZSWIM6, RNF220
# 	   DIP2A, A2M, FOXP2, TBXAS1, FOXN3, ATP8B4, ZBTB20, CTNNA3, KCNH8, NAALADL2
# PC_ 3
# Positive:  FGF14, RALYL, ROBO2, TENM2, PLCB1, DLGAP1, KCNIP4, RBFOX1, SYT1, SNTG1
# 	   NRG1, OPCML, GPM6A, SNHG14, MEG3, NRG3, STMN2, FAM155A, MAP1B, CSMD1
# 	   CNTNAP2, LRRTM4, SDK1, SLC7A8, AC120193.1, MACROD2, RAB6B, CELF2, MERTK, TMF1
# Negative:  PLP1, ST18, CERCAM, MBP, AL359091.1, TMEM144, LINC01608, SLC44A1, CNP, CTNNA3
# 	   SCD, CLDN11, EDIL3, MOG, PTGDS, KCNH8, RNF220, TF, FAM107B, CARNS1
# 	   PPP2R2B, PDE4B, MAG, SLC24A2, PIP4K2A, AC012494.1, LINC01170, LINC00609, CNTN2, SIK3
# PC_ 4
# Positive:  PLP1, TUBB2A, AC011586.2, ST18, TMEM144, SLC24A2, YWHAH, SNAP25, MAP1B, STMN2
# 	   NEFL, CNP, MOG, CALM1, LINC01608, COX6A1, MYRF, CERCAM, PLPP2, PCP4
# 	   LGALS1, CALM2, CLDN11, TF, SCD, NEFM, MAG, ATP1B1, AC012494.1, FAM107B
# Negative:  CTNNA2, LRRC4C, NRG3, CSMD1, NRXN1, GPC5, LHFPL3, PCDH15, PTPRZ1, SNTG1
# 	   SLC1A2, FGF14, NPAS3, TENM2, FAM155A, NXPH1, OPCML, VCAN, LRRTM4, PLCB1
# 	   COL5A3, CNTN5, ADGRV1, KCNIP4, LRP1B, GRIK1, DLGAP1, MIR99AHG, MEG3, ARHGAP26
# PC_ 5
# Positive:  CNTNAP2, RALYL, ANKS1B, MCF2L2, GRIK1, DLGAP1, OXR1, PTPRD, SNTG1, FGF14
# 	   NKAIN2, NRXN3, NLGN1, OPCML, IL1RAPL1, SNAP25, LRRTM4, CNTN5, SYT1, NRG1
# 	   EXT1, ADGRB3, PLCB1, FAM49B, ROBO2, NCAM2, PLCL2, LPCAT3, ARL15, DIAPH2-AS1
# Negative:  FGFR3, PTGDS, COL5A3, F3, GPC5, HPSE2, SLC1A2, ADGRV1, GLI3, GFAP
# 	   NDRG2, EMX2, ENTPD2, IGFBP7, AL137139.2, AGT, ACSS1, SLC25A18, GLUL, ID2
# 	   SMTN, ATP1A2, CCL2, AC007325.2, PHF2, SH3BP2, WFS1, AC092924.2, SLC16A9, HIST2H2AA4
# [1] "Cell type name: Mic"
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  MDGA2, FGF14, AC092691.1, DCC, SNTG1, NRG1, RGS7, LRP1B, KAZN, KCNH7
# 	   FLRT2, GRIA2, AGBL4, ANKS1B, LRRTM4, RIMS2, NRXN1, PPP2R2B, LRRC7, CABP1
# 	   RYR2, DSCAM, KCNQ5, NLGN1, ERC2, CSMD1, NPAS3, ST6GALNAC5, NAV3, GRIK2
# Negative:  CLDN5, IFI27, B2M, FLT1, A2M, ABCB1, ITM2A, TMSB10, MT2A, ATP10A
# 	   ADIRF, SLC2A1, TBC1D4, VWF, IFITM3, ST6GALNAC3, MECOM, ABCG2, ID1, PTPRB
# 	   RGCC, CGNL1, SLC7A5, SERF2, HLA-E, EEF1A1, TMEM123, HLA-A, ST6GAL1, HLA-B
# PC_ 2
# Positive:  PRKG1, ATP1A2, LAMA2, DLC1, GPC5, COLEC12, SLC6A1, SLC6A12, SLC38A11, EPS8
# 	   AL138828.1, PDE7B, GRM8, SLC30A10, PTN, PDGFRB, PDE8B, DCN, NR2F2-AS1, SLC19A1
# 	   HES4, SLC12A7, TRPC3, ARHGAP42, PTPRK, KCNE4, GRM3, NOTCH3, SLC1A3, MUSTN1
# Negative:  SLC7A5, CLDN5, ABCB1, FLT1, ATP10A, SPOCK2, SLC7A1, SLC39A10, SPOCK3, AGBL4
# 	   MYRIP, TSPAN5, LIMCH1, NRG1, MECOM, SYNE1, EGFL7, ESYT2, GPCPD1, SNTG1
# 	   ST6GALNAC3, MDGA2, NRXN1, SORBS2, RALYL, PODXL, RGS7, NRG3, VWF, PTPRB
# PC_ 3
# Positive:  LINC01088, IQGAP2, HSD11B1, PRRX1, ABCA10, CTHRC1, AC046195.1, KCNMB1, KCNIP1, LYPLAL1-DT
# 	   AP001172.1, THBS2, AL359546.1, SLC16A12-AS1, KCNK2, SLC6A20, JHY, ALDH1A2, ASPN, KLHL41
# 	   MCTP2, CACNA2D3-AS1, SLC7A14-AS1, COL15A1, LINC01011, AL359317.2, BHMT2, SLC8B1, ABCA6, SLC35E2B
# Negative:  CRIP1, IFITM3, HIGD1B, LGALS1, HES4, RPS19, NDUFA4L2, CPE, TSC22D1, RPS6
# 	   RPLP1, COL5A3, INPP4B, MYL6, YBX3, HSPB1, GAPDH, ATP5F1E, CNTN4, MYL9
# 	   STOM, ZFP36, CTNNA3, APOLD1, CACNB2, SERF2, SPARC, SGIP1, RPS15, TXNIP
# PC_ 4
# Positive:  GPC5, RGS5, SLC19A1, RGS4, ADGRB3, GRM3, HIGD1B, GRM8, ADGRL3, GJC1
# 	   ARHGAP35, BSG, NOTCH3, GRM7, PDE8B, ERBB4, UBFD1, DPP10, GPER1, TRPC3
# 	   MUSTN1, ADARB2, ARRB1, ABCC9, HIBCH, ANO3, IDH3G, RTN4RL1, SLC12A7, KCNMB2
# Negative:  LINC01088, HSD11B1, IQGAP2, BICC1, CEMIP, SLC6A20, KCNMB1, KCNK2, KCNIP1, PRRX1
# 	   CYP1B1, CLDN11, FHL2, KCNK17, CYP1B1-AS1, PDZRN3, ALDH1A2, AC046195.1, ABCA10, PLXNC1
# 	   FLRT2, RNF220, FGF13, AC011503.1, FMO2, TNXB, BHMT2, SLC16A12, TPCN1, SGCD
# PC_ 5
# Positive:  TNFRSF6B, ANXA2, ADAMTS9, ADAMTS1, SLCO4A1, C11orf96, DEPP1, CEBPD, CLDN11, IFITM1
# 	   EMP1, ZMAT3, CST3, CACNA1H, C15orf39, CP, IL1RL1, HILPDA, THYN1, C19orf53
# 	   GADD45B, GFAP, AL022328.4, MT1X, ATP1B1, STARD4, CRISPLD2, MRGPRF, KIFC2, COL15A1
# Negative:  ST6GAL1, MECOM, MRPS6, SPOCK3, SLC5A3, SLCO1A2, GPCPD1, MYRIP, GRM3, SLC7A5
# 	   SRGAP2, VCAN, PTPRB, CGNL1, LRMDA, LIMCH1, ABCB1, SYNE1, SOX5, SYNE2
# 	   AC233296.1, EXOC6, EMCN, LINC01376, SGMS1, TMEM132C, TNC, ARHGAP18, C14orf93, INPP4B
# [1] "Cell type name: End"
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  XIST, CDH24, CU634019.5, IDUA, VIL1, AKT1S1, DOLK, NUDT16, FZD10-AS1, GSTM2
# 	   PLXNB3, AC021504.1, G6PC2, REEP4, C14orf178, AC025038.1, AL096870.8, AC008969.2, PEG13, AC093673.2
# 	   NABP2, HSPG2, PCDHB10, MYO7A, FAM201A, KIF18B, POP4, AC025171.4, CILP, AL158212.2
# Negative:  FRMPD4, CCSER1, CNTNAP5, KCNMA1, N4BP2L2, ANK3, AUTS2, NKAIN2, NBEA, NEGR1
# 	   TENM2, TBC1D5, NAV3, MBD5, EXOC4, PHACTR1, PCDH9-AS2, THRB, RIMS2, RGS7
# 	   MYCBP2, STXBP5L, DAB1, PDE4D, APBB2, LRFN5, NEBL, EIF4G3, LRRC7, SNHG14
# PC_ 2
# Positive:  ADAM33, AC008080.4, PLP1, CDK18, TENM2, GRIN1, CAMK2A, FRMPD4, ST18, SYT1
# 	   CLDN11, ENC1, CERCAM, KCNQ5, EPB41L2, NKAIN2, ABCA2, FRMD4A, MYRF, CAMK2N1
# 	   NRGN, IDS, MBP, ROBO2, PTGDS, MEF2C, ATP1B1, DNAJB2, BMPER, CALM1
# Negative:  SLC35F1, KCNMB2, SNTG1, AC004852.2, FGF14, KCNMB2-AS1, SOX5, CHST11, CSMD3, AGAP1
# 	   LUZP2, EPN2, PDZRN4, NKAIN3, BRINP3, DCC, KCND2, NXPH1, PDGFRA, GRIK1
# 	   XYLT1, SEZ6L, BX284613.2, SGCZ, KIF13A, AC092691.1, TMEM132C, DISC1, CA10, ZEB1
# PC_ 3
# Positive:  AC008080.4, ADAM33, PLP1, CLDN11, GPR17, CDK18, ST18, MYRF, AL359091.1, TNS3
# 	   LINC01170, AC044781.1, BCAS1, EPHB1, RASGEF1B, SCRG1, MDFI, SEMA5B, MARCKSL1, FIBIN
# 	   FYN, CRB1, ABTB2, MBP, ZNF488, SOX4, UGT8, SLC44A1, BMPER, BCAN
# Negative:  FRMPD4, TENM2, ROBO2, KCNQ5, IQCJ-SCHIP1, CAMK2A, GRIN1, UNC5D, MEF2C, SYT1
# 	   NKAIN2, IDS, ZNF804B, NRGN, OXR1, GALNTL6, CELF2, RALYL, ENC1, NRXN3
# 	   CNTN5, CNTNAP2, BASP1, STXBP5L, INTS1, SNTG1, CNTN4, CAMK2N1, SNAP25, UNC79
# PC_ 4
# Positive:  ST18, ADAM33, AC008080.4, CDK18, CLDN11, FRMD4A, PLP1, MMD2, IQCJ-SCHIP1, EPB41L2
# 	   GPC5, AUTS2, NKAIN2, BMPER, ROBO2, TENM2, PPP2R3B, AL359091.1, AC068587.4, AC009041.2
# 	   FRMPD4, GALNTL6, USP54, KCNQ5, FRMD5, KANSL1, ANKS1B, KAZN, CERCAM, PHACTR1
# Negative:  CST3, MT2A, APOD, ACTB, MARCKSL1, GAPDH, FTH1, ITM2B, B2M, MARCKS
# 	   MT1E, CALM2, CALM1, HSP90AA1, NRGN, MT3, ISG15, ITM2C, TMSB10, ASCL1
# 	   TMSB4X, RPL41, ATP1B2, IFI6, OLIG1, FABP5, CD81, FOS, GFAP, YWHAH
# PC_ 5
# Positive:  COL5A3, NDRG2, FGFR3, C1orf61, ADGRV1, PTGDS, EMX2, COL20A1, RAPGEF3, PLXNB1
# 	   TNK2, MICALL2, GLUL, HIP1R, SLC25A18, LCNL1, PRDM16-DT, SNX22, ACSS1, RPL13
# 	   MYO15B, PAQR6, ADGRB1, CSPG4, MTSS2, SNRNP70, LRP1, ACAP3, SLC25A29, HTRA1
# Negative:  FRMPD4, KCNQ5, ENC1, YWHAH, ATP1B1, SYT1, MAP1B, TMSB10, BMPER, ZNF804B
# 	   C1orf56, CCK, CALM2, EPB41L2, ROBO2, AC008080.4, RBFOX1, RTN4, TENM2, SNAP25
# 	   UNC5D, OXR1, RASGEF1B, PDGFA, TMSB4X, PHACTR1, PHYHIPL, KHDRBS2, NRXN3, ADAM33
# [1] "Cell type name: OPC"
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  TMEM144, CNP, MOBP, RNF220, DOCK10, TF, TMTC2, CRYAB, PPP1R14A, ENPP2
# 	   PHLPP1, AL359091.1, FRMD4B, SCD, DBNDD2, TMEM165, NCKAP5, CLDN11, SPP1, SOX2-OT
# 	   DOCK5, PLCL1, LINC00609, SPOCK3, UGT8, TCF12, AC012494.1, SELENOP, FRYL, UNC5C
# Negative:  DLGAP1, FAM155A, OPCML, CELF2, PLCB1, FGF14, CCSER1, NRG3, TENM2, ATRNL1
# 	   KCNQ5, DSCAM, SNTG1, FRMD4A, MEF2C, CSMD1, RALYL, GPM6A, NRXN1, DPP10
# 	   SYT1, CAMK2A, RGS7, KCNIP4, ROBO2, CTNNA2, LRRTM4, CNTN5, ENC1, RBFOX1
# PC_ 2
# Positive:  FGF14, DSCAM, FAM155A, CCSER1, NRG3, SNTG1, CSMD1, PDE4D, OPCML, MDGA2
# 	   FRMD4A, LRRTM4, TENM2, RGS7, NRXN1, CTNNA2, RALYL, ATRNL1, DLGAP1, RBFOX1
# 	   CNTN5, ROBO2, KCNQ5, PLCB1, NAV3, NEGR1, LRRC4C, KAZN, DCC, FTX
# Negative:  MANBAL, TMEM185B, LINC01098, DDX54, ACBD7, CHAC1, NLE1, RELT, NFATC1, PTRHD1
# 	   KIF19, ZNF784, LINC02199, MTRNR2L1, AC016571.1, ZNF606, RDH10, YBX2, MTRNR2L10, NUDT17
# 	   AC009318.4, MUSTN1, RDH16, AC026726.1, ADAMTS14, LINC00351, GNG11, AL135784.1, AF250324.1, TACSTD2
# PC_ 3
# Positive:  S100B, STMN1, ACTB, COL18A1, TMSB4X, RBFOX1, CRYAB, ACSBG1, C4orf48, GAPDH
# 	   PEBP1, TUBA1B, MARCKSL1, CALM2, LINC00609, TUBA1A, MAP1B, PPP1R14A, AL591115.1, TUBB4A
# 	   SPP1, NRGN, ENC1, CALM1, AL133304.3, SLC5A11, ATP1B1, FEZ1, PDE1A, PTMA
# Negative:  NLGN1, FCHSD2, PLXDC2, LINC01608, ANO4, PALM2-AKAP2, AUTS2, ERBB4, CTNND2, LAMA2
# 	   SGK1, OPALIN, ASTN2, KCNH8, NRXN3, FIGN, EXOC6B, ERBIN, 1-Mar, STARD13
# 	   HHIP, KANK1, PHLPP1, CCNH, ROBO1, CREB5, ADGRL3, PPFIA2, MAML2, SVEP1
# PC_ 4
# Positive:  LINC00609, RBFOX1, SLC5A11, COL18A1, LRP2, MAN2A1, AL133304.3, HHATL, AC008571.2, PIEZO2
# 	   SYNJ2, LMCD1-AS1, ACSBG1, DPYD, AL591115.1, CNTNAP4, ZDHHC20, SLC25A13, LINC01505, MVB12B
# 	   PCSK6, KCTD8, FTX, ITGA2, OTUD7A, ST6GALNAC3, SLC7A14-AS1, LRRC63, SAMD12, PWRN1
# Negative:  FTH1, CNP, QDPR, ACTB, PTMA, FTL, OPALIN, CD9, GAPDH, LAMP2
# 	   DBNDD2, SELENOW, APLP1, APOD, SCD, VAMP2, PEBP1, GLUL, CALM2, ITM2B
# 	   ATP1B1, SNAP25, CALM1, GPRC5B, PLLP, NRGN, MAG, TMSB4X, RPS27, CSRP1
# PC_ 5
# Positive:  VCAN, DOCK8, PTPRZ1, LRMDA, LHFPL3, PCDH15, ARHGAP24, SOX6, FGFR3, COL5A3
# 	   ADAM28, SLC1A2, C3, LPAR6, TBXAS1, BCAN, NXPH1, CST3, CSF1R, APOE
# 	   GRIK1, CD74, RAPGEF3, PLXNB1, BNC2, MYO15B, MLC1, CERCAM, NDRG2, MAML2
# Negative:  KCNQ5, RALYL, SNAP25, VSNL1, CHN1, ENC1, SYT1, PPP3CA, PHACTR1, CALM2
# 	   YWHAH, MAP1B, CAMK2A, RTN1, NEGR1, PPFIA2, LRRC7, PCP4, RTN3, CCSER1
# 	   TENM2, FTH1, ATP1B1, ROBO2, TMSB10, PALM2-AKAP2, CNTNAP2, DPYD, LRRTM3, NRGN
#
# Warning message in asMethod(object):
# "sparse->dense coercion: allocating vector of size 1.5 GiB"
# [1] "Cell type name: Oli"

# %%
#saveRDS(rA,file = 'rA.rds')

# %%
R <- DIALOGUE.run(rA = rA, main = 'res',# list of cell.type objects
                  param = DLG.get.param(  pheno = "Condition",k = 5, # number of MCPs to identify
                                        results.dir = results.dir,
                                        spatial.flag = F,plot.flag = T,
                                        conf = "cellQ"))
# Out:
# [1] "#************DIALOGUE Step I: PMD ************#"
# Warning message in dir.create(param$results.dir):
# "'./male_condition' already exists"
# [1] "Oli: Removing 1 of 30 features."
# [1] "Mic: Removing 12 of 30 features."
# [1] "End: Removing 17 of 30 features."
# [1] "OPC: Removing 0 of 30 features."
# [1] "ExN: Removing 0 of 30 features."
# [1] "Ast: Removing 0 of 30 features."
# [1] "InN: Removing 0 of 30 features."
# Warning message in cor(t(r@tpm), r@scores):
# "the standard deviation is zero"
# Warning message in cor(t(r@tpm), r@scores):
# "the standard deviation is zero"
# Warning message in cor(t(r@tpm), r@scores):
# "the standard deviation is zero"
# Warning message in cor(t(r@tpm), r@scores):
# "the standard deviation is zero"
# Warning message in cor(t(r@tpm), r@scores):
# "the standard deviation is zero"
# Warning message in cor(t(r@tpm), r@scores):
# "the standard deviation is zero"
# Warning message in cor(t(r@tpm), r@scores):
# "the standard deviation is zero"
# Warning message in dir.create(paste0(param$results.dir, "/DIALOGUE2_", main)):
# "'./male_condition//DIALOGUE2_res' already exists"
# [1] "#************DIALOGUE Step II: HLM ************#"
# [1] "y ~ (1 | samples) + x + cellQ + tme.qc"
# [1] "#************DIALOGUE Step II (multilevel modeling): Oli vs. Mic ************#"
# [1] "1 MCPs identified for these cell types."
# [1] "#************DIALOGUE Step II (multilevel modeling): Oli vs. End ************#"
# [1] "1 MCPs identified for these cell types."
# [1] "#************DIALOGUE Step II (multilevel modeling): Oli vs. OPC ************#"
# [1] "3 MCPs identified for these cell types."
# [1] "#************DIALOGUE Step II (multilevel modeling): Oli vs. ExN ************#"
# [1] "4 MCPs identified for these cell types."
# [1] "#************DIALOGUE Step II (multilevel modeling): Oli vs. Ast ************#"
# [1] "4 MCPs identified for these cell types."
# [1] "#************DIALOGUE Step II (multilevel modeling): Oli vs. InN ************#"
# [1] "4 MCPs identified for these cell types."
# [1] "#************DIALOGUE Step II (multilevel modeling): Mic vs. End ************#"
# [1] "1 MCPs identified for these cell types."
# [1] "#************DIALOGUE Step II (multilevel modeling): Mic vs. OPC ************#"
# [1] "1 MCPs identified for these cell types."
# [1] "#************DIALOGUE Step II (multilevel modeling): Mic vs. ExN ************#"
# [1] "1 MCPs identified for these cell types."
# [1] "#************DIALOGUE Step II (multilevel modeling): Mic vs. Ast ************#"
# [1] "1 MCPs identified for these cell types."
# [1] "#************DIALOGUE Step II (multilevel modeling): Mic vs. InN ************#"
# [1] "1 MCPs identified for these cell types."
# [1] "#************DIALOGUE Step II (multilevel modeling): End vs. OPC ************#"
# [1] "1 MCPs identified for these cell types."
# [1] "#************DIALOGUE Step II (multilevel modeling): End vs. ExN ************#"
# [1] "1 MCPs identified for these cell types."
# [1] "#************DIALOGUE Step II (multilevel modeling): End vs. Ast ************#"
# [1] "1 MCPs identified for these cell types."
# [1] "#************DIALOGUE Step II (multilevel modeling): End vs. InN ************#"
# [1] "1 MCPs identified for these cell types."
# [1] "#************DIALOGUE Step II (multilevel modeling): OPC vs. ExN ************#"
# [1] "4 MCPs identified for these cell types."
# [1] "#************DIALOGUE Step II (multilevel modeling): OPC vs. Ast ************#"
# [1] "4 MCPs identified for these cell types."
# [1] "#************DIALOGUE Step II (multilevel modeling): OPC vs. InN ************#"
# [1] "4 MCPs identified for these cell types."
# [1] "#************DIALOGUE Step II (multilevel modeling): ExN vs. Ast ************#"
# [1] "5 MCPs identified for these cell types."
# [1] "#************DIALOGUE Step II (multilevel modeling): ExN vs. InN ************#"
# [1] "5 MCPs identified for these cell types."
# [1] "#************DIALOGUE Step II (multilevel modeling): Ast vs. InN ************#"
# [1] "5 MCPs identified for these cell types."
# [1] "#************Finalizing the scores************#"
# [1] "./male_condition//DIALOGUE2_res.rds"
# Plot with title "NNLS fitting - 0.333333333333333
# R = 0.8 P = 0e+00"
# Plot with title "NNLS fitting - 0.333333333333333
# R = 0.8 P = 0e+00"
# Warning message in cor.test.default(v1[, i], x, method = method, use = use, alternative = alternative):
# "Cannot compute exact p-value with ties"
# Plot with title "NNLS fitting - 0.333333333333333
# R = 0.79 P = 0e+00"
# Plot with title "NNLS fitting - 0.5
# R = 0.81 P = 0e+00"
# Plot with title "NNLS fitting - 0.333333333333333
# R = 0.92 P = 0e+00"
# Plot with title "NNLS fitting - 0.5
# R = 0.89 P = 0e+00"
# Plot with title "NNLS fitting - 0.333333333333333
# R = 0.92 P = 0e+00"
# Plot with title "NNLS fitting - 0.5
# R = 0.85 P = 0e+00"
# [1] "Removing MCP3"
# [1] "Removing MCP4"
# [1] "Removing MCP5"
# [1] "Removing MCP3"
# [1] "Removing MCP4"
# [1] "Removing MCP5"
# NULL
# NULL
# NULL
# [[1]]
# [[1]][[1]]
#
# [[1]][[2]]
#
#
# [[2]]
# [[2]][[1]]
#
# [[2]][[2]]
# Plot with title "NNLS fitting - 0.333333333333333
# R = 0.88 P = 0e+00"
# Plot with title "NNLS fitting - 0.5
# R = 0.83 P = 0e+00"

# %%
par(mfrow=c(1,2),oma = c(8, 1, 0, 5),xpd = T)
summary(R)

print(round(R$phenoZ,5))
# Out:
#                Length Class  Mode
# name             1    -none- character
# param           24    -none- list
# cell.types       7    -none- character
# k                8    -none- numeric
# emp.p          105    -none- numeric
# MCP.cell.types   5    -none- list
# gene.pval        7    -none- list
# pref            21    -none- list
# scores           7    -none- list
# MCPs.full        5    -none- list
# MCPs             5    -none- list
# phenoZ          40    -none- numeric
#         MCP1    MCP2     MCP3    MCP4     MCP5
# Oli -0.38026 1.21506 -0.71831 2.37959 -0.55883
# Mic  0.30380 2.54402  0.69593 1.29338 -1.02875
# End -0.91030 1.39665  0.60008 0.53130 -1.39964
# OPC -0.97104 1.00881 -0.35361 1.88657 -0.57978
# ExN -0.79030 1.18905  0.67771 1.61997 -1.22151
# Ast -0.99144 2.17138 -0.58137 1.56535 -0.46346
# InN  0.44818 1.58954  0.65329 2.14570 -1.40595
# All -0.54522 1.53010  0.57741 1.65007 -1.11976

# %%
MCP1 = as.data.frame(do.call(cbind, R$MCPs$MCP1))
# Out:
# Warning message in (function (..., deparse.level = 1) :
# "number of rows of result is not a multiple of vector length (arg 1)"

# %%
head(MCP1,2)
# Out:
#   Oli.up     End.up   OPC.up Ast.up Oli.down   End.down OPC.down ExN.down
# 1 AC079352.1 HSP90AA1 APOD   ACTG1  ADAM23     CSMD1    SNRNP70  MEG3
# 2 APLP1      HSPA1A   ASCL1  APOE   AL117329.1 MAST1    SNRNP70  SLC25A29
#   Ast.down
# 1 AC007368.1
# 2 AC011287.1

# %%
write.csv(MCP1,file = './male_condition/MCP1.csv',row.names =F)

# %%
MCP2 = as.data.frame(do.call(cbind, R$MCPs$MCP2))
# Out:
# Warning message in (function (..., deparse.level = 1) :
# "number of rows of result is not a multiple of vector length (arg 2)"

# %%
write.csv(MCP2,file = './male_condition/.MCP2.csv',row.names =F)

# %%
MCP3 = as.data.frame(do.call(cbind, R$MCPs$MCP3))
# Out:
# Error in do.call(cbind, R$MCPs$MCP3): second argument must be a list
# Traceback:
#
# 1. as.data.frame(do.call(cbind, R$MCPs$MCP3))
# 2. do.call(cbind, R$MCPs$MCP3)
# 3. stop("second argument must be a list")

# %%
write.csv(MCP3,file = './male_condition/.MCP3.csv',row.names =F)
# Out:
# Error in is.data.frame(x): object 'MCP3' not found
# Traceback:
#
# 1. write.csv(MCP3, file = "./male_condition/.MCP3.csv", row.names = F)
# 2. eval.parent(Call)
# 3. eval(expr, p)
# 4. eval(expr, p)
# 5. utils::write.table(MCP3, file = "./male_condition/.MCP3.csv",
#  .     row.names = F, col.names = TRUE, sep = ",", dec = ".", qmethod = "double")
# 6. is.data.frame(x)

# %%
MCP4 = as.data.frame(do.call(cbind, R$MCPs$MCP4))
# Out:
# Error in do.call(cbind, R$MCPs$MCP4): second argument must be a list
# Traceback:
#
# 1. as.data.frame(do.call(cbind, R$MCPs$MCP4))
# 2. do.call(cbind, R$MCPs$MCP4)
# 3. stop("second argument must be a list")

# %%
write.csv(MCP4,file = './male_condition/.MCP4.csv',row.names =F)
# Out:
# Error in is.data.frame(x): object 'MCP4' not found
# Traceback:
#
# 1. write.csv(MCP4, file = "./male_condition/.MCP4.csv", row.names = F)
# 2. eval.parent(Call)
# 3. eval(expr, p)
# 4. eval(expr, p)
# 5. utils::write.table(MCP4, file = "./male_condition/.MCP4.csv",
#  .     row.names = F, col.names = TRUE, sep = ",", dec = ".", qmethod = "double")
# 6. is.data.frame(x)

# %%
MCP5 = as.data.frame(do.call(cbind, R$MCPs$MCP5))
# Out:
# Error in do.call(cbind, R$MCPs$MCP5): second argument must be a list
# Traceback:
#
# 1. as.data.frame(do.call(cbind, R$MCPs$MCP5))
# 2. do.call(cbind, R$MCPs$MCP5)
# 3. stop("second argument must be a list")

# %%
write.csv(MCP5,file = './male_condition/.MCP5.csv',row.names =F)
