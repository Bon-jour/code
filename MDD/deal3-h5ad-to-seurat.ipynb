# %%
setwd('/import/GSE213982_fel/')

# %%
library(sceasy)
# Out:
# Loading required package: reticulate
#
# Warning message:
# "package 'reticulate' was built under R version 4.2.3"

# %%
h5ad_file = './res.h5ad'

# %%
sceasy::convertFormat(h5ad_file, from="anndata", to="seurat",
                       outFile='female.rds')
# Out:
# X -> counts
# An object of class Seurat
# 33562 features across 160711 samples within 1 assay
# Active assay: RNA (33562 features, 0 variable features)
#  2 layers present: counts, data
#  1 dimensional reduction calculated: umap

# %%
library(Seurat)
# Out:
# Warning message:
# "package 'Seurat' was built under R version 4.2.3"
# The legacy packages maptools, rgdal, and rgeos, underpinning the sp package,
# which was just loaded, will retire in October 2023.
# Please refer to R-spatial evolution reports for details, especially
# https://r-spatial.org/r/2023/05/15/evolution4.html.
# It may be desirable to make the sf package available;
# package maintainers should consider adding sf to Suggests:.
# The sp package is now running under evolution status 2
#      (status 2 uses the sf package in place of rgdal)
#
# Attaching SeuratObject

# %%
sce = readRDS('./female.rds')

# %%
DefaultAssay(sce) = 'RNA'

# %%
FeaturePlot(sce,features = 'VIM',raster = F)
# Out:
# plot without title

# %%
DimPlot(sce,raster=FALSE,group.by = 'celltype')
# Out:
# plot without title

# %%
library(future)
plan("multisession",workers = 40) # 使用multisession策略

# %%
options(future.globals.maxSize = 3987822434)

# %%
# Idents(sce) = 'celltype'
# FindMarkers(sce,ident.1= 'Oli' )
# Out:
#            p_val         avg_log2FC pct.1 pct.2 p_val_adj
# GABRD      0             -0.2563481 0.022 0.212 0
# KCNAB2     0             -0.3814669 0.048 0.330 0
# CHD5       0             -0.5677697 0.056 0.447 0
# TNFRSF25   0             -0.2894485 0.016 0.223 0
# CAMTA1     0             -0.2516717 0.408 0.645 0
# CLSTN1     0             -0.4928754 0.197 0.553 0
# FBXO44     0             -0.3349014 0.049 0.306 0
# KAZN       0             -0.5729981 0.431 0.742 0
# ATP13A2    0             -0.2662850 0.058 0.285 0
# PADI2      0              0.4624639 0.241 0.043 0
# IGSF21     0             -0.3740770 0.034 0.289 0
# MICOS10    0             -0.2791055 0.047 0.259 0
# RAP1GAP    0             -0.4407815 0.077 0.400 0
# LUZP1      0             -0.3952095 0.042 0.335 0
# CLIC4      0              0.5999640 0.319 0.060 0
# MAN1C1     0             -0.2513837 0.066 0.272 0
# STMN1      0             -0.2742110 0.206 0.436 0
# ATP5IF1    0             -0.2632270 0.056 0.261 0
# EPB41      0             -0.2565778 0.027 0.219 0
# ADGRB2     0             -0.3394417 0.064 0.319 0
# MARCKSL1   0              0.4947333 0.288 0.104 0
# SYNC       0             -0.2909545 0.040 0.252 0
# CSMD2      0             -0.2722697 0.155 0.378 0
# NCDN       0             -0.3715446 0.063 0.321 0
# GRIK3      0             -0.2618935 0.021 0.175 0
# COL9A2     0              0.3056082 0.154 0.027 0
# RIMS3      0             -0.2836690 0.031 0.250 0
# SCMH1      0             -0.3447854 0.137 0.419 0
# HIVEP3     0             -0.3198918 0.191 0.449 0
# RNF220     0              1.5998540 0.853 0.213 0
# ...        ...           ...        ...   ...   ...
# ZBED5      2.060305e-190 0.2771799  0.219 0.164 6.914797e-186
# VPS35L     9.558659e-186 0.2951598  0.329 0.298 3.208077e-181
# ADAM10     2.373708e-184 0.2898843  0.359 0.337 7.966638e-180
# TRPC4AP    4.860894e-178 0.2961967  0.311 0.275 1.631413e-173
# AC106791.1 7.756852e-173 0.2579311  0.196 0.144 2.603355e-168
# MEGF9      1.705246e-167 0.2921934  0.333 0.309 5.723147e-163
# ARHGEF2    2.563719e-166 0.2733570  0.227 0.179 8.604355e-162
# USP47      1.423579e-161 0.2627621  0.382 0.380 4.777815e-157
# TUBB4A     9.750694e-161 0.2610190  0.261 0.210 3.272528e-156
# NUTM2A-AS1 2.660327e-160 0.2857412  0.352 0.338 8.928590e-156
# ARHGAP22   1.200572e-158 0.2732949  0.257 0.211 4.029358e-154
# DIXDC1     1.002433e-156 0.2709887  0.257 0.213 3.364365e-152
# BACE1      2.268826e-156 0.2708374  0.228 0.182 7.614634e-152
# FANCL      3.427336e-155 0.2745905  0.246 0.202 1.150283e-150
# INF2       4.360453e-152 0.2628656  0.225 0.176 1.463455e-147
# ZNF652     1.053455e-148 0.2825670  0.312 0.284 3.535604e-144
# TUBA1A     2.786786e-146 0.2795683  0.319 0.287 9.353011e-142
# TTLL11     8.215408e-142 0.2619576  0.310 0.288 2.757255e-137
# AC118549.1 1.471122e-140 0.2612059  0.363 0.359 4.937380e-136
# CDK6       6.684743e-138 0.2635373  0.294 0.263 2.243534e-133
# FEZ1       1.216848e-135 0.2805078  0.309 0.284 4.083985e-131
# IFT80      4.239868e-127 0.2849241  0.263 0.233 1.422984e-122
# PPP1R21    1.574256e-121 0.2505032  0.348 0.345 5.283518e-117
# FCHSD2     3.241519e-121 0.2616445  0.388 0.398 1.087919e-116
# SLC13A3    7.687271e-114 0.2643756  0.269 0.244 2.580002e-109
# ANAPC5      6.600046e-99 0.2596457  0.324 0.319  2.215107e-94
# PTP4A2      7.918842e-96 0.2512098  0.275 0.253  2.657722e-91
# DNAJB2      4.777305e-92 0.2521697  0.287 0.264  1.603359e-87
# MTMR2       2.747537e-87 0.2550764  0.242 0.220  9.221283e-83
# TMEFF1      6.612467e-85 0.2508075  0.299 0.294  2.219276e-80

# %%
sce$group = substr(sce$sample,1,1)

# %%
table(sce$sample)
# Out:
#    F1    F2    F3    F4    F5    F6    F7    F8    F9   F10   F11   F12   F13
#  3864  1843  2211  5599  6413   512   516  2655  1639  2147  2405  1948  1360
#   F14   F15   F16   F17   F18   F19   F20   F21   F22   F23   F24   F25   F26
#  3453  3454   571  5671   849   942  1045  1215   957   972  1053  2756   957
#   F27   F28   F29   F30   F31   F32   F33   F34   F35   F36   F37   F38    M1
#   846  1250  2136   748  1261  1351  4110  2483  4583  3266   954  1658  2863
#    M2    M3    M4    M5    M6    M7    M8    M9   M10   M11   M12   M13   M14
#  2038  1388  2428  1307  2665  2264  1926  1320  2530  3901  2169  2182  1838
#   M15   M16   M17   M18   M19   M20   M21   M22   M23   M24 M24_2   M26   M27
#  3815  1274  3579  1560  2579  4430  2175  2121  4059   691   672  1944  1201
#   M28   M29   M30   M31   M32   M33   M34
#  2389  2087  2237  3305  2566  2363  3192

# %%
groupinfo = read.table('./groupinfo.txt',header =T,sep = '\t')

# %%
Idents(sce)  ='sample'

# %%
for(i in 1:nrow(groupinfo)){
  sce@meta.data[which(sce@meta.data$sample == groupinfo$sample[i]),'Condition'] <- groupinfo$Condition[i]}

# %%
scRNA = sce

# %%
scedata = scRNA
table(sce$Condition)#查看各组细胞数
# Out:
#    Case Control
#   93273   67438

# %%
saveRDS(sce,file = 'final.rds')

# %%
scedata = sce

# %%
Idents(scedata) = 'celltype'

# %%
prop.table(table(Idents(scedata)))
# Out:
#        Ast        End        ExN        InN        Mic        Mix        OPC
# 0.08219724 0.02456584 0.48197074 0.17631649 0.02329648 0.02364493 0.04777520
#        Oli
# 0.14023309

# %%
table(Idents(scedata), scedata$Condition)#各组不同细胞群细胞数
# Out:
#
#        Case Control
#   Ast  5819    7391
#   End  2207    1741
#   ExN 46914   30544
#   InN 16112   12224
#   Mic  2465    1279
#   Mix  2262    1538
#   OPC  3682    3996
#   Oli 13812    8725

# %%
Cellratio <- prop.table(table(Idents(scedata), scedata$Condition), margin = 2)#计算各组样本不同细胞群比例
Cellratio <- as.data.frame(Cellratio)

# %%
Cellratio$Var2 = factor(Cellratio$Var2,levels = c('Control','Case'))

allcolour=c("#DC143C","#0000FF","#20B2AA","#FFA500","#9370DB","#98FB98","#F08080","#1E90FF","#7CFC00","#FFFF00",
            "#808000","#FF00FF","#FA8072","#7B68EE","#9400D3","#800080","#A0522D","#D2B48C","#D2691E","#87CEEB","#40E0D0","#5F9EA0",
            "#FF1493","#0000CD","#008B8B","#FFE4B5","#8A2BE2","#228B22","#E9967A","#4682B4","#32CD32","#F0E68C","#FFFFE0","#EE82EE",
            "#FF6347","#6A5ACD","#9932CC","#8B008B","#8B4513","#DEB887")
library(ggplot2)
# ggplot(Cellratio) + 
#   geom_bar(aes(x =Var2, y= Freq, fill = Var1),stat = "identity",width = 0.7,size = 0.5,colour = '#222222')+ 
#   theme_classic() +
#   labs(x='Sample',y = 'Ratio')+
#   scale_fill_manual(values = allcolour)+
#   theme(panel.border = element_rect(fill=NA,color="black", size=0.5, linetype="solid"))

library(Seurat)
library(ggplot2)
library(dplyr)
library(ggalluvial)

# %%
ggplot(Cellratio, aes(x =Var2, y= Freq, fill = Var1,
                  stratum=Var1, alluvium=Var1)) +
  geom_col(width = 0.5, color='black')+
  geom_flow(width=0.5,alpha=0.4, knot.pos=0.5)+ # 参数knot.pos设置为0.5使连接为曲线面积，就像常见的桑基图
  theme_classic() +
  labs(x='Sample',y = 'Ratio')+
  scale_fill_manual(values = allcolour) + theme(axis.text.x = element_text(angle = 45, 
 vjust = 0.5, hjust=0.5))
# Out:
# plot without title

# %%
ggsave('figure2.pdf',height =  5,width = 4)

# %% [markdown]
# ## DA analysis

# %%
merged = as.SingleCellExperiment(sce)
abundances <- table(merged$celltype, merged$sample) 
abundances <- unclass(abundances) 
#library(scater)
library(SingleCellExperiment)
colLabels(merged) <- sce$celltype
# Out:
# Warning message:
# "package 'SingleCellExperiment' was built under R version 4.2.2"
# Loading required package: SummarizedExperiment
#
# Warning message:
# "package 'SummarizedExperiment' was built under R version 4.2.2"
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
# Warning message:
# "package 'matrixStats' was built under R version 4.2.3"
#
# Attaching package: 'matrixStats'
#
#
# The following object is masked from 'package:dplyr':
#
#     count
#
#
#
# Attaching package: 'MatrixGenerics'
#
#
# The following objects are masked from 'package:matrixStats':
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# Loading required package: GenomicRanges
#
# Warning message:
# "package 'GenomicRanges' was built under R version 4.2.3"
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: 'BiocGenerics'
#
#
# The following objects are masked from 'package:dplyr':
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from 'package:stats':
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from 'package:base':
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
# Warning message:
# "package 'S4Vectors' was built under R version 4.2.3"
#
# Attaching package: 'S4Vectors'
#
#
# The following objects are masked from 'package:dplyr':
#
#     first, rename
#
#
# The following objects are masked from 'package:base':
#
#     I, expand.grid, unname
#
#
# Loading required package: IRanges
#
# Warning message:
# "package 'IRanges' was built under R version 4.2.3"
#
# Attaching package: 'IRanges'
#
#
# The following objects are masked from 'package:dplyr':
#
#     collapse, desc, slice
#
#
# Loading required package: GenomeInfoDb
#
# Warning message:
# "package 'GenomeInfoDb' was built under R version 4.2.3"
# Loading required package: Biobase
#
# Warning message:
# "package 'Biobase' was built under R version 4.2.3"
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#
# Attaching package: 'Biobase'
#
#
# The following object is masked from 'package:MatrixGenerics':
#
#     rowMedians
#
#
# The following objects are masked from 'package:matrixStats':
#
#     anyMissing, rowMedians
#
#
#
# Attaching package: 'SummarizedExperiment'
#
#
# The following object is masked from 'package:SeuratObject':
#
#     Assays
#
#
# The following object is masked from 'package:Seurat':
#
#     Assays

# %%
merged
# Out:
# class: SingleCellExperiment
# dim: 33562 160711
# metadata(0):
# assays(2): counts logcounts
# rownames(33562): MIR1302-2HG AL627309.1 ... AC007325.4 AC007325.2
# rowData names(0):
# colnames(160711): F1.AAACCCACACCTCTGT-1.Mic.Mic1
#   F1.AAACCCATCGGCATTA-1.ExN.ExN7 ... M9.TTTGTCACATGCCTTC-1.InN.InN5_SST
#   M9.TTTGTCATCCTCAACC-1.Oli.Oli2
# colData names(19): orig.ident nCount_RNA ... ident label
# reducedDimNames(1): UMAP
# mainExpName: RNA
# altExpNames(0):

# %%
library(DESeq2)
library(limma)
library(edgeR)

# %%
table(colLabels(merged), merged$Condition)

extra.info <- colData(merged)[match(colnames(abundances), merged$sample),]

y.ab <- DGEList(abundances, samples=extra.info)

keep <- filterByExpr(y.ab, group=y.ab$samples$Condition)
y.ab <- y.ab[keep,]

design <- model.matrix(~factor(celltype) + factor(Condition), y.ab$samples)
y.ab <- estimateDisp(y.ab, design, trend="none")
# Out:
#
#        Case Control
#   Ast  5819    7391
#   End  2207    1741
#   ExN 46914   30544
#   InN 16112   12224
#   Mic  2465    1279
#   Mix  2262    1538
#   OPC  3682    3996
#   Oli 13812    8725

# %%
fit.ab <- glmQLFit(y.ab, design, robust=TRUE, abundance.trend=FALSE)
res <- glmQLFTest(fit.ab, coef=ncol(design))
summary(decideTests(res))

    diff=topTags(res)$table

diff$logFC = -(diff$logFC)
# Out:
#        factor(Condition)Control
# Down                          0
# NotSig                        6
# Up                            2

# %%
padj = 0.05
foldChange = 0


    diff$group = as.factor(ifelse(diff$PValue < padj & abs(diff$logFC) >= foldChange, 
                                 ifelse(diff$logFC> foldChange ,'Up','Down'),'NoSignifi'))
    table(diff$group)
    res = diff

library("edgeR")  
    library(dplyr)
    library(ggrepel)
    library(ggplot2)
    library(cowplot)
# Out:
#      Down NoSignifi        Up
#         2         5         1

# %%
    res$group<-factor(res$group,levels=c("Down","NoSignifi","Up"))

    
    top_5 <- bind_rows(   
      res %>%
        filter(group == 'Up') %>%
        arrange(PValue, desc(logFC)) %>%
        head(5),
      res %>%
        filter(group == 'Down') %>%
        arrange(PValue, desc(logFC)) %>%
        head(5)
    )
    ggplot(data=res,aes(x=logFC,y=-log10(PValue)))+
    geom_point(aes(color=group),size=2)+
    geom_hline(yintercept = -log10(0.05), linetype="dashed",color="grey30")+
    geom_vline(xintercept = c(0),linetype="dashed",color="grey30")+
    geom_text_repel(data=top_5,aes(x= logFC,y= -log10(PValue),label= rownames(top_5)))+
    scale_color_manual(values = c("blue","grey80","red"))+
    theme_half_open() 
ggsave('Volcano.pdf',height = 8,width = 8)
# Out:
# plot without title

# %% [markdown]
# ### 鉴定MCP

# %%
setwd('/import/GSE213982_fel/')
library(DIALOGUE)
# Out:
# Loading required package: lme4
#
# Warning message:
# "package 'lme4' was built under R version 4.2.3"
# Loading required package: Matrix
#
# Warning message:
# "package 'Matrix' was built under R version 4.2.3"
# Loading required package: lmerTest
#
# Warning message:
# "package 'lmerTest' was built under R version 4.2.3"
#
# Attaching package: 'lmerTest'
#
#
# The following object is masked from 'package:lme4':
#
#     lmer
#
#
# The following object is masked from 'package:stats':
#
#     step
#
#
# Loading required package: PMA
#
# Loading required package: plyr
#
# Loading required package: matrixStats
#
# Warning message:
# "package 'matrixStats' was built under R version 4.2.3"
#
# Attaching package: 'matrixStats'
#
#
# The following object is masked from 'package:plyr':
#
#     count
#
#
# Loading required package: psych
#
# Warning message:
# "package 'psych' was built under R version 4.2.3"
# Loading required package: stringi
#
# Warning message:
# "package 'stringi' was built under R version 4.2.2"
# Loading required package: RColorBrewer
#
# Loading required package: unikn
#
# Welcome to unikn (v1.0.0)!
#
# simcol() searches for similar colors.
#
# Loading required package: reshape2
#
# Warning message:
# "package 'reshape2' was built under R version 4.2.3"
# Loading required package: ggplot2
#
# Warning message:
# "package 'ggplot2' was built under R version 4.2.3"
#
# Attaching package: 'ggplot2'
#
#
# The following objects are masked from 'package:psych':
#
#     %+%, alpha
#
#
# Loading required package: ppcor
#
# Loading required package: MASS
#
# Warning message:
# "package 'MASS' was built under R version 4.2.3"
# Loading required package: Hmisc
#
# Warning message:
# "package 'Hmisc' was built under R version 4.2.3"
#
# Attaching package: 'Hmisc'
#
#
# The following object is masked from 'package:psych':
#
#     describe
#
#
# The following objects are masked from 'package:plyr':
#
#     is.discrete, summarize
#
#
# The following objects are masked from 'package:base':
#
#     format.pval, units
#
#
# Loading required package: grid
#
# Loading required package: beanplot
#
# Loading required package: UpSetR

# %%
library(Seurat)
sce = readRDS('./final.rds')
table(sce$celltype)
# Out:
# Loading required package: lme4
#
# Warning message:
# "package 'lme4' was built under R version 4.2.3"
# Loading required package: Matrix
#
# Warning message:
# "package 'Matrix' was built under R version 4.2.3"
# Loading required package: lmerTest
#
# Warning message:
# "package 'lmerTest' was built under R version 4.2.3"
#
# Attaching package: 'lmerTest'
#
#
# The following object is masked from 'package:lme4':
#
#     lmer
#
#
# The following object is masked from 'package:stats':
#
#     step
#
#
# Loading required package: PMA
#
# Loading required package: plyr
#
# Loading required package: matrixStats
#
# Warning message:
# "package 'matrixStats' was built under R version 4.2.3"
#
# Attaching package: 'matrixStats'
#
#
# The following object is masked from 'package:plyr':
#
#     count
#
#
# Loading required package: psych
#
# Warning message:
# "package 'psych' was built under R version 4.2.3"
# Loading required package: stringi
#
# Warning message:
# "package 'stringi' was built under R version 4.2.2"
# Loading required package: RColorBrewer
#
# Loading required package: unikn
#
# Welcome to unikn (v1.0.0)!
#
# unikn.guide() opens user guides.
#
# Loading required package: reshape2
#
# Warning message:
# "package 'reshape2' was built under R version 4.2.3"
# Loading required package: ggplot2
#
# Warning message:
# "package 'ggplot2' was built under R version 4.2.3"
#
# Attaching package: 'ggplot2'
#
#
# The following objects are masked from 'package:psych':
#
#     %+%, alpha
#
#
# Loading required package: ppcor
#
# Loading required package: MASS
#
# Warning message:
# "package 'MASS' was built under R version 4.2.3"
# Loading required package: Hmisc
#
# Warning message:
# "package 'Hmisc' was built under R version 4.2.3"
#
# Attaching package: 'Hmisc'
#
#
# The following object is masked from 'package:psych':
#
#     describe
#
#
# The following objects are masked from 'package:plyr':
#
#     is.discrete, summarize
#
#
# The following objects are masked from 'package:base':
#
#     format.pval, units
#
#
# Loading required package: grid
#
# Loading required package: beanplot
#
# Loading required package: UpSetR
#
# Warning message:
# "package 'Seurat' was built under R version 4.2.3"
# The legacy packages maptools, rgdal, and rgeos, underpinning the sp package,
# which was just loaded, will retire in October 2023.
# Please refer to R-spatial evolution reports for details, especially
# https://r-spatial.org/r/2023/05/15/evolution4.html.
# It may be desirable to make the sf package available;
# package maintainers should consider adding sf to Suggests:.
# The sp package is now running under evolution status 2
#      (status 2 uses the sf package in place of rgdal)
#
# Attaching SeuratObject
#
#
# Attaching package: 'Seurat'
#
#
# The following object is masked from 'package:Hmisc':
#
#     Key
#   Ast   End   ExN   InN   Mic   Mix   OPC   Oli
# 13210  3948 77458 28336  3744  3800  7678 22537

# %%
Idents(sce) <- "celltype"
# Downsample the number of cells per identity class
ob1 <- subset(x = sce, downsample = 5000)
#ob1 = sce
library(Seurat)
ob1 <- FindVariableFeatures(ob1, selection.method = "vst", nfeatures = 5000)
ob1
# Out:
# An object of class Seurat
# 33562 features across 36492 samples within 1 assay
# Active assay: RNA (33562 features, 5000 variable features)
#  1 dimensional reduction calculated: umap

# %%
set.seed(1263)
# Simulating data based on Seurat object of PBMCs
obj<-ob1
obj@meta.data$samples <- obj@meta.data$sample
obj@meta.data$cell.subtypes<-obj@meta.data$celltype
b1<-is.element(obj@meta.data$cell.subtypes,c("Ast",'InN'))
b2<-is.element(obj@meta.data$cell.subtypes,c("Mic","Mix"))
b3<-is.element(obj@meta.data$cell.subtypes,c('End', 'ExN'))
b4<-is.element(obj@meta.data$cell.subtypes,c("OPC","Oli"))




obj@meta.data$samples[b1] <- sample(obj@meta.data$sample, size = sum(b1), replace =FALSE)
obj@meta.data$samples[b2] <- sample(obj@meta.data$sample, size = sum(b2), replace =FALSE)
obj@meta.data$samples[b3] <- sample(obj@meta.data$sample, size = sum(b3), replace =FALSE)
obj@meta.data$samples[b4] <- sample(obj@meta.data$sample, size = sum(b4), replace =FALSE)

DIALOGUE_make.cell.type.seurat<- function(obj, cell.subtypes, name){
  # Given a Seurat object with "cell.subtypes" and "samples" information provided in the meta.data field
  
  if(is.null(obj@meta.data$cell.subtypes)){return("Cell subtypes information is missing")}
  if(is.null(obj@meta.data$samples)){return("Sample information is missing")}
  
  sub_obj<- subset(x = obj,cells = rownames(obj@meta.data)[is.element(obj@meta.data$cell.subtypes,cell.subtypes)])
  sub_obj<- NormalizeData(sub_obj,normalization.method = "LogNormalize", scale.factor = 100000)
  sub_obj<-FindVariableFeatures(sub_obj,selection.method = "vst", nfeatures = 5000)
  sub_obj<-ScaleData(sub_obj)
  sub_obj<-RunPCA(sub_obj,npcs = 30) 
  
  tpm<- as.matrix(sub_obj@assays$RNA@data)
  
  X<- sub_obj@reductions$pca@cell.embeddings
  assertthat::are_equal(rownames(X),colnames(tpm))
  n_cells<- ncol(tpm)
  samples<- sub_obj@meta.data$sample
  n_count<- as.vector(scale(log(sub_obj@meta.data$nCount_RNA)))
  metadata<- data.frame(nFeatures = sub_obj@meta.data$nFeature_RNA,
                        samples = samples,
                        group = sub_obj@meta.data$group,
                        Condition = sub_obj@meta.data$Condition,
                        cell.subtypes = as.character(sub_obj@meta.data$cell.subtypes))
  r<-make.cell.type(name = name ,tpm,samples,X,metadata, cellQ = n_count)
  return(r)
}

# %%
r1<- DIALOGUE_make.cell.type.seurat(obj, cell.subtypes = c('ExN'), name = "ExN")
r2<- DIALOGUE_make.cell.type.seurat(obj, cell.subtypes = c("Ast"), name = "Ast")
r3<- DIALOGUE_make.cell.type.seurat(obj, cell.subtypes = c("InN"), name = "InN")
r4<- DIALOGUE_make.cell.type.seurat(obj, cell.subtypes = c("Mic"), name = "Mic")
r5<- DIALOGUE_make.cell.type.seurat(obj, cell.subtypes = c("End"), name = "End")
r6<- DIALOGUE_make.cell.type.seurat(obj, cell.subtypes = c("OPC"), name = "OPC")
r7<- DIALOGUE_make.cell.type.seurat(obj, cell.subtypes = c("Oli"), name = "Oli")

rA<- list(ExN = r1,Ast = r2,Oli = r7,Mic= r4,End= r5,OPC = r6,InN = r3)  #
library(DIALOGUE)
results.dir = './condition/'
# Out:
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  MALAT1, KCNIP4, XIST, ST18, LRRTM4, DOCK5, FRMD4B, FA2H, CNDP1, ASPA
# 	   LPAR1, C10orf90, RFTN2, SLC1A3, LINC01608, UGT8, PLP1, SHROOM4, TMEM63A, MYRF
# 	   LINC00639, LRP1B, ABCA8, CLDN11, CD22, MOG, OBI1-AS1, COL4A5, FLT1, DOCK10
# Negative:  CFL1, SELENOW, NEFL, RAB3A, OAZ1, YWHAH, STMN1, PEBP1, DYNLL1, NGRN
# 	   TMSB10, BEX1, GAPDH, CALM3, TUBB2A, ATP5MPL, ATP6V1G2, UQCRH, NDUFA4, PPIA
# 	   BEX4, RGS4, SOD1, BEX3, TPI1, EIF1, PCSK1N, ATP6AP2, ATP6V0C, RPL15
# PC_ 2
# Positive:  NEFL, TUBB2A, HSP90AB1, NCDN, ACTG1, NEFM, TUBB, GAPDH, CFL1, RAB3A
# 	   LDHA, TUBA1B, B4GAT1, TUBB3, TUBB4A, ATP6AP1, ATP6V0C, GNG3, RTL8C, PGAM1
# 	   ALDOC, NAP1L3, ACTB, NAP1L5, THY1, CTSD, GPX4, FAIM2, GHITM, PNMA8B
# Negative:  IQCJ-SCHIP1, TMEM108, LINGO2, TMEM132D, RGS6, AC107223.1, AC092691.1, DAB1, SYN3, SGCD
# 	   ASIC2, CNTN4, AC011287.1, GRM7, CDH18, GPC6, LRRC4C, DGKB, ADGRL2, KCNH7
# 	   ZFPM2, TAFA1, GRID2, SNTG1, KIRREL3, PDE10A, GALNTL6, AC068587.4, CNTNAP5, TENM2
# PC_ 3
# Positive:  XIST, ST18, C10orf90, PLP1, TMEM144, FRMD4B, DLC1, DOCK5, KLHL5, FA2H
# 	   RNF220, NCKAP5, ZBTB20, DOCK10, LPAR1, HIPK2, HIP1, MBP, QKI, MOBP
# 	   LINC01608, KCNH8, ZNF536, HS3ST4, SILC1, SEMA3E, UGT8, COL4A5, DOCK1, LMCD1-AS1
# Negative:  AP001825.1, TTTY14, USP9Y, NLGN4Y, AC110296.1, LINC00513, P2RY14, PCDH9-AS2, AC008696.2, IGSF10
# 	   KCNV2, PDE5A, CHRM3-AS2, TAFA1, CUX2, KCNIP4, LRTM1, LINC02306, EPHA6, AC009041.2
# 	   AC027288.3, ARHGAP26-AS1, UTY, AC016716.2, AC104827.1, LRRTM4, CBLN2, AC091885.2, AL138828.1, HS6ST3
# PC_ 4
# Positive:  FOXP2, IL1RAPL2, AC008415.1, AC109466.1, RXFP1, TLL1, TSHZ2, TOX, TRMT9B, FSTL5
# 	   CASC15, POU6F2, CLSTN2, HS3ST4, CPNE4, SLC35F1, HS3ST2, RORB, AL109930.1, PHLDB2
# 	   PDZRN4, LINC02232, VWC2L, PTPRT, CHRM2, PCDH11X, NRG1, CDH7, AP003066.1, PLCXD3
# Negative:  SERPINE2, LINC02306, CBLN2, PDZD2, ST18, GNAL, STXBP6, CUX2, RASGRF2, SPOCK3
# 	   QKI, FRMD4B, PCDH8, LINC01331, PLP1, FGFR2, ROBO1, FA2H, MEIS2, LAMP5
# 	   DOCK5, AC008574.1, CDH9, MOG, KCNMB2, LINC01608, LPAR1, ENPP2, HPCAL1, AC009041.2
# PC_ 5
# Positive:  TTTY14, USP9Y, NLGN4Y, LSAMP-AS1, AC091885.2, LINC00513, PCDH9-AS2, AC104827.1, AC027288.3, UTY
# 	   AP001825.1, PDE5A, CTNNA3, RPL7, AC016716.2, AC005400.1, P2RY14, SNAP25-AS1, ARHGAP26-AS1, MALAT1
# 	   AC110296.1, AC090579.1, PCDH11Y, RPL34, CHRM3-AS2, SYNC, KCNV2, RPL21, RPS27, AP000462.1
# Negative:  XIST, AC007563.2, NPTXR, LINC00486, CREG2, CXXC5, MTPN, SLIT3, SYT11, SYN1
# 	   SYN3, CUX2, RYR3, OLFM1, CALN1, TSPYL4, CCBE1, AC117453.1, RASGRF2, LINC01331
# 	   SLC17A7, VSTM2L, TMEM30A, PHYHIP, MIR646HG, EEF1A2, SMIM10L2B, TUBB4A, CDK5R1, JUND
#
# Warning message in asMethod(object):
# "sparse->dense coercion: allocating vector of size 1.3 GiB"
# [1] "Cell type name: ExN"
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  FGF12, TMEM132D, DSCAM, ANK3, SNTG1, GRIN2B, MDGA2, OPCML, SLC24A2, XKR4
# 	   GRIN2A, MYT1L, MMP16, AK5, ASIC2, SHISA9, NLGN1, GALNT17, SYN2, PRKCB
# 	   BASP1, ATRNL1, CNTNAP5, RYR2, IL1RAPL1, CNTN4, SH3GL3, CSMD3, KHDRBS2, GRM5
# Negative:  OBI1-AS1, HPSE2, ZNF98, NKAIN3, CDH20, AL137139.2, COL5A3, RYR3, FGFR3, AC002429.2
# 	   LINC00299, WIF1, EMX2, NHSL1, CABLES1, GPC5-AS2, PRDM16-DT, AL590617.2, AL589740.1, SLC4A4
# 	   PREX2, GLI1, AC006487.1, GLUL, GLIS3, BMPR1B, AC009902.3, AC097518.2, LINC02123, AC099518.5
# PC_ 2
# Positive:  XIST, IL1RAPL1, ROBO2, KCNIP4, CSMD1, CNTNAP2, NLGN1, RBFOX1, PTPRD, MDGA2
# 	   KAZN, DLGAP1, RALYL, ANK3, IQCJ-SCHIP1, CCSER1, RIMS2, ATRNL1, GRID2, DPYD
# 	   KCNQ5, LINC00609, DCLK1, OPCML, TMEFF2, DSCAML1, CSMD3, HS6ST3, STXBP5L, NRXN3
# Negative:  GLUL, CST3, APOE, FTL, ITM2C, HEPN1, GJA1, PCDH9-AS2, MT2A, ATP1B2
# 	   CLU, FTH1, IGSF10, LSAMP-AS1, TUBB2B, ITM2B, GPR37L1, NAT8L, AC016716.2, AP000462.1
# 	   P2RY14, SNHG25, DLC1, NDRG2, GJB6, F3, MT1X, FGFR3, GNA14-AS1, AL512422.1
# PC_ 3
# Positive:  XIST, SLC39A11, RFX4, GLIS3, RPS6KA2, AL137139.2, PARD3, LRIG1, SHROOM3, MEIS2
# 	   AHCYL2, MAML2, NHSL1, BMPR1B, ZSWIM6, FAM189A2, PDE7B, ADCY2, LINC00511, ALDH1A1
# 	   DCLK2, AC073050.1, DGKG, AC114971.1, OPHN1, SLC14A1, NAALADL2, PDE4B, ITPKB, TPD52L1
# Negative:  MEG3, GRIN1, LINC00599, CHD5, SLC17A7, TTTY14, CABP1, PDIA2, AC016716.2, NLGN4Y
# 	   NRGN, KCNT1, CAMK2A, EPHB6, TMSB10, ENC1, SULT4A1, BASP1, YWHAH, VSNL1
# 	   USP9Y, SLC6A17, STX1A, CORO6, CAMKV, NPTX1, CKMT1B, RPS4Y1, RAP1GAP, UTY
# PC_ 4
# Positive:  HPSE2, GRM3, CACNB2, CABLES1, ZNF98, COL5A3, WIF1, RERG, ARHGAP24, SGCD
# 	   PLCB1, PDE4D, DNM3, FLRT2, LINC00499, SYNE1, MIAT, FRMD4A, AC097518.2, DLC1
# 	   PTN, LRRC3B, SLC35F1, PREX2, MACROD2, RORB, SLC4A4, ESRRG, GLUL, TENM2
# Negative:  TNC, AC012405.1, GFAP, VCAN, AC073941.1, CD44, LINC00609, WDR49, SLC38A1, LINC00836
# 	   ADAMTSL3, CRYAB, DPP10, AQP1, IGFBP5, ID3, TJP2, DCLK1, HSPA1A, DPYSL3
# 	   ADAMTS9, GPC6, FOS, JUN, APLNR, LINC01088, ITGB4, PFKFB2, HSPB8, HSPB1
# PC_ 5
# Positive:  ST18, LINC01608, KCNH8, FRMD4B, DOCK10, ZNF536, PLP1, EDIL3, CTNNA3, CERCAM
# 	   MOBP, AL359091.1, ANO4, SPOCK3, CREB5, SHTN1, MBP, AC008571.2, PDE1C, SH3GL3
# 	   PCDH9-AS2, ELMO1, SLC24A2, IL1RAPL1, TTLL7, TMEFF2, 1-Mar, LSAMP-AS1, PALM2-AKAP2, ANK3
# Negative:  XIST, MMD2, PHYHIP, MAPK11, MAPK8IP2, CAMK2A, CHD5, SOHLH1, SNCB, DNM1
# 	   NAT8L, ADGRB2, GRIN1, CABP1, SULT4A1, SLC25A18, PSD, TSPYL1, GPC1, GABRD
# 	   KIFC2, MLC1, SYN1, SLC12A5, CALY, SLC6A17, NSMF, ADGRB1, SLC17A7, CLU
#
# Warning message in asMethod(object):
# "sparse->dense coercion: allocating vector of size 1.3 GiB"
# [1] "Cell type name: Ast"
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  SOX6, NXPH1, KIAA1217, GRIK3, TAC1, PRKG1, MYO5B, SPARCL1, RSPO2, DPP10
# 	   GPC6, SATB1-AS1, PLCH1, CUX2, STXBP6, SCN1A-AS1, TMEM132C, POSTN, SLC9A9, DPP10-AS3
# 	   AC093610.1, EYS, CNTNAP3B, TENM2, SATB1, RASGRF2, PVALB, SLIT2, SULF1, HHATL
# Negative:  ADARB2, NFIB, KCNT2, DSCAM, RGS12, DOCK10, PROX1, COBL, NFIX, CXCL14
# 	   EGFR, CNTNAP4, NEDD4L, MAPK4, PCSK2, AP1S2, LINGO2, MAGI3, DLX6-AS1, CCNH
# 	   CCK, CHST11, NYAP2, CCDC85A, CACNA1E, DGKB, CNR1, ZBTB16, C8orf34, PKP2
# PC_ 2
# Positive:  SPARCL1, SOX6, NXPH1, PRKG1, TAC1, SCN1A-AS1, CNTNAP3B, SLIT2, SNCG, TMEM132C
# 	   MYO5B, SERPINI1, RASGRF2, SAMD5, SLC24A2, SATB1, TENM1, SULF1, MMP16, RGS5
# 	   SLC9A9, PVALB, SOX5, AL033504.1, PTPRM, STXBP5-AS1, FMN1, MYO16, RSPO2, RGS4
# Negative:  ADARB2, RGS12, PROX1, KCNT2, VIP, SYNPR, CHRM3, NR2F2-AS1, CXCL14, DSCAM
# 	   AC013265.1, LINGO2, CALB2, NRXN1, LAMA3, PROX1-AS1, AL391832.4, NFIB, L3MBTL4, MAPK4
# 	   AC087564.1, SHISA8, CHRNA2, PDE3A, AL589740.1, TSHZ2, ASIC4, EGFR, NFIX, ADRA1B
# PC_ 3
# Positive:  SV2C, FBXL7, EYA4, LAMP5, KIT, TRPC3, PDGFD, AC132803.1, NTNG1, FGF13
# 	   PRELID2, CPLX3, ID2, ROR2, AC137770.1, SPHKAP, HPCAL1, PTPRT, LINC00298, ARHGAP31
# 	   NXPH2, CACNA2D1, LINC01344, TOX, NRG1, JAM2, UNC13C, LTBP1, TPD52L1, CHST9
# Negative:  KCNMB2, KIAA1217, ASIC2, PDE4B, SPOCK3, HS6ST3, ZNF804A, STARD13, SNTG1, SLC44A5
# 	   VWC2L, LDLRAD4, CDH10, ROBO1, NPAS3, TENM2, LINC01322, FRMD5, PLXNA4, L3MBTL4
# 	   KHDRBS2, LRRTM4, GRM7, CNTN3, PTPRZ1, BTBD11, ADAMTS17, PLD5, NDST3, 1-Mar
# PC_ 4
# Positive:  TTTY14, USP9Y, VIP, RPS27, LSAMP-AS1, RPL41, NLGN4Y, RPS15, RPL21, RPL34
# 	   RPL7, UQCR10, TMA7, MIF, COX7C, ATP5ME, AC091885.2, RPS18, FTL, NDUFA4
# 	   ATP5MF, NDUFA1, COX6B1, PRDX2, AP001825.1, ATP5MPL, UBL5, GAPDH, ELOB, COX5B
# Negative:  XIST, DSCAML1, TENM4, NETO1, XKR4, SLC8A1, NXPH1, WLS, LINC00486, ST6GALNAC5
# 	   PTPRM, PTCHD4, PTPRT, KCNIP1, RPH3A, ALK, GRIN3A, PDZRN3, RYR2, GRIK3
# 	   ENOX1, DLGAP2, KIF26B, MAP3K5, RALYL, SYN3, MGAT4C, COL25A1, TMTC2, UTRN
# PC_ 5
# Positive:  ERBB4, LRRC4C, MYO16, SHISA9, ZNF804A, GRIA4, SDK1, CALN1, ZNF536, TMEM132C
# 	   PLXNA4, NEAT1, PLD5, TAFA2, ADAMTS17, HS6ST3, INPP4B, PLCXD3, CEMIP, PLCL1
# 	   BTBD11, SOX5, RARB, KCNH7, SLC9A9, SGK1, AC093610.1, SLC35F4, LDB2, SLIT2
# Negative:  SST, PDE1A, TRHDE, SYNPR, RALYL, GRM1, MAN1A1, CACNA2D3, ROBO1, LINC01122
# 	   GRID2, COL25A1, GRIK1, PAWR, PCDH11X, SLC8A1, CHRM3, SHISA6, PLCH1, CDH8
# 	   EPHB6, RAB3B, NELL1, STXBP6, TMSB4X, RGS6, FXYD6, RAB31, ST6GALNAC5, EDNRA
#
# Warning message in asMethod(object):
# "sparse->dense coercion: allocating vector of size 1.3 GiB"
# [1] "Cell type name: InN"
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  C3, RASGEF1C, SLCO2B1, ABCC4, FLI1, CSF2RA, AC008691.1, LYN, PALD1, PTPRC
# 	   LY86, RBM47, RUNX1, FYB1, SYNDIG1, SH3RF3, IKZF1, SAMSN1, LINC01374, ARHGAP22
# 	   BMP2K, LPCAT2, A2M, LNCAROD, CTSB, FGD4, ARHGAP6, LPAR6, LINC02712, BNC2
# Negative:  NTM, NCAM1, CTNND2, MAGI2, PPP2R2B, NCAM2, DPP6, LSAMP, ADGRL3, ANKS1B
# 	   NLGN1, IL1RAPL1, KAZN, DMD, ANK3, CTNNA2, PTPRG, OPCML, FAM155A, RORA
# 	   NPAS3, CDH20, AC092691.1, SLC24A2, GPM6B, CADM2, LRRC4C, FGF14, FBXL7, GPM6A
# PC_ 2
# Positive:  XIST, SYNDIG1, RASGEF1C, IL1RAPL1, PCDH9, ST18, C10orf90, AC008050.1, PDE4B, UNC5C
# 	   AC008691.1, RNF220, PTPRD, DLG2, FRMD5, CTNNA3, MAGI2, ARHGAP22, ERBB4, PHLPP1
# 	   ABCC4, CADM2, ZNF536, PALD1, NCAM2, TMTC2, NLGN1, PRKCA, LINC00609, HS3ST4
# Negative:  AC120193.1, TMSB4X, TMSB10, FTL, RPL41, RPS27, RPLP1, RPLP2, RPS18, RPS15
# 	   RPS27A, RPL34, FTH1, RPS14, RPS28, RPL36A, GAPDH, RPS6, TMA7, RPL13A
# 	   RPL19, SERF2, USP9Y, TTTY14, RPL37A, RPL26, RPL39, COX7C, RPL7, RPL11
# PC_ 3
# Positive:  MEG3, RBFOX1, TTTY14, GRIN1, KCNIP4, AP001825.1, FRMPD4, TENM2, MIAT, LINC00599
# 	   SYT1, CHRM3, DLGAP1, CCSER1, FGF14, OPCML, SNTG1, FGF12, CBLN2, CSMD1
# 	   CNTN4, ROBO2, LRRTM4, RALYL, ST6GALNAC5, GRIN2A, ASIC2, USP9Y, NLGN4Y, LINGO2
# Negative:  PIP4K2A, DOCK5, FTL, XIST, PADI2, MOBP, MBP, PAG1, RNF220, LYN
# 	   GLDN, ACSL1, CD74, TLR2, C10orf90, RPS24, TPT1, RPL11, NCKAP5, IKZF1
# 	   FRMD4B, CTSB, EEF1A1, SLC1A3, HIF1A, RPL37, TF, RBM47, SLC11A1, SPP1
# PC_ 4
# Positive:  ST18, CERCAM, SLC7A14-AS1, LINC01608, RNF220, MOBP, ZNF536, C10orf90, TF, TMEM144
# 	   AC012494.1, AL359091.1, PLP1, DOCK5, PDE1C, TMTC2, PTGDS, SLC24A2, AC008571.2, CTNNA3
# 	   SLC5A11, EDIL3, SPOCK3, FRMD5, LINC00609, HIP1, SH3GL3, PALM2-AKAP2, TTLL7, MAP7
# Negative:  LRRK1, KCNMA1, CACNA1D, SH3RF3, PALD1, DSCAM, RASGEF1C, KHDRBS3, ABCC4, MERTK
# 	   STXBP5L, LHFPL2, OPCML, GRIK2, XIST, SDK1, IPCEF1, CSMD1, IKZF1, MAF
# 	   KCNIP4, CACNA2D3, KCNQ5, FGF14, CSF2RA, HS3ST4, FAM149A, FAM155A, PRKCA, FLI1
# PC_ 5
# Positive:  P2RY12, AC008691.1, SYNDIG1, DLEU1, AC120193.1, LINC02712, ARHGAP22, C3, FOXP2, LINC01374
# 	   A2M, LNCAROD, HS3ST4, ITM2B, LPAR6, RASGEF1C, LINC02232, SLCO2B1, LINC02798, CPED1
# 	   TUBB2A, STMN1, USP53, LPCAT2, BEX1, RGS4, LINC02642, ABCC4, SLC24A2, AC009432.2
# Negative:  SKAP1, SLFN12L, SAMD3, RUNX3, CD247, ITGA4, CD96, TC2N, PTPN22, CD44
# 	   STAT4, SYNE2, PYHIN1, ATP10A, CRYBG1, ITK, CD6, RIPOR2, IQGAP2, THEMIS
# 	   CEMIP2, MCTP2, PRF1, VAV3, KLRF1, GRAP2, LINC01934, ADGRE5, TXK, ETS1
# [1] "Cell type name: Mic"
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  CLDN5, IFI27, TMSB10, FLT1, ITM2A, MT2A, ABCB1, ATP10A, TMSB4X, DUSP1
# 	   IFITM3, RPS27, VWF, HSPA1A, HLA-B, MECOM, KLF2, SOX18, HSPA1B, SRGN
# 	   UBC, ANKRD37, ID3, FOS, CGNL1, MT1E, MT1M, ID1, ICAM2, SLC7A1
# Negative:  TRIM9, CACNA1B, SRGAP3, PPP2R2B, AC092691.1, NCAM1, DOCK3, GRIA1, ASTN1, DPP6
# 	   ANK3, FGF14, NAV3, AKAP6, ANKS1B, KCNQ3, ATP2B2, AGBL4, LRRC7, NALCN
# 	   NLGN1, NLGN4X, RGS7, NRCAM, TMEM132B, CTNND2, IL1RAPL1, SRRM4, FRMPD4, RBFOX3
# PC_ 2
# Positive:  SLC19A1, SLC38A11, PDGFRB, PRKG1, PDE8B, SLC6A1, ARHGAP42, GPC5, SLC6A12, NOTCH3
# 	   SLC30A10, COLEC12, GRM8, CARMN, ARHGAP10, GRM3, NR2F2-AS1, TRPC3, PDE7B, SNTB1
# 	   GJC1, CACNA1C, EPS8, ATP1A2, PLCE1, PLXDC1, SLC1A3, CASC15, PTH1R, CDH6
# Negative:  CSMD1, RBFOX1, RYR2, KCNIP4, CNTNAP2, ROBO2, NRXN3, NRXN1, RALYL, LRRTM4
# 	   CACNA1B, AC092691.1, PEX5L, CSMD3, LRRC7, NKAIN2, HS6ST3, CADPS, ASIC2, AGBL4
# 	   STXBP5L, RGS7, FGF14, LRP1B, MDGA2, PPP2R2B, CADM2, DSCAM, GRIN2A, NEGR1
# PC_ 3
# Positive:  ABCB1, MECOM, ST6GALNAC3, FLT1, ELOVL7, ATP10A, VWF, SLC7A1, THSD4, PTPRB
# 	   ITGA6, ANO2, MYRIP, CLDN5, ABCG2, CGNL1, FLI1, SLC39A10, ST8SIA6, INPP5D
# 	   LIMCH1, SGPP2, SORBS1, SORBS2, ST6GAL1, PIK3R3, GRB10, TFRC, SAMD12, GALNT18
# Negative:  PRKG1, SLC6A1, COLEC12, GPC5, SLC19A1, LAMA2, GRM8, SLC38A11, ATP1A2, NR2F2-AS1
# 	   CACNA1C, PDGFRB, MIR99AHG, CARMN, SLC1A3, GRM3, TRPC3, PDE8B, SLC6A12, ARHGAP42
# 	   NOTCH3, EPS8, CASC15, SGIP1, ARHGAP10, DGKB, DLC1, SEMA5A, SLC30A10, SLC20A2
# PC_ 4
# Positive:  PCDH9, FLI1, CADM2, IL1RAPL1, RNF220, ST6GALNAC3, KCNIP4, TMEM132C, CSMD1, ANO2
# 	   ERBB4, ST18, LRP1B, SORBS1, THSD4, ST6GAL1, ATP10A, GRB10, DLG2, LIMCH1
# 	   KCNH8, GALNT18, SORBS2, NRG3, CCDC85A, AC079352.1, ST8SIA6, LRMDA, SAMD12, PTPRD
# Negative:  TMSB4X, MIF, RPL34, IFITM1, TTTY14, POLR2L, LGALS1, RPL7, TMSB10, COX6A1
# 	   RPS27, RPL21, COX5B, RPL41, ATP5ME, SERF2, RPS18, RPS29, ATP5MPL, COX7A2
# 	   COX8A, RPL36, NDUFA4L2, UQCR10, UQCRQ, FTL, TMA7, COX7C, USP9Y, RPS19
# PC_ 5
# Positive:  GRM8, ZNF385B, ANO3, GPCPD1, GPC5, TRPC3, ATP10A, PDE8B, ADGRL3, CNTN4
# 	   SLC39A10, SORBS2, CCDC3, ABCB1, ABCG2, DACH1, TFRC, HIF1A-AS3, MPPED2, GALNT18
# 	   PTPRB, GUCY1A2, SLC6A12, SLC38A11, LRRTM4, SPOCK3, FLT1, GRK3, SLC16A1, GJC1
# Negative:  SLC7A14-AS1, COL15A1, CLDN11, PLD1, LINC01088, SLC6A20, PDGFRA, PAMR1, LPAR1, COL6A3
# 	   BICC1, HSD11B1, C7, VIT, ROR2, MCTP2, CEMIP, IQGAP2, THBS2, CYP1B1
# 	   KCNIP1, FGFR2, ADAM12, ABCA8, KCNK2, F3, FBLN5, ITGA8, RASSF2, FLRT2
# [1] "Cell type name: End"
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  XIST, DSCAML1, STXBP5L, KCNMA1, MEG8, ZDHHC14, FRMD4A, ADAMTS17, TMEM108, ANK2
# 	   KCNIP1, CSGALNACT1, ERC2, CDH13, COBL, KIAA1217, CELF2, SLC24A3, SORCS3, MEGF11
# 	   SORCS1, TAFA2, SPOCK1, PARD3, ANK3, NTRK3, TOX, CCSER1, MTSS1, SMYD3
# Negative:  NLGN4Y, TTTY14, LSAMP-AS1, UTY, PCDH11Y, SLC6A1-AS1, CFTR, AC016716.2, AL160262.1, AP001267.1
# 	   AL359091.1, AP001825.1, AC002463.1, PCDH9-AS2, SNHG25, AC114760.2, USP9Y, PLXNB3, ZBTB20-AS5, PKP4-AS1
# 	   ZFY, PCDH9-AS1, AL596218.1, AC092069.1, DDX3Y, AC091885.2, AC073349.4, FBP1, GPC5-AS2, AL353784.1
# PC_ 2
# Positive:  NLGN4Y, TTTY14, PCDH9-AS2, TMSB4X, FTH1, LSAMP-AS1, USP9Y, RPL41, PCDH11Y, GRIN1
# 	   AC091885.2, UTY, AP001825.1, FTL, CAMK2A, RAB11A, RPL34, BEX3, ZFPM2-AS1, STMN1
# 	   MIF, RPS15, CHD5, TMA7, RPS27, SLC12A5, YWHAH, P2RY14, LINC00513, AC016716.2
# Negative:  XIST, MEGF11, MMD2, HIP1, TMEM132C, ADARB2, DSCAML1, LINC00511, SLC24A3, DISC1
# 	   ADAMTS17, KCNIP1, CACNA1A, XYLT1, SEZ6L, KCNMA1, KIF26B, CHST11, NAV2, DGKG
# 	   APBB2, PRKCA, CASK, LDLRAD3, MTSS1, PDZD2, COBL, XKR4, PARD3, ZSWIM6
# PC_ 3
# Positive:  DLGAP2, TENM2, ROBO2, LINGO2, DCLK1, FRMPD4, CHRM3, RYR2, RGS6, ADGRL2
# 	   KCNQ5, NKAIN2, MGAT4C, GRIN2A, SYT1, RBFOX3, KCNH7, KCNC2, GRIN1, GABRG3
# 	   CAMK2A, IQCJ-SCHIP1, SYNPR, CDH12, PRKG1, CHD5, NRG1, KIRREL3, XIST, AC011287.1
# Negative:  KCNMB2-AS1, PCDH9-AS2, IPO9-AS1, AL353784.1, ZFPM2-AS1, LSAMP-AS1, NLGN4Y, LRP4-AS1, EPN2-AS1, CFTR
# 	   HEPN1, APOD, AC091885.2, LINC01572, AL354771.1, SCRG1, PRKCA-AS1, AC012404.1, OLIG1, AL138828.1
# 	   LHFPL3-AS1, GPNMB, AP000462.1, AC069437.1, PRSS48, AL355835.1, MROH9, TTTY14, ZBTB20-AS5, AC007319.1
# PC_ 4
# Positive:  LINGO2, ADGRL2, GABRG3, CHRM3, FRMPD4, KCNH7, DLGAP2, TENM2, ROBO2, RGS6
# 	   AP001825.1, RYR2, MGAT4C, NKAIN2, CDH12, KCNQ5, AC008696.2, AC068282.1, AP002336.2, MAK
# 	   RBFOX3, KCNC2, IQCJ-SCHIP1, GRIN2A, AC023590.1, AC011287.1, AC090579.1, ZNF804B, NLGN4Y, AL008633.1
# Negative:  ACTB, MARCKSL1, CST3, GAPDH, MT2A, MARCKS, FTH1, APOD, ACTG1, UBB
# 	   TUBA1A, OLIG1, MIF, HSP90AA1, BCAN, RPS2, FTL, DBI, PCSK1N, RPL8
# 	   RPLP1, H3F3B, TUBA1B, SRP14, MT1E, UBC, SOX8, CALM3, ALDOC, RPL37A
# PC_ 5
# Positive:  ADAM33, AC008080.4, CDK18, CLDN11, ST18, MYRF, PLP1, CERCAM, TMEM235, MAG
# 	   AL359091.1, CARNS1, AC044781.1, PTGDS, MBP, GPR17, CNP, BIN1, RASGEF1B, LINC01170
# 	   FRMD5, EPB41L2, SLC44A1, ABCA2, RNF220, MOBP, BMPER, EPHB1, TMTC2, PKP4
# Negative:  SNCB, NRGN, RGS4, NEFL, PTPRT, NPTX1, ENC1, NEFM, YWHAH, IDS
# 	   GRM5, VSNL1, PDGFRA, TUBA1B, CAMK2A, CPLX2, SLC17A7, SNAP25, SEZ6L, CHN1
# 	   RAB3A, VSTM2L, TSPYL1, SYT1, NAV2, GRIK1, STMN1, PNMA2, CALM3, PHYHIP
#
# Warning message in asMethod(object):
# "sparse->dense coercion: allocating vector of size 1.3 GiB"
# [1] "Cell type name: OPC"
# Centering and scaling data matrix
#
# PC_ 1
# Positive:  MOBP, KCNH8, PDE8A, NCKAP5, UNC5C, PDE1C, SLC7A14-AS1, LINC01608, CREB5, POLR2F
# 	   HIP1, AC012494.1, CNP, SCD, LPAR1, FAM107B, LINC00609, SLAIN1, SLCO3A1, GAB1
# 	   NEAT1, CERCAM, FGFR2, FBXL7, CDH20, MTUS1, AC079352.1, HHIP, ALCAM, CNDP1
# Negative:  CELF2, MYT1L, OPCML, DLGAP1, MIAT, ASIC2, PLCB1, FAM155A, DSCAM, KCNMA1
# 	   FGF14, FLRT2, NTRK3, DLGAP2, NRG3, XKR4, STXBP5L, SNTG1, CACNA1A, AGBL4
# 	   MEG3, DCLK1, CABP1, CACNA1B, GRIA1, KCND2, FRMPD4, FGF12, ATP2B2, LRFN5
# PC_ 2
# Positive:  XIST, GRID1, OTUD7A, DSCAML1, SLCO3A1, ZSWIM6, SLC39A11, PDE1C, PDE8A, KIRREL3
# 	   ATXN1, SPOCK1, HIP1, CDK19, LINC00609, MYO1D, MVB12B, LPGAT1, GAB2, GAB1
# 	   FGFR2, PCSK6, RFFL, ACYP2, DLEU2, ENOX1, BCAS3, PALM2-AKAP2, VRK2, NTM
# Negative:  TMSB4X, UTY, PCDH9-AS2, TTTY14, MIF, TMSB10, NLGN4Y, BEX3, COX6A1, AC064829.1
# 	   UQCR11, GAPDH, ATP5ME, SNCG, UQCR10, AC004797.1, USP9Y, ELOB, RPL41, GRIN1
# 	   SNHG25, FTH1, ATP5MPL, FTL, PDE5A, NDUFA4, AL359091.1, SNHG9, KDM5D, COX7C
# PC_ 3
# Positive:  KCNIP4, DLGAP1, NRG3, DLGAP2, FAM155A, OPCML, CCSER1, CSMD1, ROBO2, RALYL
# 	   DPP10, DSCAM, CNTN5, PLCB1, RIMS2, FGF14, LINGO2, KCNQ5, RGS6, STXBP5L
# 	   LRRTM4, FRMPD4, ST6GALNAC5, HS6ST3, SNTG1, NRXN1, CNTN4, SYT1, EFNA5, EPHA6
# Negative:  DBNDD2, CNP, SCD, CRYAB, MARCKSL1, FTH1, SPP1, FTL, ACTB, CLDND1
# 	   PTMA, TUBA1A, APLP1, PPP1R14A, S100B, CALM2, STMN1, TSC22D4, MTUS1, GLUL
# 	   CARNS1, FAM107B, MOBP, C4orf48, ATP1B1, SELENOW, TLE4, LINC00609, NEAT1, GAPDH
# PC_ 4
# Positive:  XIST, NRGN, NEFL, RAB6B, SLC17A7, EEF1A2, KCNJ4, RGS4, PHYHIP, ENC1
# 	   YWHAG, PNMA2, CALM3, SYT1, TUBA1B, SNCB, CPLX2, SULT4A1, ARHGDIG, CAMK2A
# 	   CHN1, CAMK2B, NEFM, PACSIN1, TUBB3, RAB3A, IDS, SYT4, NPTX1, TSPYL1
# Negative:  PCDH9-AS2, AC004852.2, KCNMB2-AS1, CHST11, UTY, PTPRZ1, LHFPL3, VCAN, NLGN4Y, PDGFRA
# 	   AP002370.2, AP003086.1, LSAMP-AS1, ANKUB1, AL359091.1, PCDH15, KCNMB2, PID1, LRMDA, TNR
# 	   LINC00513, CFTR, AC004797.1, LUZP2, LRRTM3, SOX6, PDE5A, AC026202.2, LINC00960, ELMO1-AS1
# PC_ 5
# Positive:  COL18A1, SLC5A11, DPYSL5, LINC00609, RASGRF2, ACSBG1, RBFOX1, AP001825.1, SYNJ2, AL591115.1
# 	   KCTD8, PCSK6, LINC01505, PDE1A, ITGA2, ZDHHC20, CNTNAP4, FMN1, SLC25A13, NEGR1
# 	   AC077690.1, HHATL, MVB12B, AC008696.2, MSRA, CDK18, LMCD1-AS1, MACROD2, PDE4D, AC104827.1
# Negative:  AC004852.2, VCAN, PDGFRA, PTPRZ1, FCHSD2, LHFPL3, CHST11, NLGN1, PCDH15, PLXDC2
# 	   OPALIN, NXPH1, SOX6, CTNND2, LAMA2, LUZP2, DISC1, LINC01608, ANO4, PITPNC1
# 	   C1orf61, SLC35F1, PALM2-AKAP2, RBMS3, PID1, AC114971.1, AL445250.1, LRMDA, SLC1A2, KANK1
#
# Warning message in asMethod(object):
# "sparse->dense coercion: allocating vector of size 1.3 GiB"
# [1] "Cell type name: Oli"

# %%
#saveRDS(rA,file = 'rA.rds')

# %%
R <- DIALOGUE.run(rA = rA, main = 'res',# list of cell.type objects
                  param = DLG.get.param( pheno = "Condition",k = 5, # number of MCPs to identify
                                        results.dir = results.dir,
                                        spatial.flag = F,plot.flag = T,
                                        conf = "cellQ"))
# Out:
# Error in DIALOGUE.run(rA = rA, main = "res", param = DLG.get.param(pheno = "Condition", : could not find function "DIALOGUE.run"
# Traceback:

# %%
par(mfrow=c(1,2),oma = c(8, 1, 0, 5),xpd = T)
summary(R)

print(round(R$phenoZ,5))
# Out:
# Error in summary(R): object 'R' not found
# Traceback:
#
# 1. summary(R)

# %%
data = readRDS('./condition/DLG.output_res.rds')

# %%
R =data

# %%
MCP1 = as.data.frame(do.call(cbind, R$MCPs$MCP1))
# Out:
# Warning message in (function (..., deparse.level = 1) :
# "number of rows of result is not a multiple of vector length (arg 2)"

# %%
head(MCP1,2)
# Out:
#   ExN.up     Ast.up Oli.up     Mic.up End.up OPC.up     InN.up ExN.down
# 1 ABL1       ABLIM1 1-Mar      3-Mar  ABCB1  AC007376.2 ABCB9  AC002463.1
# 2 AC004951.1 ABR    AC008571.2 ABCC4  ABLIM3 AC023282.1 ABLIM2 AC004594.1
#   Ast.down   Oli.down   Mic.down   End.down OPC.down   InN.down
# 1 AC016716.2 AC016716.2 ABCA2      ACTB     AC004797.1 AC016716.2
# 2 AC104827.1 AC068587.4 AC009041.2 ACTG1    AC012404.1 AC026202.2

# %%
write.csv(MCP1,file = './condition/MCP1.csv',row.names =F)

# %%
MCP2 = as.data.frame(do.call(cbind, R$MCPs$MCP2))
# Out:
# Warning message in (function (..., deparse.level = 1) :
# "number of rows of result is not a multiple of vector length (arg 2)"

# %%
write.csv(MCP2,file = './condition/MCP2.csv',row.names =F)

# %%
MCP3 = as.data.frame(do.call(cbind, R$MCPs$MCP3))
# Out:
# Warning message in (function (..., deparse.level = 1) :
# "number of rows of result is not a multiple of vector length (arg 1)"

# %%
write.csv(MCP3,file = './condition/MCP3.csv',row.names =F)

# %%
MCP4 = as.data.frame(do.call(cbind, R$MCPs$MCP4))
# Out:
# Warning message in (function (..., deparse.level = 1) :
# "number of rows of result is not a multiple of vector length (arg 2)"

# %%
write.csv(MCP4,file = './condition/MCP4.csv',row.names =F)

# %%
MCP5 = as.data.frame(do.call(cbind, R$MCPs$MCP5))
# Out:
# Warning message in (function (..., deparse.level = 1) :
# "number of rows of result is not a multiple of vector length (arg 1)"

# %%
write.csv(MCP5,file = './condition/MCP5.csv',row.names =F)
