# %%
setwd('/import/a.wangsheng/')

# %%
data = read.table('./prot.txt',header =F,sep = '\t')

# %%
library(ggplot2)
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 4.2.3"

# %%
data$V1 = factor(data$V1 ,levels = data$V1 )

# %%
ggplot(data=data,mapping=aes(x=V1,y=V2,fill=V1,group=factor(1)))+
  geom_bar(stat="identity") +theme_classic() + 
theme(axis.text.x = element_text(angle = 45, hjust = 1)) +xlab('Protein') +
ylab('Value')
# Out:
# plot without title

# %%
ggsave('barplot.pdf',width = 6,height = 5)
