# %%
setwd('/import/DB/fel/BJTC-204')

# %%
library("enrichR")
# Out:
# Welcome to enrichR
# Checking connection ...
#
# Enrichr ...
# Connection is Live!
#
# FlyEnrichr ...
# Connection is Live!
#
# WormEnrichr ...
# Connection is Live!
#
# YeastEnrichr ...
# Connection is Live!
#
# FishEnrichr ...
# Connection is Live!
#
# OxEnrichr ...
# Connection is Live!

# %%
websiteLive <- getOption("enrichR.live")
if (websiteLive) {
    listEnrichrSites()
    setEnrichrSite("Enrichr") # Human genes   
}
# Out:
# Enrichr ...
# Connection is Live!
#
# FlyEnrichr ...
# Connection is Live!
#
# WormEnrichr ...
# Connection is Live!
#
# YeastEnrichr ...
# Connection is Live!
#
# FishEnrichr ...
# Connection is Live!
#
# OxEnrichr ...
# Connection is Live!
#
# Connection changed to https://maayanlab.cloud/Enrichr/
#
# Connection is Live!

# %%
if (websiteLive) dbs <- listEnrichrDbs()

# %%
dbs$libraryName
# Out:
#   [1] "Genome_Browser_PWMs"
#   [2] "TRANSFAC_and_JASPAR_PWMs"
#   [3] "Transcription_Factor_PPIs"
#   [4] "ChEA_2013"
#   [5] "Drug_Perturbations_from_GEO_2014"
#   [6] "ENCODE_TF_ChIP-seq_2014"
#   [7] "BioCarta_2013"
#   [8] "Reactome_2013"
#   [9] "WikiPathways_2013"
#  [10] "Disease_Signatures_from_GEO_up_2014"
#  [11] "KEGG_2013"
#  [12] "TF-LOF_Expression_from_GEO"
#  [13] "TargetScan_microRNA"
#  [14] "PPI_Hub_Proteins"
#  [15] "GO_Molecular_Function_2015"
#  [16] "GeneSigDB"
#  [17] "Chromosome_Location"
#  [18] "Human_Gene_Atlas"
#  [19] "Mouse_Gene_Atlas"
#  [20] "GO_Cellular_Component_2015"
#  [21] "GO_Biological_Process_2015"
#  [22] "Human_Phenotype_Ontology"
#  [23] "Epigenomics_Roadmap_HM_ChIP-seq"
#  [24] "KEA_2013"
#  [25] "NURSA_Human_Endogenous_Complexome"
#  [26] "CORUM"
#  [27] "SILAC_Phosphoproteomics"
#  [28] "MGI_Mammalian_Phenotype_Level_3"
#  [29] "MGI_Mammalian_Phenotype_Level_4"
#  [30] "Old_CMAP_up"
#  [31] "Old_CMAP_down"
#  [32] "OMIM_Disease"
# ...

# %%
dbs <- c("DSigDB",'KEGG_2019_Human','GO_Biological_Process_2023','GO_Molecular_Function_2023')
if (websiteLive) {
    enriched <- enrichr(c('HIST1H4C','PRSS3','TUSC3'), dbs)
}
# Out:
# Uploading data to Enrichr... Done.
#   Querying DSigDB... Done.
#   Querying KEGG_2019_Human... Done.
#   Querying GO_Biological_Process_2023... Done.
#   Querying GO_Molecular_Function_2023... Done.
# Parsing results... Done.

# %%
enriched$GO_Molecular_Function_2023
# Out:
#   Term                                                          Overlap
# 1 Magnesium Ion Transmembrane Transporter Activity (GO:0015095) 1/10
# 2 Metal Ion Transmembrane Transporter Activity (GO:0046873)     1/29
# 3 Serine-Type Endopeptidase Activity (GO:0004252)               1/125
# 4 Serine-Type Peptidase Activity (GO:0008236)                   1/142
# 5 Endopeptidase Activity (GO:0004175)                           1/335
# 6 Calcium Ion Binding (GO:0005509)                              1/346
# 7 Metal Ion Binding (GO:0046872)                                1/521
#   P.value     Adjusted.P.value Old.P.value Old.Adjusted.P.value Odds.Ratio
# 1 0.001499295 0.01049506       0           0                    1110.44444
# 2 0.004343851 0.01520348       0           0                     356.58929
# 3 0.018633837 0.03701254       0           0                      80.13306
# 4 0.021150023 0.03701254       0           0                      70.41135
# ...

# %%
write.csv(enriched$DSigDB,file = './figure/target.dsig.csv')

# %%
write.csv(enriched$KEGG_2019_Human,file = './figure/target.kegg.csv')

# %%
library(ggplot2)
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 4.2.3"

# %%
if (websiteLive) {
    plotEnrich(enriched[[1]], showTerms = 10, numChar = 40, y = "Genes", orderBy = "P.value")+ theme(text=element_text(size= 13 ))
}
# Out:
# plot without title

# %%
library(ggplot2)

# %%
ggsave('./figure/drug.pdf',width = 6,height = 6)

# %%
if (websiteLive) {
    plotEnrich(enriched[[2]], showTerms = 10, numChar = 40, y = "Genes", orderBy = "P.value")+ theme(text=element_text(size= 13 ))
}
# Out:
# plot without title

# %%
ggsave('./figure/kegg.pdf',width = 6,height = 6)

# %%
if (websiteLive) {
    plotEnrich(enriched[[3]], showTerms = 10, numChar = 40, y = "Genes", orderBy = "P.value")+ theme(text=element_text(size= 13 ))
}
# Out:
# plot without title

# %%
if (websiteLive) {
    plotEnrich(enriched[[4]], showTerms = 10, numChar = 40, y = "Genes", orderBy = "P.value")+ theme(text=element_text(size= 13 ))
}
# Out:
# plot without title
