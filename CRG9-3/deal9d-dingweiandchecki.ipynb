# %%
setwd('/import/DB/fel/BJTC-204')

# %%
data = read.table('./subdingwei.txt',header =T,sep = '\t')

# %%
head(data,6)
# Out:
#   type                  HIST1H4C  PRSS3     TUSC3
# 1 Centrosome            -1.682585 -1.332571 -1.557121
# 2 Cytoplasm             -2.229355 -3.250651 -2.234574
# 3 Cytoskeleton          -1.662518 -1.943487 -1.483979
# 4 Endosome              -3.827210 -2.804896 -2.222125
# 5 Endoplasmic reticulum -1.678877 -1.785239  0.993993
# 6 Extracellular         -2.993731  1.282783 -4.588474

# %%
library(ggplot2)
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 4.2.3"

# %%
library(ggthemes)
ggplot(data,aes(x = reorder(type,HIST1H4C),y=HIST1H4C,
           fill = type,
           label = HIST1H4C))+
    geom_col(show.legend = FALSE) +
    coord_flip() +
    geom_text(nudge_x = 0.1) +
    xlab('') +
    ggtitle('Expression level of significant HIST1H4C')+
    theme_clean()
# Out:
# Warning message:
# "package 'ggthemes' was built under R version 4.2.3"
# plot without title

# %%
library(ggthemes)
ggplot(data,aes(x = reorder(type,PRSS3),y=PRSS3,
           fill = type,
           label = PRSS3))+
    geom_col(show.legend = FALSE) +
    coord_flip() +
    geom_text(nudge_x = 0.1) +
    xlab('') +
    ggtitle('Expression level of significant PRSS3')+
    theme_clean()
# Out:
# plot without title

# %%
library(ggthemes)
ggplot(data,aes(x = reorder(type,TUSC3),y=TUSC3,
           fill = type,
           label = TUSC3))+
    geom_col(show.legend = FALSE) +
    coord_flip() +
    geom_text(nudge_x = 0.1) +
    xlab('') +
    ggtitle('Expression level of significant TUSC3')+
    theme_clean()
# Out:
# plot without title

# %%
getwd()
# Out:
# [1] "/import/jliu/data2/scrna"

# %%
library(openxlsx)
data<- read.xlsx("../res/CI-CTR/bulk/74-mRNA_FPKM.genename.xlsx", sheet = 1)
library(dplyr)

# %%
head(data,2)
# Out:
#   Gene_name C10       C11       C12       C13       C14       C15
# 1 ZZZ3       9.694104  8.204165  9.569441  6.659882  5.449594  8.611691
# 2 ZZEF1     18.515927 18.296195 19.053030 18.403302 19.992571 18.649972
#   C16       C17       C18       ... CI41      CI42      CI43      CI44
# 1  6.886018  5.389103  5.336686 ... 14.880933  8.037799  5.667441 11.80003
# 2 19.680564 20.438019 19.539639 ...  8.751292 17.115120 16.585566 16.60637
#   CI4       CI5       CI6       CI7      CI8       CI9
# 1  6.659176  5.785232  8.749977 11.03076  8.004704 10.07247
# 2 18.344102 21.665904 21.333761 20.21582 17.918223 13.92859

# %%
data = data[!duplicated(data$Gene_name),]

# %%
library(linkET)

# %%
expr1 = data %>% filter(Gene_name %in% c('FAM200B','BCL2A1','IGJ','TXN')) %>%  tibble::remove_rownames() %>% 
tibble::column_to_rownames(.,'Gene_name') %>% t() %>% as.data.frame()

# %%
head(expr1,2)
# Out:
#     TXN       IGJ      FAM200B  BCL2A1
# C10  7.655688 21.40125 4.886505 22.32717
# C11 17.794071 21.30293 6.201921 32.12134

# %%
expr1 = data %>% filter(Gene_name %in% c('FAM200B','BCL2A1','IGJ','TXN')) %>%  tibble::remove_rownames() %>% 
tibble::column_to_rownames(.,'Gene_name') %>% t() %>% as.data.frame()

# %%
checki = read.table('./checkimmu.txt',header =F)

# %%
gene = checki$V1

# %%
expr2 = data %>% filter(Gene_name %in% gene) %>%  tibble::remove_rownames() %>% 
tibble::column_to_rownames(.,'Gene_name') %>% t() %>% as.data.frame()

# %%
head(expr2,2)
# Out:
#     TNFSF9     TNFSF4   TNFSF15   TNFSF14  TNFRSF9  TNFRSF8  TNFRSF25  TNFRSF14
# C10 0.06244118 2.335969 0.3147624 17.80428 3.397495 4.082689 12.358764 22.07720
# C11 0.57962415 2.218426 0.1089287 16.12199 1.305784 3.583620  9.160292 19.54021
#     TIGIT     PDCD1LG2  ... CD86     CD48     CD44     CD40     CD28
# C10  5.962277 0.2353423 ... 17.43522 69.44686 71.89586 6.051481 24.05006
# C11 12.656005 2.5295569 ... 17.86174 69.98670 70.60826 5.443445 19.00903
#     CD276      CD274    CD200R1  CD200    C10orf54
# C10 0.07467704 1.851188 4.795690 1.833382 176.3022
# C11 0.00000000 9.425702 3.313861 1.098531 146.3151

# %%
cor_res <- correlate(expr1, expr2,method = "spearman")
  
qcorrplot(cor_res) +
  geom_square() +
  scale_fill_gradientn(colours = RColorBrewer::brewer.pal(11, "RdBu"))
# Out:
# plot without title

# %%
options(repr.plot.width = 12,repr.plot.height = 4)

# %%
library(tidyr)
library(tibble)
# Out:
# Warning message:
# "package 'tibble' was built under R version 4.2.3"

# %%
# 先整理下数据
df_r <- cor_res$r %>% 
  as.data.frame() %>% 
  rownames_to_column(var = "gene") %>% 
  pivot_longer(-1,names_to = "cell_type",values_to = "correlation")

df_p <- cor_res$p %>% 
  as.data.frame() %>% 
  rownames_to_column(var = "gene") %>% 
  pivot_longer(-1,names_to = "cell_type",values_to = "pvalue")

df_cor <- df_r %>% 
  left_join(df_p) %>% 
  mutate(stars = cut(pvalue,breaks = c(-Inf,0.05,0.01,0.001,Inf),right = F,labels = c("***","**","*"," ")))
## Joining with `by = join_by(gene, cell_type)`

head(df_cor)
# Out:
# Joining with `by = join_by(gene, cell_type)`
#   gene cell_type correlation pvalue     stars
# 1 TXN  TNFSF9     0.03763608 0.75021283
# 2 TXN  TNFSF4    -0.05791929 0.62330156
# 3 TXN  TNFSF15    0.21196594 0.06994019
# 4 TXN  TNFSF14    0.28805628 0.01307417 *
# 5 TXN  TNFRSF9    0.26921881 0.02064036 *
# 6 TXN  TNFRSF8   -0.07305442 0.53539466

# %%
library(ggplot2)

ggplot(df_cor, aes(cell_type,gene))+
  geom_tile(aes(fill=correlation))+
  geom_text(aes(label=stars), color="black", size=4)+
  scale_fill_gradient2(low='#67B26F', high='#F2AA9D',mid = 'white',
                      limit=c(-1,1),name=paste0("*    p < 0.05","\n\n","**  p < 0.01","\n\n","*** p < 0.001","\n\n","Correlation"))+
  labs(x=NULL,y=NULL)+
  theme(axis.text.x = element_text(size=13,angle = 45,hjust = 1,color = "black"),
        axis.text.y = element_text(size=13,color = "black"),
        axis.ticks.y = element_blank(),
        panel.background=element_blank())
# Out:
# plot without title

# %% [markdown]
# ###
